# %% [markdown]
# # COVID-19 Literature Clustering

# %% [markdown]
# # Table of Contents
# 1. Loading the data
# 2. Pre-processing
# 3. Vectorization
# 4. PCA  & Clustering
# 5. Dimensionality Reduction with t-SNE
# 6. Topic Modeling on Each Cluster
# 7. Classify
# 8. Plot
# 9. How to Use the Plot?
# 10. Conclusion
# 11. Citation/Sources
#
# <br>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import glob
import json
from Bio import Entrez
from Bio import Medline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
def get_breaks(content, length):
    data = ""
    words = content.split(' ')
    total_chars = 0

    # add break every length characters
    for i in range(len(words)):
        total_chars += len(words[i])
        if total_chars > length:
            data = data + "<br>" + words[i]
            total_chars = 0
        else:
            data = data + " " + words[i]
    return data

# %% [markdown]
# #### specification du nombre de fichiers a lire :

# %%
max_articles = 10
term = "Covid"

# %%
Entrez.email = 'A.N.Other@example.com'
h = Entrez.esearch(db='pubmed', retmax=max_articles, term=term)
result = Entrez.read(h)
result
ids = result['IdList']
h = Entrez.efetch(db='pubmed', id=ids, rettype='medline', retmode='json')
records = Medline.parse(h)

# %%
dict_ = {'paper_id': [], 'abstract': [], 'body_text': [], 'authors': [], 'title': [], 'journal': [], 'abstract_summary': []}
for idx, entry in enumerate(records):

    if idx >max_articles:
        break
    try:
        dict_['paper_id'].append(entry["PMID"])
    except Exception as e:
        dict_['paper_id'].append("")
        
    try:
        dict_['abstract'].append(entry["AB"])
        # also create a column for the summary of abstract to be used in a plot
        if len(entry["AB"]) == 0: 
            # no abstract provided
            dict_['abstract_summary'].append("Not provided.")
        elif len(entry["AB"].split(' ')) > 100:
            # abstract provided is too long for plot, take first 100 words append with ...
            info = entry["AB"].split(' ')[:100]
            summary = get_breaks(' '.join(info), 40)
            dict_['abstract_summary'].append(summary + "...")
        else:
            # abstract is short enough
            summary = get_breaks(entry["AB"], 40)
            dict_['abstract_summary'].append(summary)
    except Exception as e:
        dict_['abstract'].append("")  
        dict_['abstract_summary'].append("Not provided.")

        
    try:
        dict_['body_text'].append(entry["AB"])
    except Exception as e:
        dict_['body_text'].append("")     
    
   
    
    
    try:
        # if more than one author
        authors = entry['AU'][0].split(',')
        if len(authors) > 2:
            # if more than 2 authors, take them all with html tag breaks in between
            dict_['authors'].append(get_breaks('. '.join(authors), 40))
        else:
            # authors will fit in plot
            dict_['authors'].append(". ".join(authors))
    except Exception as e:
        # if only one author - or Null valie
        try : 
            dict_['authors'].append(entry['AU'][0])
        except Exception as e:
            dict_['authors'].append("")


    
    # add the title information, add breaks when needed
    try:
        title = get_breaks(entry['TI'][0], 40)
        dict_['title'].append(title)
    # if title was not provided
    except Exception as e:
        try:
            dict_['title'].append(entry['TI'][0])
        except Exception as e:
            dict_['title'].append("")
    
    # add the journal information
    dict_['journal'].append(entry['PT'][0])
df_covid = pd.DataFrame(dict_, columns=['paper_id', 'abstract', 'body_text', 'authors', 'title', 'journal', 'abstract_summary'])
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   paper_id          10 non-null     object
#  1   abstract          10 non-null     object
#  2   body_text         10 non-null     object
#  3   authors           10 non-null     object
#  4   title             10 non-null     object
#  5   journal           10 non-null     object
#  6   abstract_summary  10 non-null     object
# dtypes: object(7)
# memory usage: 688.0+ bytes

# %% [markdown]
# ## Some feature engineering
# Adding word count columns for both abstract and body_text can be useful parameters later:

# %%
df_covid['abstract_word_count'] = df_covid['abstract'].apply(lambda x: len(x.strip().split()))  # word count in abstract
df_covid['body_word_count'] = df_covid['body_text'].apply(lambda x: len(x.strip().split()))  # word count in body
df_covid['body_unique_words']=df_covid['body_text'].apply(lambda x:len(set(str(x).split())))  # number of unique words in body
df_covid.head()
# Out:
#    paper_id                                           abstract  \
# 0  33957689  The COVID-19 pandemic poses new challenges for...
# 1  33957677  INTRODUCTION: Depression is responsible for 80...
# 2  33957663  OBJECTIVE: To assess the effect of a consumer-...
# 3  33957662
# 4  33957638  BACKGROUND: Much remains unknown about the tra...
#
#                                            body_text              authors  \
# 0  The COVID-19 pandemic poses new challenges for...             Berlit P
# 1  INTRODUCTION: Depression is responsible for 80...               Nass J
# 2  OBJECTIVE: To assess the effect of a consumer-...             Smith RB
# 3                                                                 Toma HV
# 4  BACKGROUND: Much remains unknown about the tra...  Mendoza-Hernandez M
#
#   title           journal                                   abstract_summary  \
# 0     [  English Abstract   The COVID-19 pandemic poses new challenges fo...
# 1     W   Journal Article   INTRODUCTION: Depression is responsible for<b...
# 2     M   Journal Article   OBJECTIVE: To assess the effect of a<br>consu...
# 3     C   Journal Article                                      Not provided.
# 4     P      Case Reports   BACKGROUND: Much remains unknown about the<br...
#
#    abstract_word_count  body_word_count  body_unique_words
# 0                  142              142                103
# 1                  231              231                145
# 2                  291              291                165
# 3                    0                0                  0
# 4                  154              154                111

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   paper_id             10 non-null     object
#  1   abstract             10 non-null     object
#  2   body_text            10 non-null     object
#  3   authors              10 non-null     object
#  4   title                10 non-null     object
#  5   journal              10 non-null     object
#  6   abstract_summary     10 non-null     object
#  7   abstract_word_count  10 non-null     int64
#  8   body_word_count      10 non-null     int64
#  9   body_unique_words    10 non-null     int64
# dtypes: int64(3), object(7)
# memory usage: 928.0+ bytes

# %%
df_covid['abstract'].describe(include='all')
# Out:
# count     10
# unique     9
# top
# freq       2
# Name: abstract, dtype: object

# %% [markdown]
# ## Handle Possible Duplicates

# %% [markdown]
# When we look at the unique values above, we can see that tehre are duplicates. It may have caused because of author submiting the article to multiple journals. Let's remove the duplicats from our dataset:
#
# (Thank you Desmond Yeoh for recommending the below approach on Kaggle)

# %%
df_covid.drop_duplicates(['abstract', 'body_text'], inplace=True)
df_covid['abstract'].describe(include='all')
# Out:
# count                                                     9
# unique                                                    9
# top       BACKGROUND: Much remains unknown about the tra...
# freq                                                      1
# Name: abstract, dtype: object

# %%
df_covid['body_text'].describe(include='all')
# Out:
# count                                                     9
# unique                                                    9
# top       BACKGROUND: Much remains unknown about the tra...
# freq                                                      1
# Name: body_text, dtype: object

# %% [markdown]
# It looks like we didn't have duplicates. Instead, it was articles without Abstracts.

# %% [markdown]
# ## Take a Look at the Data:

# %%
df_covid.head()
# Out:
#    paper_id                                           abstract  \
# 0  33957689  The COVID-19 pandemic poses new challenges for...
# 1  33957677  INTRODUCTION: Depression is responsible for 80...
# 2  33957663  OBJECTIVE: To assess the effect of a consumer-...
# 3  33957662
# 4  33957638  BACKGROUND: Much remains unknown about the tra...
#
#                                            body_text              authors  \
# 0  The COVID-19 pandemic poses new challenges for...             Berlit P
# 1  INTRODUCTION: Depression is responsible for 80...               Nass J
# 2  OBJECTIVE: To assess the effect of a consumer-...             Smith RB
# 3                                                                 Toma HV
# 4  BACKGROUND: Much remains unknown about the tra...  Mendoza-Hernandez M
#
#   title           journal                                   abstract_summary  \
# 0     [  English Abstract   The COVID-19 pandemic poses new challenges fo...
# 1     W   Journal Article   INTRODUCTION: Depression is responsible for<b...
# 2     M   Journal Article   OBJECTIVE: To assess the effect of a<br>consu...
# 3     C   Journal Article                                      Not provided.
# 4     P      Case Reports   BACKGROUND: Much remains unknown about the<br...
#
#    abstract_word_count  body_word_count  body_unique_words
# 0                  142              142                103
# 1                  231              231                145
# 2                  291              291                165
# 3                    0                0                  0
# 4                  154              154                111

# %% [markdown]
# In the majority of this notebook we will be working with **body_text** <br>
# Links to the papers will be generated using **doi**

# %%
df_covid.describe()
# Out:
#        abstract_word_count  body_word_count  body_unique_words
# count             9.000000         9.000000           9.000000
# mean            165.333333       165.333333         105.000000
# std             106.056589       106.056589          56.120406
# min               0.000000         0.000000           0.000000
# 25%             103.000000       103.000000          84.000000
# 50%             154.000000       154.000000         111.000000
# 75%             231.000000       231.000000         145.000000
# max             312.000000       312.000000         165.000000

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ### Réduction de la taille du dataset :

# %%
#df = df_covid.sample(4000, random_state=42)
df = df_covid

# %% [markdown]
# ### Suppression des valeurs null :

# %% [markdown]
# Now that we have our dataset loaded, we need to clean-up the text to improve any clustering or classification efforts. First, let's drop Null vales:

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   paper_id             9 non-null      object
#  1   abstract             9 non-null      object
#  2   body_text            9 non-null      object
#  3   authors              9 non-null      object
#  4   title                9 non-null      object
#  5   journal              9 non-null      object
#  6   abstract_summary     9 non-null      object
#  7   abstract_word_count  9 non-null      int64
#  8   body_word_count      9 non-null      int64
#  9   body_unique_words    9 non-null      int64
# dtypes: int64(3), object(7)
# memory usage: 792.0+ bytes

# %% [markdown]
# ### Handling multiple languages
# Next we are going to determine the language of each paper in the dataframe. Not all of the sources are English and the language needs to be identified so that we know how handle these instances

# %%
from tqdm import tqdm
from langdetect import detect
from langdetect import DetectorFactory

# set seed
DetectorFactory.seed = 0

# hold label - language
languages = []

# go through each text
for ii in tqdm(range(0,len(df))):
    # split by space into list, take the first x intex, join with space
    text = df.iloc[ii]['body_text'].split(" ")
    
    lang = "en"
    try:
        if len(text) > 50:
            lang = detect(" ".join(text[:50]))
        elif len(text) > 0:
            lang = detect(" ".join(text[:len(text)]))
    # ught... beginning of the document was not in a good format
    except Exception as e:
        all_words = set(text)
        try:
            lang = detect(" ".join(all_words))
        # what!! :( let's see if we can find any text in abstract...
        except Exception as e:
            
            try:
                # let's try to label it through the abstract then
                lang = detect(df.iloc[ii]['abstract_summary'])
            except Exception as e:
                lang = "unknown"
                pass
    
    # get the language    
    languages.append(lang)
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 49.51it/s]

# %%
from pprint import pprint

languages_dict = {}
for lang in set(languages):
    languages_dict[lang] = languages.count(lang)
    
print("Total: {}\n".format(len(languages)))
pprint(languages_dict)
# Out:
# Total: 9
#
# {'en': 9}

# %% [markdown]
# Lets take a look at the language distribution in the dataset

# %%
df['language'] = languages
plt.bar(range(len(languages_dict)), list(languages_dict.values()), align='center')
plt.xticks(range(len(languages_dict)), list(languages_dict.keys()))
plt.title("Distribution of Languages in Dataset")
plt.show()

# %% [markdown]
# We will be dropping any language that is not English. Attempting to translate foreign texts gave the following problems:
#
# 1. API calls were limited
#
# 2. Translating the language may not carry over the true semantic meaning of the text

# %%
df = df[df['language'] == 'en'] 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   paper_id             9 non-null      object
#  1   abstract             9 non-null      object
#  2   body_text            9 non-null      object
#  3   authors              9 non-null      object
#  4   title                9 non-null      object
#  5   journal              9 non-null      object
#  6   abstract_summary     9 non-null      object
#  7   abstract_word_count  9 non-null      int64
#  8   body_word_count      9 non-null      int64
#  9   body_unique_words    9 non-null      int64
#  10  language             9 non-null      object
# dtypes: int64(3), object(8)
# memory usage: 864.0+ bytes

# %%
#Download the spacy bio parser

from IPython.utils import io
# with io.capture_output() as captured:
#    !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_core_sci_lg-0.4.0.tar.gz

# %%
import spacy.cli
spacy.cli.download("en_core_web_lg")
import en_core_web_lg
nlp = en_core_web_lg.load()
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
#NLP 
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
import en_core_sci_lg  # model downloaded in previous step

# %% [markdown]
# ### Stopwords
#
# Part of the preprocessing will be finding and removing stopwords (common words that will act as noise in the clustering step).

# %%
import string

punctuations = string.punctuation
stopwords = list(STOP_WORDS)
print(stopwords)
print("-----------")

print(punctuations)
# Out:
# ['are', 'alone', 'could', 'the', 'might', '’ll', 'although', 'move', 'another', 'when', "'ve", 'who', 'either', 'whatever', 'seeming', 'against', 'each', 'anyway', 'here', 'next', "'re", 'him', 'mine', 'eleven', 'therein', 'then', 'thus', 'therefore', 'for', 'without', 'becomes', 'thereafter', 'anywhere', 'seemed', 'hundred', 'becoming', 'out', 'n’t', 'yourself', 'will', 'cannot', 'himself', 'hers', 'several', "'s", 'something', 'because', 'others', 'over', '‘ve', 'empty', 'two', 'in', 'third', 'from', 'though', '’ve', 'ever', 'where', 'never', 'nor', '‘d', 'full', 'already', 'became', 'some', 'twelve', 'yet', 'first', 'be', "'d", 'using', 'together', 'see', 'afterwards', 'more', 'made', 'whether', 'after', 'former', 'should', 'ca', 'otherwise', 'last', 'seems', 'wherein', 'n‘t', 'nothing', 'really', '‘re', 'she', 'except', 'various', 'same', 'again', 'whither', 'along', 'between', 'due', 'itself', 'formerly', 'latterly', 'become', 'keep', 'somewhere', 'regarding', 'please', 'since', 'only', "'ll", 'however', 'had', 'until', 'themselves', 'fifteen', 'elsewhere', '‘s', 'back', 'also', 'most', 'hence', 'whence', 'hereafter', 'a', 'would', 'while', 'these', 'if', 'own', 'moreover', 'ourselves', 'take', 'beside', 'their', 'one', 'ten', 'am', 'before', 'both', 'often', 'so', 'else', 'as', 'wherever', 'above', 'none', 'whose', 'such', 'very', 'get', 'whole', 'used', '’re', 'to', 'what', 'within', 'still', 'throughout', 'not', 'namely', 'were', 'thru', 'noone', 'toward', 'them', 'sometimes', 'further', 'herein', 'anyhow', 'thereby', 'any', 'his', 'of', 'down', 'being', 'few', 'mostly', '’d', 'nowhere', 'there', 'whom', 'why', 'those', 'everywhere', 'he', 'unless', 'no', 'may', 'done', 'make', 'towards', 'fifty', 'whereafter', 'side', 'every', 'indeed', 'nobody', "'m", 'do', 'twenty', 'all', '’m', 'say', 'least', 'with', 'into', 'at', 'this', 'hereby', 'or', 'amongst', 'during', 'seem', 'can', 'latter', '’s', 'has', 'is', 'hereupon', 'top', 'go', 'six', 'perhaps', 'beyond', 'through', 'just', 'off', 'and', 'we', 'yourselves', 'how', 'myself', 'nevertheless', 'much', 'too', 'always', 'rather', 'upon', "n't", 'my', 'eight', 'meanwhile', 'thereupon', 'did', 'forty', 'now', 'four', 'sometime', 'beforehand', 'three', 'does', 'it', 'neither', 'about', 'than', 'on', 'thence', 'put', 'whereupon', 'herself', 'call', 'give', 'below', 'i', 'yours', 'but', 'five', 'somehow', 'by', 'besides', 'sixty', 'anything', 'front', 'been', 'doing', 're', 'whereas', 'well', 'must', 'whenever', 'enough', 'me', 'ours', 'anyone', 'someone', 'bottom', 'via', 'an', 'almost', 'us', 'that', 'among', 'many', 'other', 'even', 'our', 'her', 'up', 'amount', 'they', 'everything', 'whoever', 'have', 'across', 'once', 'name', 'behind', 'serious', 'was', 'show', 'you', 'part', 'onto', 'per', 'around', 'your', 'which', '‘ll', 'everyone', 'quite', '‘m', 'less', 'under', 'nine', 'whereby', 'its']
# -----------
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %% [markdown]
# Now the above stopwords are used in everyday english text. Research papers will often frequently use words that don't actually contribute to the meaning and are not considered everyday stopwords.
#
# Thank you Daniel Wolffram for the idea.
# #### Cite: [Custom Stop Words | Topic Modeling: Finding Related Articles](https://www.kaggle.com/danielwolffram/topic-modeling-finding-related-articles)

# %%
custom_stop_words = [
    'doi', 'preprint', 'copyright', 'peer', 'reviewed', 'org', 'https', 'et', 'al', 'author', 'figure', 
    'rights', 'reserved', 'permission', 'used', 'using', 'biorxiv', 'medrxiv', 'license', 'fig', 'fig.', 
    'al.', 'Elsevier', 'PMC', 'CZI', 'www'
]

for w in custom_stop_words:
    if w not in stopwords:
        stopwords.append(w)

# %% [markdown]
# ### Next lets create a function that will process the text data for us.
# For this purpose we will be using the spacy library. This function will convert text to lower case, remove punctuation, and find and remove stopwords. For the parser, we will use en_core_sci_lg. This is a model for processing biomedical, scientific or clinical text.

# %%
# Parser
parser = en_core_sci_lg.load(disable=["tagger", "ner"])
parser.max_length = 7000000

def spacy_tokenizer(sentence):
    mytokens = parser(sentence)

    mytokens = [ word for word in mytokens if word not in stopwords and word.text not in punctuations ]
    mytokens = " ".join([i for i in mytokens])
    return mytokens

# %% [markdown]
# Applying the text-processing function on the **body_text**.

# %%
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
#c'est dans cette partie la que ça bug , ça prend un temps énorme et on a pas eu de résultat  
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
#tqdm.pandas()
#df["processed_text"] = df["body_text"].progress_apply(spacy_tokenizer)

# %%
import spacy
nlp = en_core_web_lg.load()
def spacy_process(texte):
    tmp = []
    tmp.append(texte)
    for lt in tmp:
        mytokens = nlp(lt)
        mytokens2 = [word.lemma_.lower().strip() for word in mytokens if word.pos_ != "PUNCT" and word.text not in stopwords]
        mytokens2 = " ".join([i for i in mytokens2])
    return mytokens2
df["processed_text"] = df["body_text"].apply(spacy_process)

# %% [markdown]
# ### Exemple

# %%
k = spacy_process("hello , it's me and I am speaking to you my friends")
print(k)
# Out:
# hello i speak friend

# %%
df.head()
# Out:
#    paper_id                                           abstract  \
# 0  33957689  The COVID-19 pandemic poses new challenges for...
# 1  33957677  INTRODUCTION: Depression is responsible for 80...
# 2  33957663  OBJECTIVE: To assess the effect of a consumer-...
# 3  33957662
# 4  33957638  BACKGROUND: Much remains unknown about the tra...
#
#                                            body_text              authors  \
# 0  The COVID-19 pandemic poses new challenges for...             Berlit P
# 1  INTRODUCTION: Depression is responsible for 80...               Nass J
# 2  OBJECTIVE: To assess the effect of a consumer-...             Smith RB
# 3                                                                 Toma HV
# 4  BACKGROUND: Much remains unknown about the tra...  Mendoza-Hernandez M
#
#   title           journal                                   abstract_summary  \
# 0     [  English Abstract   The COVID-19 pandemic poses new challenges fo...
# 1     W   Journal Article   INTRODUCTION: Depression is responsible for<b...
# 2     M   Journal Article   OBJECTIVE: To assess the effect of a<br>consu...
# 3     C   Journal Article                                      Not provided.
# 4     P      Case Reports   BACKGROUND: Much remains unknown about the<br...
#
#    abstract_word_count  body_word_count  body_unique_words language  \
# 0                  142              142                103       en
# 1                  231              231                145       en
# 2                  291              291                165       en
# 3                    0                0                  0       en
# 4                  154              154                111       en
#
#                                       processed_text
# 0  the covid-19 pandemic pose new challenge healt...
# 1  introduction depression responsible 800 000 de...
# 2  objective to assess effect consumer base mobil...
# 3
# 4  background much remain unknown transmission sa...

# %%
nlp = en_core_web_lg.load()

tmp = "The COVID-19 pandemic poses new challenges"
for lt in tmp:
    mytokens = nlp(lt)
    mytokens2 = [word.lemma_.lower().strip() for word in mytokens]
    mytokens2 = " ".join([i for i in mytokens2])
    print(mytokens2)
# Out:
# t
# h
# e
#
# c
# o
# v
# i
# d
# -
# 1
# 9
#
# p
# a
# n
# d
# e
# m
# i
# c
#
# p
# o
# s
# e
# s
#
# n
# e
# w
#
# c
# h
# a
# l
# l
# e
# n
# g
# e
# s

# %%
processed_text = df["processed_text"]
body_text = df["body_text"]

for i in range(1,30):
    print(body_text[i])
    print("")
    print(processed_text[i])
    print("")
    print("----------------------------------------------------------")
# Out:
# INTRODUCTION: Depression is responsible for 800 000 deaths worldwide, a number that will rise significantly due to the COVID-19 pandemic. Affordable novel drugs with less severe side effects are urgently required. We investigated the effect of withanone (WN) from Withania somnifera on the serotonin system of wild-type and knockout Caenorhabditis elegans strains using in silico, in vitro, and in vivo methods. METHODS: WN or fluoxetine (as positive control drug) was administered to wild-type (N2) and knockout C. elegans strains (AQ866, DA1814, DA2100, DA2109, and MT9772) to determine their effect on oxidative stress (Trolox, H2DCFDA, and juglone assays) on osmotic stress and heat stress and lifespan. Quantitative real-time RT-PCR was applied to investigate the effect of WN or fluoxetine on the expression of serotonin receptors (ser-1, ser-4, ser-7) and serotonin transporter (mod-5). The binding affinity of WN to serotonin receptors and transporter was analyzed in silico using AutoDock 4.2.6. RESULTS: WN scavenged ROS in wild-type and knockout C. elegans and prolonged their lifespan. WN upregulated the expression of serotonin receptor and transporter genes. In silico analyses revealed high binding affinities of WN to Ser-1, Ser-4, Ser-7, and Mod-5. LIMITATIONS: Further studies are needed to prove whether the results from C. elegans are transferrable to mammals and human beings. CONCLUSION: WN ameliorated depressive-associated stress symptoms by activating the serotonin system. WN may serve as potential candidate in developing new drugs to treat depression.
#
# introduction depression responsible 800 000 death worldwide number rise significantly covid-19 pandemic affordable novel drug severe effect urgently require we investigate effect withanone wn withania somnifera serotonin system wild type knockout caenorhabditis elegan strain silico vitro vivo method method wn fluoxetine positive control drug administer wild type n2 knockout c. elegan strain aq866 da1814 da2100 da2109 mt9772 determine effect oxidative stress trolox h2dcfda juglone assay osmotic stress heat stress lifespan quantitative real time rt pcr apply investigate effect wn fluoxetine expression serotonin receptor ser-1 ser-4 ser-7 serotonin transporter mod-5 the bind affinity wn serotonin receptor transporter analyze silico autodock 4.2.6 result wn scavenge ros wild type knockout c. elegan prolong lifespan wn upregulate expression serotonin receptor transporter gene in silico analysis reveal high bind affinity wn ser-1 ser-4 ser-7 mod-5 limitation further study need prove result c. elegan transferrable mammal human being conclusion wn ameliorate depressive associate stress symptom activate serotonin system wn serve potential candidate develop new drug treat depression
#
# ----------------------------------------------------------
# OBJECTIVE: To assess the effect of a consumer-based mobile meditation application (app) on wellness in outpatient obstetric and gynecology patients during the coronavirus disease 2019 (COVID-19) pandemic. METHODS: We conducted a randomized controlled trial at a university outpatient clinic of obstetric and gynecology patients during the COVID-19 pandemic. Women were randomly assigned to the intervention group, who was prescribed a mobile meditation app for 30 days, or the control group, which received standard care. The primary outcome was self-reported perceived stress. Secondary outcomes included self-reported depression, anxiety, sleep disturbance, and satisfaction with the meditation app. A sample size of 80 participants (40 per group) was calculated to achieve 84% power to detect a 3-point difference in the primary outcome. RESULTS: From April to May 2020, 101 women were randomized in the study-50 in the meditation app group and 51 in the control group. Analysis was by intention-to-treat. Most characteristics were similar between groups. Perceived stress was significantly less in the intervention group at days 14 and 30 (mean difference 4.27, 95% CI 1.30-7.24, P=.005, d=0.69 and mean difference 4.28, 95% CI 1.68-6.88, P=.002, d=0.69, respectively). Self-reported depression and anxiety were significantly less in the intervention group at days 14 and 30 (depression: P=.002 and P=.04; anxiety: P=.01, and P=.04, respectively). Sleep disturbance was significantly less in the intervention group at days 14 and 30 (P=.001 and P=.02, respectively). More than 80% of those in the intervention group reported high satisfaction with the meditation app, and 93% reported that mindfulness meditation improved their stress. CONCLUSION: Outpatient obstetric and gynecology patients who used the prescribed consumer-based mobile meditation app during the COVID-19 pandemic had significant reductions in perceived stress, depression, anxiety, and sleep disturbance compared with standard care. CLINICAL TRIAL REGISTRATION: ClinicalTrials.gov, NCT04329533.
#
# objective to assess effect consumer base mobile meditation application app wellness outpatient obstetric gynecology patient coronavirus disease 2019 covid-19 pandemic method we conduct randomized control trial university outpatient clinic obstetric gynecology patient covid-19 pandemic woman randomly assign intervention group prescribe mobile meditation app 30 day control group receive standard care the primary outcome self report perceive stress secondary outcome include self report depression anxiety sleep disturbance satisfaction meditation app a sample size 80 participant 40 group calculate achieve 84 % power detect 3 point difference primary outcome result from april may 2020 101 woman randomize study-50 meditation app group 51 control group analysis intention treat most characteristic similar group perceive stress significantly intervention group day 14 30 mean difference 4.27 95 % ci 1.30 - 7.24 p=.005 d=0.69 mean difference 4.28 95 % ci 1.68 - 6.88 p=.002 d=0.69 respectively self report depression anxiety significantly intervention group day 14 30 depression p=.002 p=.04 anxiety p=.01 p=.04 respectively sleep disturbance significantly intervention group day 14 30 p=.001 p=.02 respectively more 80 % intervention group report high satisfaction meditation app 93 % report mindfulness meditation improve stress conclusion outpatient obstetric gynecology patient prescribed consumer base mobile meditation app covid-19 pandemic significant reduction perceive stress depression anxiety sleep disturbance compare standard care clinical trial registration clinicaltrials.gov nct04329533
#
# ----------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------
# BACKGROUND: Much remains unknown about the transmission of the SARS-CoV-2 virus. Pregnant women are considered part of the risk population, and vertical transmission of other coronaviruses has been suggested; however, this type of transmission in SARS-CoV-2 is believed to be unlikely. CASE REPORT: A newborn delivered in term via cesarean section to an asymptomatic but COVID-19-positive 35-year-old woman started with respiratory distress in the first 30 min of life. A chest radiograph revealed pneumothorax and ground glass opacities. Ventilatory support with continuous positive airway pressure was needed. Given the respiratory failure and the positive test from the mother, the patient was sampled for SARS-CoV-2 (RT-PCR) at minute 30 of life, with a positive result reported at 36 h of life. No complications had been present during pregnancy, and cardiac screening and blood cultures revealed no other etiologies. CONCLUSION: Vertical transmission was highly likely in this case. Clinicians should be alert and report similar cases.
#
# background much remain unknown transmission sars cov-2 virus pregnant woman consider risk population vertical transmission coronaviruse suggest type transmission sars cov-2 believe unlikely case report a newborn deliver term cesarean section asymptomatic covid-19 positive 35 year old woman start respiratory distress 30 min life a chest radiograph reveal pneumothorax ground glass opacity ventilatory support continuous positive airway pressure need give respiratory failure positive test mother patient sample sars cov-2 rt pcr minute 30 life positive result report 36 h life no complication present pregnancy cardiac screening blood culture reveal etiology conclusion vertical transmission highly likely case clinician alert report similar case
#
# ----------------------------------------------------------
# The coronavirus disease 2019 causes a wide degree of organ dysfunction and is associated with bacterial secondary infections. We reported lung microbiota dynamics in a critically ill patient with coronavirus disease 2019, who developed severe Hafnia alvei ventilator-associated pneumonia and required extracorporeal membrane oxygenation support.
#
# the coronavirus disease 2019 cause wide degree organ dysfunction associate bacterial secondary infection we report lung microbiota dynamic critically ill patient coronavirus disease 2019 develop severe hafnia alvei ventilator associate pneumonia require extracorporeal membrane oxygenation support
#
# ----------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 6
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-c5a90e3ff68d> in <module>
#       3
#       4 for i in range(1,30):
# ----> 5     print(body_text[i])
#       6     print("")
#       7     print(processed_text[i])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 6

# %% [markdown]
# ### Removal of Frequent words
# So this step is to remove the frequent words in the given corpus. If we use something like tfidf, this is automatically taken care of.

# %%
from collections import Counter
cnt = Counter()
for text in df["processed_text"].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(40)
# Out:
# [('%', 476),
#  ('covid-19', 464),
#  ('patient', 312),
#  ('the', 273),
#  ('-', 250),
#  ('pandemic', 179),
#  ('study', 175),
#  ('sars', 157),
#  ('cov-2', 147),
#  ('result', 131),
#  ('care', 116),
#  ('infection', 114),
#  ('disease', 109),
#  ('we', 107),
#  ('health', 106),
#  ('high', 101),
#  ('include', 100),
#  ('risk', 95),
#  ('clinical', 95),
#  ('in', 94),
#  ('vaccine', 93),
#  ('method', 92),
#  ('this', 91),
#  ('participant', 90),
#  ('case', 89),
#  ('/', 89),
#  ('2020', 82),
#  ('time', 81),
#  ('report', 81),
#  ('increase', 81),
#  ('conclusion', 80),
#  ('95', 80),
#  ('group', 79),
#  ('=', 79),
#  ('severe', 75),
#  ('year', 72),
#  ('age', 72),
#  ('a', 71),
#  ('coronavirus', 71),
#  ('analysis', 68)]

# %%
FREQWORDS = set([w for (w, wc) in cnt.most_common(30)])
def remove_freqwords(text):
    """custom function to remove the frequent words"""
    return " ".join([word for word in str(text).split() if word not in FREQWORDS])

df["text_wo_stopfreq"] = df["processed_text"].apply(lambda text: remove_freqwords(text))

# %%
df["body_text"]
# Out:
# 0      The COVID-19 pandemic poses new challenges for...
# 1      INTRODUCTION: Depression is responsible for 80...
# 2      OBJECTIVE: To assess the effect of a consumer-...
# 3
# 4      BACKGROUND: Much remains unknown about the tra...
#                              ...
# 195    DISCLAIMER: In an effort to expedite the publi...
# 196    DISCLAIMER: In an effort to expedite the publi...
# 197    PURPOSE: To explore pharmacy learner (eg, resi...
# 198    PURPOSE: To examine the vaccine-related belief...
# 199    PURPOSE: A collaborative advanced pharmacy pra...
# Name: body_text, Length: 166, dtype: object

# %%
df["text_wo_stopfreq"]
# Out:
# 0      pose new challenge healthcare system world wid...
# 1      introduction depression responsible 800 000 de...
# 2      objective to assess effect consumer base mobil...
# 3
# 4      background much remain unknown transmission vi...
#                              ...
# 195    disclaimer effort expedite publication article...
# 196    disclaimer effort expedite publication article...
# 197    purpose to explore pharmacy learner eg residen...
# 198    purpose to examine relate belief behavior asso...
# 199    purpose a collaborative advanced pharmacy prac...
# Name: text_wo_stopfreq, Length: 166, dtype: object

# %%
df["processed_text"]
# Out:
# 0      the covid-19 pandemic pose new challenge healt...
# 1      introduction depression responsible 800 000 de...
# 2      objective to assess effect consumer base mobil...
# 3
# 4      background much remain unknown transmission sa...
#                              ...
# 195    disclaimer in effort expedite publication arti...
# 196    disclaimer in effort expedite publication arti...
# 197    purpose to explore pharmacy learner eg residen...
# 198    purpose to examine vaccine relate belief behav...
# 199    purpose a collaborative advanced pharmacy prac...
# Name: processed_text, Length: 166, dtype: object

# %% [markdown]
# ### Removal of Rare words
# This is very similar to previous preprocessing step but we will remove the rare words from the corpus.

# %%
#cnt.most_common()[:-500-1:-1]

# %%
# n_rare_words = 10
# RAREWORDS = set([w for (w, wc) in cnt.most_common()[:-n_rare_words-1:-1]])
# def remove_rarewords(text):
#     """custom function to remove the rare words"""
#     return " ".join([word for word in str(text).split() if word not in RAREWORDS])

# df["text_wo_stopfreqrare"] = df["text_wo_stopfreq"].apply(lambda text: remove_rarewords(text))
# df.head()

# %% [markdown]
# ### Lemmatization

# %% [markdown]
# Lemmatization is similar to stemming in reducing inflected words to their word stem but differs in the way that it makes sure the root word (also called as lemma) belongs to the language.

# %%
import nltk
#nltk.download('wordnet')

# %% [markdown]
# Now let us redo the lemmatization process for our dataset.

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Seyf_GOUMEIDA\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}
def lemmatize_words(text):
    pos_tagged_text = nltk.pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word) for word, pos in pos_tagged_text])

df["text_lemmatized"] = df["text_wo_stopfreq"].apply(lambda text: lemmatize_words(text))

# %%
df.head()
# Out:
#    paper_id                                           abstract  \
# 0  33957689  The COVID-19 pandemic poses new challenges for...
# 1  33957677  INTRODUCTION: Depression is responsible for 80...
# 2  33957663  OBJECTIVE: To assess the effect of a consumer-...
# 3  33957662
# 4  33957638  BACKGROUND: Much remains unknown about the tra...
#
#                                            body_text              authors  \
# 0  The COVID-19 pandemic poses new challenges for...             Berlit P
# 1  INTRODUCTION: Depression is responsible for 80...               Nass J
# 2  OBJECTIVE: To assess the effect of a consumer-...             Smith RB
# 3                                                                 Toma HV
# 4  BACKGROUND: Much remains unknown about the tra...  Mendoza-Hernandez M
#
#   title           journal                                   abstract_summary  \
# 0     [  English Abstract   The COVID-19 pandemic poses new challenges fo...
# 1     W   Journal Article   INTRODUCTION: Depression is responsible for<b...
# 2     M   Journal Article   OBJECTIVE: To assess the effect of a<br>consu...
# 3     C   Journal Article                                      Not provided.
# 4     P      Case Reports   BACKGROUND: Much remains unknown about the<br...
#
#    abstract_word_count  body_word_count  body_unique_words language  \
# 0                  142              142                103       en
# 1                  231              231                145       en
# 2                  291              291                165       en
# 3                    0                0                  0       en
# 4                  154              154                111       en
#
#                                       processed_text  \
# 0  the covid-19 pandemic pose new challenge healt...
# 1  introduction depression responsible 800 000 de...
# 2  objective to assess effect consumer base mobil...
# 3
# 4  background much remain unknown transmission sa...
#
#                                     text_wo_stopfreq  \
# 0  pose new challenge healthcare system world wid...
# 1  introduction depression responsible 800 000 de...
# 2  objective to assess effect consumer base mobil...
# 3
# 4  background much remain unknown transmission vi...
#
#                                      text_lemmatized
# 0  pose new challenge healthcare system world wid...
# 1  introduction depression responsible 800 000 de...
# 2  objective to ass effect consumer base mobile m...
# 3
# 4  background much remain unknown transmission vi...

# %%
processed_text = df["processed_text"]
body_text = df["body_text"]
text_lemmatized = df["text_lemmatized"]

for i in range(1,30):
    print(body_text[i])
    print("")
    print(processed_text[i])
    print("")
    print(text_lemmatized[i])
    print("----------------------------------------------------------")
# Out:
# INTRODUCTION: Depression is responsible for 800 000 deaths worldwide, a number that will rise significantly due to the COVID-19 pandemic. Affordable novel drugs with less severe side effects are urgently required. We investigated the effect of withanone (WN) from Withania somnifera on the serotonin system of wild-type and knockout Caenorhabditis elegans strains using in silico, in vitro, and in vivo methods. METHODS: WN or fluoxetine (as positive control drug) was administered to wild-type (N2) and knockout C. elegans strains (AQ866, DA1814, DA2100, DA2109, and MT9772) to determine their effect on oxidative stress (Trolox, H2DCFDA, and juglone assays) on osmotic stress and heat stress and lifespan. Quantitative real-time RT-PCR was applied to investigate the effect of WN or fluoxetine on the expression of serotonin receptors (ser-1, ser-4, ser-7) and serotonin transporter (mod-5). The binding affinity of WN to serotonin receptors and transporter was analyzed in silico using AutoDock 4.2.6. RESULTS: WN scavenged ROS in wild-type and knockout C. elegans and prolonged their lifespan. WN upregulated the expression of serotonin receptor and transporter genes. In silico analyses revealed high binding affinities of WN to Ser-1, Ser-4, Ser-7, and Mod-5. LIMITATIONS: Further studies are needed to prove whether the results from C. elegans are transferrable to mammals and human beings. CONCLUSION: WN ameliorated depressive-associated stress symptoms by activating the serotonin system. WN may serve as potential candidate in developing new drugs to treat depression.
#
# introduction depression responsible 800 000 death worldwide number rise significantly covid-19 pandemic affordable novel drug severe effect urgently require we investigate effect withanone wn withania somnifera serotonin system wild type knockout caenorhabditis elegan strain silico vitro vivo method method wn fluoxetine positive control drug administer wild type n2 knockout c. elegan strain aq866 da1814 da2100 da2109 mt9772 determine effect oxidative stress trolox h2dcfda juglone assay osmotic stress heat stress lifespan quantitative real time rt pcr apply investigate effect wn fluoxetine expression serotonin receptor ser-1 ser-4 ser-7 serotonin transporter mod-5 the bind affinity wn serotonin receptor transporter analyze silico autodock 4.2.6 result wn scavenge ros wild type knockout c. elegan prolong lifespan wn upregulate expression serotonin receptor transporter gene in silico analysis reveal high bind affinity wn ser-1 ser-4 ser-7 mod-5 limitation further study need prove result c. elegan transferrable mammal human being conclusion wn ameliorate depressive associate stress symptom activate serotonin system wn serve potential candidate develop new drug treat depression
#
# introduction depression responsible 800 000 death worldwide number rise significantly affordable novel drug severe effect urgently require investigate effect withanone wn withania somnifera serotonin system wild type knockout caenorhabditis elegan strain silico vitro vivo wn fluoxetine positive control drug administer wild type n2 knockout c. elegan strain aq866 da1814 da2100 da2109 mt9772 determine effect oxidative stress trolox h2dcfda juglone assay osmotic stress heat stress lifespan quantitative real rt pcr apply investigate effect wn fluoxetine expression serotonin receptor ser-1 ser-4 ser-7 serotonin transporter mod-5 bind affinity wn serotonin receptor transporter analyze silico autodock 4.2.6 wn scavenge ro wild type knockout c. elegan prolong lifespan wn upregulate expression serotonin receptor transporter gene silico analysis reveal bind affinity wn ser-1 ser-4 ser-7 mod-5 limitation further need prove c. elegan transferrable mammal human being conclusion wn ameliorate depressive associate stress symptom activate serotonin system wn serve potential candidate develop new drug treat depression
# ----------------------------------------------------------
# OBJECTIVE: To assess the effect of a consumer-based mobile meditation application (app) on wellness in outpatient obstetric and gynecology patients during the coronavirus disease 2019 (COVID-19) pandemic. METHODS: We conducted a randomized controlled trial at a university outpatient clinic of obstetric and gynecology patients during the COVID-19 pandemic. Women were randomly assigned to the intervention group, who was prescribed a mobile meditation app for 30 days, or the control group, which received standard care. The primary outcome was self-reported perceived stress. Secondary outcomes included self-reported depression, anxiety, sleep disturbance, and satisfaction with the meditation app. A sample size of 80 participants (40 per group) was calculated to achieve 84% power to detect a 3-point difference in the primary outcome. RESULTS: From April to May 2020, 101 women were randomized in the study-50 in the meditation app group and 51 in the control group. Analysis was by intention-to-treat. Most characteristics were similar between groups. Perceived stress was significantly less in the intervention group at days 14 and 30 (mean difference 4.27, 95% CI 1.30-7.24, P=.005, d=0.69 and mean difference 4.28, 95% CI 1.68-6.88, P=.002, d=0.69, respectively). Self-reported depression and anxiety were significantly less in the intervention group at days 14 and 30 (depression: P=.002 and P=.04; anxiety: P=.01, and P=.04, respectively). Sleep disturbance was significantly less in the intervention group at days 14 and 30 (P=.001 and P=.02, respectively). More than 80% of those in the intervention group reported high satisfaction with the meditation app, and 93% reported that mindfulness meditation improved their stress. CONCLUSION: Outpatient obstetric and gynecology patients who used the prescribed consumer-based mobile meditation app during the COVID-19 pandemic had significant reductions in perceived stress, depression, anxiety, and sleep disturbance compared with standard care. CLINICAL TRIAL REGISTRATION: ClinicalTrials.gov, NCT04329533.
#
# objective to assess effect consumer base mobile meditation application app wellness outpatient obstetric gynecology patient coronavirus disease 2019 covid-19 pandemic method we conduct randomized control trial university outpatient clinic obstetric gynecology patient covid-19 pandemic woman randomly assign intervention group prescribe mobile meditation app 30 day control group receive standard care the primary outcome self report perceive stress secondary outcome include self report depression anxiety sleep disturbance satisfaction meditation app a sample size 80 participant 40 group calculate achieve 84 % power detect 3 point difference primary outcome result from april may 2020 101 woman randomize study-50 meditation app group 51 control group analysis intention treat most characteristic similar group perceive stress significantly intervention group day 14 30 mean difference 4.27 95 % ci 1.30 - 7.24 p=.005 d=0.69 mean difference 4.28 95 % ci 1.68 - 6.88 p=.002 d=0.69 respectively self report depression anxiety significantly intervention group day 14 30 depression p=.002 p=.04 anxiety p=.01 p=.04 respectively sleep disturbance significantly intervention group day 14 30 p=.001 p=.02 respectively more 80 % intervention group report high satisfaction meditation app 93 % report mindfulness meditation improve stress conclusion outpatient obstetric gynecology patient prescribed consumer base mobile meditation app covid-19 pandemic significant reduction perceive stress depression anxiety sleep disturbance compare standard care clinical trial registration clinicaltrials.gov nct04329533
#
# objective to ass effect consumer base mobile meditation application app wellness outpatient obstetric gynecology coronavirus 2019 conduct randomized control trial university outpatient clinic obstetric gynecology woman randomly assign intervention group prescribe mobile meditation app 30 day control group receive standard primary outcome self perceive stress secondary outcome self depression anxiety sleep disturbance satisfaction meditation app a sample size 80 40 group calculate achieve 84 power detect 3 point difference primary outcome from april may 101 woman randomize study-50 meditation app group 51 control group analysis intention treat most characteristic similar group perceive stress significantly intervention group day 14 30 mean difference 4.27 95 ci 1.30 7.24 p=.005 d=0.69 mean difference 4.28 95 ci 1.68 6.88 p=.002 d=0.69 respectively self depression anxiety significantly intervention group day 14 30 depression p=.002 p=.04 anxiety p=.01 p=.04 respectively sleep disturbance significantly intervention group day 14 30 p=.001 p=.02 respectively more 80 intervention group satisfaction meditation app 93 mindfulness meditation improve stress conclusion outpatient obstetric gynecology prescribed consumer base mobile meditation app significant reduction perceive stress depression anxiety sleep disturbance compare standard trial registration clinicaltrials.gov nct04329533
# ----------------------------------------------------------
#
#
#
#
#
# ----------------------------------------------------------
# BACKGROUND: Much remains unknown about the transmission of the SARS-CoV-2 virus. Pregnant women are considered part of the risk population, and vertical transmission of other coronaviruses has been suggested; however, this type of transmission in SARS-CoV-2 is believed to be unlikely. CASE REPORT: A newborn delivered in term via cesarean section to an asymptomatic but COVID-19-positive 35-year-old woman started with respiratory distress in the first 30 min of life. A chest radiograph revealed pneumothorax and ground glass opacities. Ventilatory support with continuous positive airway pressure was needed. Given the respiratory failure and the positive test from the mother, the patient was sampled for SARS-CoV-2 (RT-PCR) at minute 30 of life, with a positive result reported at 36 h of life. No complications had been present during pregnancy, and cardiac screening and blood cultures revealed no other etiologies. CONCLUSION: Vertical transmission was highly likely in this case. Clinicians should be alert and report similar cases.
#
# background much remain unknown transmission sars cov-2 virus pregnant woman consider risk population vertical transmission coronaviruse suggest type transmission sars cov-2 believe unlikely case report a newborn deliver term cesarean section asymptomatic covid-19 positive 35 year old woman start respiratory distress 30 min life a chest radiograph reveal pneumothorax ground glass opacity ventilatory support continuous positive airway pressure need give respiratory failure positive test mother patient sample sars cov-2 rt pcr minute 30 life positive result report 36 h life no complication present pregnancy cardiac screening blood culture reveal etiology conclusion vertical transmission highly likely case clinician alert report similar case
#
# background much remain unknown transmission virus pregnant woman consider population vertical transmission coronaviruse suggest type transmission believe unlikely a newborn deliver term cesarean section asymptomatic positive 35 year old woman start respiratory distress 30 min life a chest radiograph reveal pneumothorax ground glass opacity ventilatory support continuous positive airway pressure need give respiratory failure positive test mother sample rt pcr minute 30 life positive 36 h life no complication present pregnancy cardiac screening blood culture reveal etiology conclusion vertical transmission highly likely clinician alert similar
# ----------------------------------------------------------
# The coronavirus disease 2019 causes a wide degree of organ dysfunction and is associated with bacterial secondary infections. We reported lung microbiota dynamics in a critically ill patient with coronavirus disease 2019, who developed severe Hafnia alvei ventilator-associated pneumonia and required extracorporeal membrane oxygenation support.
#
# the coronavirus disease 2019 cause wide degree organ dysfunction associate bacterial secondary infection we report lung microbiota dynamic critically ill patient coronavirus disease 2019 develop severe hafnia alvei ventilator associate pneumonia require extracorporeal membrane oxygenation support
#
# coronavirus 2019 cause wide degree organ dysfunction associate bacterial secondary lung microbiota dynamic critically ill coronavirus 2019 develop severe hafnia alvei ventilator associate pneumonia require extracorporeal membrane oxygenation support
# ----------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 6
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-126-d03614168f44> in <module>
#       4
#       5 for i in range(1,30):
# ----> 6     print(body_text[i])
#       7     print("")
#       8     print(processed_text[i])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 6

# %% [markdown]
# ### Removal of URLs

# %%
import re
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

# %%
df["text_lemmatized_no_url"] = df["text_lemmatized"].apply(lambda text: remove_urls(text))
df.head()
# Out:
#    paper_id                                           abstract  \
# 0  33957689  The COVID-19 pandemic poses new challenges for...
# 1  33957677  INTRODUCTION: Depression is responsible for 80...
# 2  33957663  OBJECTIVE: To assess the effect of a consumer-...
# 3  33957662
# 4  33957638  BACKGROUND: Much remains unknown about the tra...
#
#                                            body_text              authors  \
# 0  The COVID-19 pandemic poses new challenges for...             Berlit P
# 1  INTRODUCTION: Depression is responsible for 80...               Nass J
# 2  OBJECTIVE: To assess the effect of a consumer-...             Smith RB
# 3                                                                 Toma HV
# 4  BACKGROUND: Much remains unknown about the tra...  Mendoza-Hernandez M
#
#   title           journal                                   abstract_summary  \
# 0     [  English Abstract   The COVID-19 pandemic poses new challenges fo...
# 1     W   Journal Article   INTRODUCTION: Depression is responsible for<b...
# 2     M   Journal Article   OBJECTIVE: To assess the effect of a<br>consu...
# 3     C   Journal Article                                      Not provided.
# 4     P      Case Reports   BACKGROUND: Much remains unknown about the<br...
#
#    abstract_word_count  body_word_count  body_unique_words language  \
# 0                  142              142                103       en
# 1                  231              231                145       en
# 2                  291              291                165       en
# 3                    0                0                  0       en
# 4                  154              154                111       en
#
#                                       processed_text  \
# 0  the covid-19 pandemic pose new challenge healt...
# 1  introduction depression responsible 800 000 de...
# 2  objective to assess effect consumer base mobil...
# 3
# 4  background much remain unknown transmission sa...
#
#                                     text_wo_stopfreq  \
# 0  pose new challenge healthcare system world wid...
# 1  introduction depression responsible 800 000 de...
# 2  objective to assess effect consumer base mobil...
# 3
# 4  background much remain unknown transmission vi...
#
#                                      text_lemmatized  \
# 0  pose new challenge healthcare system world wid...
# 1  introduction depression responsible 800 000 de...
# 2  objective to ass effect consumer base mobile m...
# 3
# 4  background much remain unknown transmission vi...
#
#                               text_lemmatized_no_url
# 0  pose new challenge healthcare system world wid...
# 1  introduction depression responsible 800 000 de...
# 2  objective to ass effect consumer base mobile m...
# 3
# 4  background much remain unknown transmission vi...

# %% [markdown]
# ### Removal of HTML Tags

# %%
def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

# %%
df["text_lemmatized_url_html"] = df["text_lemmatized_no_url"].apply(lambda text: remove_html(text))
df.head()
# Out:
#    paper_id                                           abstract  \
# 0  33957689  The COVID-19 pandemic poses new challenges for...
# 1  33957677  INTRODUCTION: Depression is responsible for 80...
# 2  33957663  OBJECTIVE: To assess the effect of a consumer-...
# 3  33957662
# 4  33957638  BACKGROUND: Much remains unknown about the tra...
#
#                                            body_text              authors  \
# 0  The COVID-19 pandemic poses new challenges for...             Berlit P
# 1  INTRODUCTION: Depression is responsible for 80...               Nass J
# 2  OBJECTIVE: To assess the effect of a consumer-...             Smith RB
# 3                                                                 Toma HV
# 4  BACKGROUND: Much remains unknown about the tra...  Mendoza-Hernandez M
#
#   title           journal                                   abstract_summary  \
# 0     [  English Abstract   The COVID-19 pandemic poses new challenges fo...
# 1     W   Journal Article   INTRODUCTION: Depression is responsible for<b...
# 2     M   Journal Article   OBJECTIVE: To assess the effect of a<br>consu...
# 3     C   Journal Article                                      Not provided.
# 4     P      Case Reports   BACKGROUND: Much remains unknown about the<br...
#
#    abstract_word_count  body_word_count  body_unique_words language  \
# 0                  142              142                103       en
# 1                  231              231                145       en
# 2                  291              291                165       en
# 3                    0                0                  0       en
# 4                  154              154                111       en
#
#                                       processed_text  \
# 0  the covid-19 pandemic pose new challenge healt...
# 1  introduction depression responsible 800 000 de...
# 2  objective to assess effect consumer base mobil...
# 3
# 4  background much remain unknown transmission sa...
#
#                                     text_wo_stopfreq  \
# 0  pose new challenge healthcare system world wid...
# 1  introduction depression responsible 800 000 de...
# 2  objective to assess effect consumer base mobil...
# 3
# 4  background much remain unknown transmission vi...
#
#                                      text_lemmatized  \
# 0  pose new challenge healthcare system world wid...
# 1  introduction depression responsible 800 000 de...
# 2  objective to ass effect consumer base mobile m...
# 3
# 4  background much remain unknown transmission vi...
#
#                               text_lemmatized_no_url  \
# 0  pose new challenge healthcare system world wid...
# 1  introduction depression responsible 800 000 de...
# 2  objective to ass effect consumer base mobile m...
# 3
# 4  background much remain unknown transmission vi...
#
#                             text_lemmatized_url_html
# 0  pose new challenge healthcare system world wid...
# 1  introduction depression responsible 800 000 de...
# 2  objective to ass effect consumer base mobile m...
# 3
# 4  background much remain unknown transmission vi...

# %% [markdown]
# ### Let's take a look at word count in the papers

# %%
import seaborn as sns

# %%
sns.distplot(df['body_word_count'])
df['body_word_count'].describe()
# Out:
# C:\Users\Seyf_GOUMEIDA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count    166.000000
# mean     216.951807
# std       78.447652
# min        0.000000
# 25%      172.500000
# 50%      221.500000
# 75%      253.000000
# max      472.000000
# Name: body_word_count, dtype: float64

# %%
sns.distplot(df['body_unique_words'])
df['body_unique_words'].describe()
# Out:
# C:\Users\Seyf_GOUMEIDA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count    166.000000
# mean     138.572289
# std       43.787132
# min        0.000000
# 25%      111.000000
# 50%      140.500000
# 75%      165.000000
# max      279.000000
# Name: body_unique_words, dtype: float64

# %% [markdown]
# These two plots give us a good idea of the content we are dealing with. Most papers are about 5000 words in length. The long tails in both plots are caused by outliers. In fact, ~98% of the papers are under 20,000 words in length while a select few are over 200,000! <br><br>

# %% [markdown]
# # Vectorization
#
# Now that we have pre-processed the data, it is time to convert it into a format that can be handled by our algorithms. For this purpose we will be using tf-idf. This will convert our string formatted data into a measure of how important each word is to the instance out of the literature as a whole.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
def vectorize(text, maxx_features):
    
    global vectorizer 
    X = vectorizer.fit_transform(text)
    return X

# %% [markdown]
# Vectorize our data. We will be clustering based off the content of the body text. The maximum number of features will be limited. Only the top 2 ** 12 features will be used, eseentially acting as a noise filter. Additionally, more features cause painfully long runtimes.

# %%
text = df['text_lemmatized_url_html'].values
vectorizer = TfidfVectorizer(max_features= 2 ** 12)
X = vectorize(text, 2 ** 12)
X.shape
print(X)
# Out:
#   (0, 1026)	0.09742698702132963
#   (0, 4087)	0.046262078850385406
#   (0, 625)	0.10335043964707637
#   (0, 1673)	0.08590434475097743
#   (0, 3189)	0.11169907722050237
#   (0, 452)	0.09742698702132963
#   (0, 2523)	0.05162137909703472
#   (0, 4069)	0.07659784732061345
#   (0, 3482)	0.05663762447134744
#   (0, 2540)	0.11169907722050237
#   (0, 3028)	0.11169907722050237
#   (0, 2898)	0.09742698702132963
#   (0, 1805)	0.07856031001427662
#   (0, 673)	0.10335043964707637
#   (0, 1718)	0.09742698702132963
#   (0, 1614)	0.07021167244085061
#   (0, 3576)	0.07163225455180468
#   (0, 3511)	0.07021167244085061
#   (0, 3886)	0.06534436278826068
#   (0, 1547)	0.11169907722050237
#   (0, 2337)	0.08072971187447765
#   (0, 2748)	0.11169907722050237
#   (0, 3421)	0.09742698702132963
#   (0, 2357)	0.11169907722050237
#   (0, 693)	0.11169907722050237
#   :	:
#   (165, 1318)	0.044016293866592476
#   (165, 1879)	0.038300221997213085
#   (165, 1139)	0.04904454308653962
#   (165, 1031)	0.04550162088401453
#   (165, 2273)	0.0500892852516574
#   (165, 2897)	0.04807191140009357
#   (165, 493)	0.06355967267235345
#   (165, 316)	0.058816232489420105
#   (165, 2776)	0.04630741550090107
#   (165, 4033)	0.04473940456409363
#   (165, 896)	0.04204599040213913
#   (165, 215)	0.055273310286895014
#   (165, 1293)	0.058816232489420105
#   (165, 3819)	0.04904454308653962
#   (165, 3908)	0.05378798326947297
#   (165, 137)	0.030819654228641184
#   (165, 1171)	0.029501164280778643
#   (165, 1081)	0.02412480927962665
#   (165, 2873)	0.03978554901463514
#   (165, 1614)	0.04807191140009357
#   (165, 2163)	0.04332847121716023
#   (165, 4049)	0.05693376462277331
#   (165, 3692)	0.03877815142193187
#   (165, 1859)	0.1261379712064174
#   (165, 925)	0.08947880912818726

# %% [markdown]
# # PCA  & Clustering
#
# Let's see how much we can reduce the dimensions while still keeping 95% variance. We will apply Principle Component Analysis (PCA) to our vectorized data. The reason for this is that by keeping a large number of dimensions with PCA, you don’t destroy much of the information, but hopefully will remove some noise/outliers from the data, and make the clustering problem easier for k-means. Note that X_reduced will only be used for k-means, t-SNE will still use the original feature vector X that was generated through tf-idf on the NLP processed text.
#
# (Thank you Dr. Edward Raff for the suggestion)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.95, random_state=42)
X_reduced= pca.fit_transform(X.toarray())
X_reduced.shape
# Out:
# (166, 149)

# %% [markdown]
# To separate the literature, k-means will be run on the vectorized text. Given the number of clusters, k, k-means will categorize each vector by taking the mean distance to a randomly initialized centroid. The centroids are updated iteratively.

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ### How many clusters?
#
# To find the best k value for k-means we'll look at the distortion at different k values. Distortion computes the sum of squared distances from each point to its assigned center. When distortion is plotted against k there will be a k value after which decreases in distortion are minimal. This is the desired number of clusters.

# %%
from sklearn import metrics
from scipy.spatial.distance import cdist

# run kmeans with many different k
distortions = []
K = range(2, 10)
for k in K:
    k_means = KMeans(n_clusters=k, random_state=42).fit(X_reduced)
    k_means.fit(X_reduced)
    distortions.append(sum(np.min(cdist(X_reduced, k_means.cluster_centers_, 'euclidean'), axis=1)) / X.shape[0])
    #print('Found distortion for {} clusters'.format(k))

# %%
X_line = [K[0], K[-1]]
Y_line = [distortions[0], distortions[-1]]

# Plot the elbow
plt.plot(K, distortions, 'b-')
plt.plot(X_line, Y_line, 'r')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# In this plot we can see that the better k values are between 18-25. After that, the decrease in distortion is not as significant. For simplicity, we will use k=20

# %% [markdown]
# ### Run k-means

# %% [markdown]
# Now that we have an appropriate k value, we can run k-means on the PCA-processed feature vector (X_reduced).

# %%
k = 5
kmeans = KMeans(n_clusters=k, random_state=42)
y_pred = kmeans.fit_predict(X_reduced)
df['y'] = y_pred
df['y']
# Out:
# 0      3
# 1      0
# 2      3
# 3      0
# 4      0
#       ..
# 195    2
# 196    2
# 197    1
# 198    2
# 199    0
# Name: y, Length: 166, dtype: int32

# %% [markdown]
# # Dimensionality Reduction with t-SNE

# %%
from sklearn.manifold import TSNE

tsne = TSNE(verbose=1, perplexity=100, random_state=42)
X_embedded = tsne.fit_transform(X.toarray())
# Out:
# [t-SNE] Computing 165 nearest neighbors...
# [t-SNE] Indexed 166 samples in 0.003s...
# [t-SNE] Computed neighbors for 166 samples in 0.017s...
# [t-SNE] Computed conditional probabilities for sample 166 / 166
# [t-SNE] Mean sigma: 0.477598
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.451958
# [t-SNE] KL divergence after 1000 iterations: 1.132487

# %% [markdown]
# So that step took a while! Let's take a look at what our data looks like when compressed to 2 dimensions.

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# sns settings
sns.set(rc={'figure.figsize':(15,15)})

# colors
palette = sns.color_palette("bright", 1)

# plot
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], palette=palette)
plt.title('t-SNE with no Labels')
plt.savefig("t-sne_covid19.png")
plt.show()
# Out:
# C:\Users\Seyf_GOUMEIDA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# This looks pretty bland. There are some clusters we can immediately detect, but the many instances closer to the center are harder to separate. t-SNE did a good job at reducing the dimensionality, but now we need some labels. Let's use the clusters found by k-means as labels. This will help visually separate different concentrations of topics.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# sns settings
sns.set(rc={'figure.figsize':(15,15)})

# colors
palette = sns.hls_palette(5, l=.4, s=.9)

# plot
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y_pred, legend='full', palette=palette)
plt.title('t-SNE with Kmeans Labels')
plt.savefig("improved_cluster_tsne.png")
plt.show()
# Out:
# C:\Users\Seyf_GOUMEIDA\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The labeled plot gives better insight into how the papers are grouped. It is interesting that both k-means and t-SNE are able to agree on certain clusters even though they were ran independetly. The location of each paper on the plot was determined by t-SNE while the label (color) was determined by k-means. If we look at a particular part of the plot where t-SNE has grouped many articles forming a cluster, it is likely that k-means is uniform in the labeling of this cluster (most of the cluster is the same color). This behavior shows that structure within the literature can be observed and measured to some extent.
#
# Now there are other cases where the colored labels (k-means) are spread out on the plot (t-SNE). This is a result of t-SNE and k-means finding different connections in the higher dimensional data. The topics of these papers often intersect so it hard to cleanly separate them. This effect can be observed in the formation of subclusters on the plot. These subclusters are a conglomeration of different k-means labels but may share some connection determined by t-SNE.
#
# This organization of the data does not act as a simple search engine. The clustering + dimensionality reduction is performed on the mathematical similarities of the publications. As an unsupervised approach, the algorithms may even find connections that were unnaparent to humans. This may highlight hidden shared information and advance further research.

# %% [markdown]
# # NMF

# %%
import en_ner_bc5cdr_md
nlp = spacy.load("en_ner_bc5cdr_md")

# %%
from sklearn.decomposition import NMF, LatentDirichletAllocation
nmf = NMF(n_components=20, random_state=1,
          alpha=.1, l1_ratio=.5).fit(X)

# %%
def plot_top_words(model, feature_names, n_top_words, title):
    fig, axes = plt.subplots(5, 4, figsize=(30, 60), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f'Topic {topic_idx +1}',
                     fontdict={'fontsize': 30})
        ax.invert_yaxis()
        ax.tick_params(axis='both', which='major', labelsize=20)
        for i in 'top right left'.split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()

# %%
#vectorizer = TfidfVectorizer(max_features= 2 ** 12)

# %%
tfidf_feature_names = vectorizer.get_feature_names()
plot_top_words(nmf, tfidf_feature_names, 40,
               'Topics in NMF model')

# %%
all_keywords = []
for topic_idx, topic in enumerate(nmf.components_):
    #top words = 100
    top_features_ind = topic.argsort()[:-40 - 1:-1]
    top_features = [tfidf_feature_names[i] for i in top_features_ind]
    all_keywords.append(top_features)

# %%
for num_clus in range(0,20):
    print("*************Cluster ",num_clus,"*********************")
    str1 = ','.join(all_keywords[num_clus])
    doc = nlp(str1)
    print(str1)
    print("-------------------------------------------")
    TERM_LIST = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
    print("TERM_LIST : " ,TERM_LIST )
    print("")
# Out:
# *************Cluster  0 *********************
# zn,zika,disability,director,directly,direct,dimer,dimension,dilemma,digital,digestive,difficulty,difficult,difficile,differently,differentiate,differential,different,difference,differ,dietary,die,dichotomy,diarrhea,diagnostic,diagnosis,diagnose,diabetic,diabetes,diabete,dhl,disaster,discharge,discipline,disorder,distance,dissociation,dissemination,disseminate,disruption
# -------------------------------------------
# TERM_LIST :  ['diarrhea', 'diabetic', 'diabetes', 'diabete', 'disorder']
#
# *************Cluster  1 *********************
# ci,95,or,mortality,associate,aor,severe,co,superinfection,age,icu,hospital,pneumonia,ischemic,acei,stroke,adult,resident,vaccination,severity,hba1c,irr,non,year,001,65,admission,model,predictor,group,acute,outcome,association,condition,rr,identify,odd,cohort,imv,60
# -------------------------------------------
# TERM_LIST :  ['pneumonia', 'stroke']
#
# *************Cluster  2 *********************
# influenza,virus,rhinovirus,hesitancy,facility,emerge,seasonal,angeles,respondent,notably,follow,los,replace,anticipate,cdc,specifically,county,globally,circulate,suspect,pathway,strain,address,vaccination,diagnostic,lipid,year,highly,previous,challenge,potential,examine,99,later,reduction,guideline,use,involve,month,isolation
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  3 *********************
# receptor,protein,antigen,coronavirus,cov,cell,spike,host,immune,structure,human,coronaviruse,syndrome,interaction,evolutionary,tropism,viral,process,mechanism,antibody,molecular,advance,animal,range,response,respiratory,acute,emergence,field,microbial,evolution,carbohydrate,recombination,membrane,molecule,entry,structural,review,specificity,mutation
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  4 *********************
# 0246312,doi,pone,1371,journal,correct,article,10,dilemma,difficile,digestive,dimension,dimer,difficulty,direct,directly,difficult,director,digital,zn,differently,disaster,differentiate,differential,different,difference,differ,dietary,die,dichotomy,diarrhea,diagnostic,diagnosis,diagnose,disability,disclaimer,discharge,dislodge,dissociation,dissemination
# -------------------------------------------
# TERM_LIST :  ['difficile', 'diarrhea']
#
# *************Cluster  5 *********************
# 0238091,doi,pone,1371,journal,correct,article,10,dilemma,difficile,digestive,dimension,difficulty,dimer,direct,directly,difficult,director,digital,zn,differently,disaster,differentiate,differential,different,difference,differ,dietary,die,dichotomy,diarrhea,diagnostic,diagnosis,diagnose,disability,disclaimer,discharge,dislodge,dissociation,dissemination
# -------------------------------------------
# TERM_LIST :  ['difficile', 'diarrhea']
#
# *************Cluster  6 *********************
# woman,pregnant,pregnancy,anxiety,depression,asymptomatic,mental,testing,disorder,symptomatic,stress,obstetric,period,support,positive,fold,hospitalisation,trimester,screening,antenatal,complication,social,infect,compare,mother,newborn,characteristic,short,transmission,significantly,pneumonia,chest,frequency,moderate,pre,30,group,scale,outcome,relate
# -------------------------------------------
# TERM_LIST :  ['anxiety', 'depression', 'disorder', 'pneumonia']
#
# *************Cluster  7 *********************
# lockdown,sleep,partial,1st,air,bt,caregiver,quality,period,pm2,march,no2,phase,total,exposure,pm10,score,2nd,decline,iraq,24,technology,august,change,therapy,21,pollutant,activity,overall,burden,april,population,iraqi,o3,witness,aqi,ed,foot,spread,likely
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  8 *********************
# model,particle,rate,class,different,approach,specific,population,quarantine,ordinary,collision,arbitrary,yield,applicability,equation,tune,cyprus,velocity,simulation,datum,both,prediction,transmit,recover,transition,varied,crowd,adjust,infectious,lift,susceptible,differential,incorporate,restriction,subgroup,set,allow,parameter,impose,derive
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  9 *********************
# dose,antibody,second,symptomatic,expose,vaccinate,igg,response,worker,individual,titer,exposure,receive,day,vaccination,asymptomatic,reach,bnt162b2,unvaccinated,subject,symptom,fully,transplant,show,biontech,pfizer,multivariate,test,partially,nct04387929funding,naive,lr,voluntarily,clincaltrials,philantropic,corrente,exp,unexposed,donation,plateau
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  10 *********************
# opioid,misuse,adolescent,overdose,use,rise,initiate,adult,epidemic,disorder,constantly,reliever,lock,resurgence,2015,recession,synthetic,prescription,analog,norther,recent,europe,fentanyl,north,addiction,young,crisis,move,america,abstract,mainly,mediterranean,eastern,decade,death,pain,finally,generate,activation,economic
# -------------------------------------------
# TERM_LIST :  ['overdose', 'disorder', 'death', 'pain']
#
# *************Cluster  11 *********************
# palliative,team,spiritual,telehealth,psychological,session,87,die,carry,our,delivery,implementation,support,accentuate,psychosocially,corona,medically,love,population,psychiatric,gather,delineate,veteran,involvement,disease,advanced,satisfaction,institutional,chart,share,they,emphasize,complex,participate,hospital,criterion,recommendation,facility,course,75
# -------------------------------------------
# TERM_LIST :  ['psychiatric', 'veteran']
#
# *************Cluster  12 *********************
# inpatient,postoperative,surgical,outcome,stay,length,90,surgery,2019,ncepod,district,mortality,day,uk,difference,general,significant,undergo,statistically,hospital,intervention,appropriately,027,theatre,nonelective,list,141,enquiry,250,132,196,acute,confidential,elucidate,versus,centre,fast,compare,prioritise,discharge
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  13 *********************
# ra,hospitalization,death,va,non,hr,match,multivariable,associate,chronic,national,10,condition,arthritis,affair,rheumatoid,prednisone,predominant,cox,dmard,886,228,autoantibody,deceased,503,ace2,age,hazard,seropositivity,prioritize,388,while,veteran,hispanic,related,ethnicity,surveillance,recognize,unclear,county
# -------------------------------------------
# TERM_LIST :  ['death', 'arthritis']
#
# *************Cluster  14 *********************
# productivity,output,pharmacist,model,manuscript,work,final,ajhp,replace,project,2018,consensus,july,post,validate,purpose,article,online,june,day,identify,accepted,formatting,copyedit,proofing,disclaimer,expedite,responsibility,obsolete,input,thoughtfully,weighting,labor,style,author,version,proof,ultimately,verify,inpatient
# -------------------------------------------
# TERM_LIST :  ['labor']
#
# *************Cluster  15 *********************
# nurse,support,social,cope,perception,mental,05,design,disaster,work,confidence,significant,381,marital,333,protective,theory,subscale,weakly,practice,multidimensional,volunteer,network,income,promote,and,perceive,there,implication,relationship,family,status,scale,sectional,experience,leader,ground,cross,exercise,nursing
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  16 *********************
# janssen,event,vaccination,cvst,syncope,adverse,site,vaers,cdc,anxiety,recipient,use,receipt,fda,dose,administration,relate,administer,reporting,2021,april,episode,tt,thrombocytopenia,000,monitoring,pause,reaction,on,thrombosis,safety,system,authorization,eua,safe,influenza,week,interview,adenoviral,prompt
# -------------------------------------------
# TERM_LIST :  ['syncope', 'anxiety', 'thrombosis']
#
# *************Cluster  17 *********************
# covid,deficit,cognitive,post,fatigue,illness,treatment,intensive,syndrome,acute,elderly,multimorbidity,attentional,psychiatrist,pathogenetic,dysexecutive,dysphoria,encephalopathy,neurologist,reintegration,confusional,memory,manifest,pose,survivor,appraisal,assume,preexist,far,come,somatic,activation,practitioner,several,expert,proportion,cerebral,usually,suffer,combine
# -------------------------------------------
# TERM_LIST :  ['deficit,cognitive,', 'fatigue', 'illness', 'multimorbidity', 'dysexecutive', 'dysphoria', 'encephalopathy', 'confusional']
#
# *************Cluster  18 *********************
# meal,school,program,teaching,continue,close,online,teacher,helpful,resource,improve,transportation,offer,2021,staff,analyze,pediatric,need,change,dfw,west,lapse,reimbursement,open,midwestern,teach,issue,north,address,solve,office,district,telehealth,telemedicine,item,variety,adjustment,proportion,urban,hour
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  19 *********************
# mi,lva4ls,child,spectrum,lvgls,initial,10,echocardiographic,presentation,multisystem,age,tertile,course,involvement,median,year,early,normal,kawasaki,group,adverse,kd,longitudinal,outcome,associate,abnormal,lv,fever,mild,different,los,ventricular,follow,compare,inflammatory,69,week,dysfunction,independently,severe
# -------------------------------------------
# TERM_LIST :  ['kawasaki', 'fever']

# %% [markdown]
# # Word's Similarity

# %%
import spacy
nlp = spacy.load('en_core_web_md')
cov_word =nlp("coronavirus")
for num_clus in range(0,20):
    print("*************Cluster ",num_clus,"*********************")
    str1 = ' '.join(all_keywords[num_clus])
    doc = nlp(str1)
    print(str1)
    print("-------------------------------------------")
    words = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
    print("TERM_LIST : " ,words)
    print("")
    for token in doc:
        #print(token.text, token.has_vector, token.vector_norm, token.is_oov) 
        if cov_word.similarity(token) > 0.5 :
            print("Similarity Between {",cov_word,"} and {",token,"} is :   ",cov_word.similarity(token))
    print("__________________________________________________________________")
# Out:
# *************Cluster  0 *********************
# zn zika disability director directly direct dimer dimension dilemma digital digestive difficulty difficult difficile differently differentiate differential different difference differ dietary die dichotomy diarrhea diagnostic diagnosis diagnose diabetic diabetes diabete dhl disaster discharge discipline disorder distance dissociation dissemination disseminate disruption
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { difficile } is :    0.5350284756573006
# __________________________________________________________________
# *************Cluster  1 *********************
# ci 95 or mortality associate aor severe co superinfection age icu hospital pneumonia ischemic acei stroke adult resident vaccination severity hba1c irr non year 001 65 admission model predictor group acute outcome association condition rr identify odd cohort imv 60
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { superinfection } is :    0.5350284756573006
# Similarity Between { coronavirus } and { pneumonia } is :    0.7140130452187041
# Similarity Between { coronavirus } and { vaccination } is :    0.516190829505902
# __________________________________________________________________
# *************Cluster  2 *********************
# influenza virus rhinovirus hesitancy facility emerge seasonal angeles respondent notably follow los replace anticipate cdc specifically county globally circulate suspect pathway strain address vaccination diagnostic lipid year highly previous challenge potential examine 99 later reduction guideline use involve month isolation
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { influenza } is :    0.6127955278394492
# Similarity Between { coronavirus } and { virus } is :    0.9999999598655379
# Similarity Between { coronavirus } and { vaccination } is :    0.516190829505902
# __________________________________________________________________
# *************Cluster  3 *********************
# receptor protein antigen coronavirus cov cell spike host immune structure human coronaviruse syndrome interaction evolutionary tropism viral process mechanism antibody molecular advance animal range response respiratory acute emergence field microbial evolution carbohydrate recombination membrane molecule entry structural review specificity mutation
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { coronavirus } is :    1.0
# Similarity Between { coronavirus } and { immune } is :    0.524877441820188
# Similarity Between { coronavirus } and { viral } is :    0.6789279758381194
# Similarity Between { coronavirus } and { microbial } is :    0.5350284756573006
# __________________________________________________________________
# *************Cluster  4 *********************
# 0246312 doi pone 1371 journal correct article 10 dilemma difficile digestive dimension dimer difficulty direct directly difficult director digital zn differently disaster differentiate differential different difference differ dietary die dichotomy diarrhea diagnostic diagnosis diagnose disability disclaimer discharge dislodge dissociation dissemination
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { difficile } is :    0.5350284756573006
# __________________________________________________________________
# *************Cluster  5 *********************
# 0238091 doi pone 1371 journal correct article 10 dilemma difficile digestive dimension difficulty dimer direct directly difficult director digital zn differently disaster differentiate differential different difference differ dietary die dichotomy diarrhea diagnostic diagnosis diagnose disability disclaimer discharge dislodge dissociation dissemination
# -------------------------------------------
# <ipython-input-151-a9ecc4291df1>:15: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   if cov_word.similarity(token) > 0.5 :
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { difficile } is :    0.5350284756573006
# __________________________________________________________________
# *************Cluster  6 *********************
# woman pregnant pregnancy anxiety depression asymptomatic mental testing disorder symptomatic stress obstetric period support positive fold hospitalisation trimester screening antenatal complication social infect compare mother newborn characteristic short transmission significantly pneumonia chest frequency moderate pre 30 group scale outcome relate
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { infect } is :    0.6573915586705649
# Similarity Between { coronavirus } and { pneumonia } is :    0.7140130452187041
# __________________________________________________________________
# *************Cluster  7 *********************
# lockdown sleep partial 1st air bt caregiver quality period pm2 march no2 phase total exposure pm10 score 2nd decline iraq 24 technology august change therapy 21 pollutant activity overall burden april population iraqi o3 witness aqi ed foot spread likely
# -------------------------------------------
# TERM_LIST :  []
#
# __________________________________________________________________
# *************Cluster  8 *********************
# model particle rate class different approach specific population quarantine ordinary collision arbitrary yield applicability equation tune cyprus velocity simulation datum both prediction transmit recover transition varied crowd adjust infectious lift susceptible differential incorporate restriction subgroup set allow parameter impose derive
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { quarantine } is :    0.5746238784930114
# Similarity Between { coronavirus } and { infectious } is :    0.5332051459892988
# __________________________________________________________________
# *************Cluster  9 *********************
# dose antibody second symptomatic expose vaccinate igg response worker individual titer exposure receive day vaccination asymptomatic reach bnt162b2 unvaccinated subject symptom fully transplant show biontech pfizer multivariate test partially nct04387929funding naive lr voluntarily clincaltrials philantropic corrente exp unexposed donation plateau
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { vaccination } is :    0.516190829505902
# __________________________________________________________________
# *************Cluster  10 *********************
# opioid misuse adolescent overdose use rise initiate adult epidemic disorder constantly reliever lock resurgence 2015 recession synthetic prescription analog norther recent europe fentanyl north addiction young crisis move america abstract mainly mediterranean eastern decade death pain finally generate activation economic
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { epidemic } is :    0.5010447134454742
# __________________________________________________________________
# *************Cluster  11 *********************
# palliative team spiritual telehealth psychological session 87 die carry our delivery implementation support accentuate psychosocially corona medically love population psychiatric gather delineate veteran involvement disease advanced satisfaction institutional chart share they emphasize complex participate hospital criterion recommendation facility course 75
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { disease } is :    0.5610362870623191
# __________________________________________________________________
# *************Cluster  12 *********************
# inpatient postoperative surgical outcome stay length 90 surgery 2019 ncepod district mortality day uk difference general significant undergo statistically hospital intervention appropriately 027 theatre nonelective list 141 enquiry 250 132 196 acute confidential elucidate versus centre fast compare prioritise discharge
# -------------------------------------------
# TERM_LIST :  []
#
# __________________________________________________________________
# *************Cluster  13 *********************
# ra hospitalization death va non hr match multivariable associate chronic national 10 condition arthritis affair rheumatoid prednisone predominant cox dmard 886 228 autoantibody deceased 503 ace2 age hazard seropositivity prioritize 388 while veteran hispanic related ethnicity surveillance recognize unclear county
# -------------------------------------------
# TERM_LIST :  []
#
# __________________________________________________________________
# *************Cluster  14 *********************
# productivity output pharmacist model manuscript work final ajhp replace project 2018 consensus july post validate purpose article online june day identify accepted formatting copyedit proofing disclaimer expedite responsibility obsolete input thoughtfully weighting labor style author version proof ultimately verify inpatient
# -------------------------------------------
# TERM_LIST :  []
#
# __________________________________________________________________
# *************Cluster  15 *********************
# nurse support social cope perception mental 05 design disaster work confidence significant 381 marital 333 protective theory subscale weakly practice multidimensional volunteer network income promote and perceive there implication relationship family status scale sectional experience leader ground cross exercise nursing
# -------------------------------------------
# TERM_LIST :  []
#
# __________________________________________________________________
# *************Cluster  16 *********************
# janssen event vaccination cvst syncope adverse site vaers cdc anxiety recipient use receipt fda dose administration relate administer reporting 2021 april episode tt thrombocytopenia 000 monitoring pause reaction on thrombosis safety system authorization eua safe influenza week interview adenoviral prompt
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { vaccination } is :    0.516190829505902
# Similarity Between { coronavirus } and { influenza } is :    0.6127955278394492
# __________________________________________________________________
# *************Cluster  17 *********************
# covid deficit cognitive post fatigue illness treatment intensive syndrome acute elderly multimorbidity attentional psychiatrist pathogenetic dysexecutive dysphoria encephalopathy neurologist reintegration confusional memory manifest pose survivor appraisal assume preexist far come somatic activation practitioner several expert proportion cerebral usually suffer combine
# -------------------------------------------
# TERM_LIST :  []
#
# __________________________________________________________________
# *************Cluster  18 *********************
# meal school program teaching continue close online teacher helpful resource improve transportation offer 2021 staff analyze pediatric need change dfw west lapse reimbursement open midwestern teach issue north address solve office district telehealth telemedicine item variety adjustment proportion urban hour
# -------------------------------------------
# TERM_LIST :  []
#
# __________________________________________________________________
# *************Cluster  19 *********************
# mi lva4ls child spectrum lvgls initial 10 echocardiographic presentation multisystem age tertile course involvement median year early normal kawasaki group adverse kd longitudinal outcome associate abnormal lv fever mild different los ventricular follow compare inflammatory 69 week dysfunction independently severe
# -------------------------------------------
# TERM_LIST :  []
#
# __________________________________________________________________

# %%
import spacy
nlp = spacy.load('en_core_web_md')
cov_word =nlp("coronavirus")
top_similar = []
for num_clus in range(0,20):
    str1 = ' '.join(all_keywords[num_clus])
    doc = nlp(str1)
    words = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
    for token in doc:
        if cov_word.similarity(token) > 0.5 :
            top_similar.append((token.text , cov_word.similarity(token)))
LL = top_similar
top_similar_sorted = []
for a in top_similar :
    if a not in top_similar_sorted:
        top_similar_sorted.append(a)
top_similar_sorted = sorted(top_similar_sorted, key=lambda tup: tup[1],reverse=True)
top_similar_sorted
# Out:
# <ipython-input-152-7ae6cfacfccd>:10: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   if cov_word.similarity(token) > 0.5 :
# [('coronavirus', 1.0),
#  ('virus', 0.9999999598655379),
#  ('pneumonia', 0.7140130452187041),
#  ('viral', 0.6789279758381194),
#  ('infect', 0.6573915586705649),
#  ('influenza', 0.6127955278394492),
#  ('quarantine', 0.5746238784930114),
#  ('disease', 0.5610362870623191),
#  ('difficile', 0.5350284756573006),
#  ('superinfection', 0.5350284756573006),
#  ('microbial', 0.5350284756573006),
#  ('infectious', 0.5332051459892988),
#  ('immune', 0.524877441820188),
#  ('vaccination', 0.516190829505902),
#  ('epidemic', 0.5010447134454742)]

# %%
li = top_similar_sorted[0:10]

# %%
nlp = spacy.load('en_core_web_md')
lii = []
for tup in li:
    cov_word =nlp(tup[0])
    top_similar = []
    for num_clus in range(0,20):
        str1 = ' '.join(all_keywords[num_clus])
        doc = nlp(str1)
        words = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
        for token in doc:
            if cov_word.similarity(token) > 0.5 :
                top_similar.append((token.text , cov_word.similarity(token)))
    top_similar_sorted = []
    for a in top_similar :
        if a not in top_similar_sorted:
            top_similar_sorted.append(a)
    top_similar_sorted = sorted(top_similar_sorted, key=lambda tup: tup[1],reverse=True)
    top_similar_sorted = top_similar_sorted[0:10]
    lii.append((tup[0],top_similar_sorted))
# LL = top_similar
# top_similar_sorted = []
# for a in top_similar :
#     if a not in top_similar_sorted:
#         top_similar_sorted.append(a)
# top_similar_sorted = sorted(top_similar_sorted, key=lambda tup: tup[1],reverse=True)
# top_similar_sorted
top_ten_of_ten = lii
top_ten_of_ten
# Out:
# <ipython-input-154-241254ade84c>:11: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   if cov_word.similarity(token) > 0.5 :
# [('coronavirus',
#   [('coronavirus', 1.0),
#    ('virus', 0.9999999598655379),
#    ('pneumonia', 0.7140130452187041),
#    ('viral', 0.6789279758381194),
#    ('infect', 0.6573915586705649),
#    ('influenza', 0.6127955278394492),
#    ('quarantine', 0.5746238784930114),
#    ('disease', 0.5610362870623191),
#    ('difficile', 0.5350284756573006),
#    ('superinfection', 0.5350284756573006)]),
#  ('virus',
#   [('virus', 1.0),
#    ('coronavirus', 0.9999999598655379),
#    ('pneumonia', 0.7140130452187041),
#    ('viral', 0.6789279758381194),
#    ('infect', 0.6573915586705649),
#    ('influenza', 0.6127955278394492),
#    ('quarantine', 0.5746238784930114),
#    ('disease', 0.5610362870623191),
#    ('difficile', 0.5350284756573006),
#    ('superinfection', 0.5350284756573006)]),
#  ('pneumonia',
#   [('pneumonia', 1.0),
#    ('difficile', 0.7614367047278192),
#    ('superinfection', 0.7614367047278192),
#    ('microbial', 0.7614367047278192),
#    ('disease', 0.723913034916283),
#    ('virus', 0.7140130557321445),
#    ('coronavirus', 0.7140130557321445),
#    ('infectious', 0.6859604228532314),
#    ('chronic', 0.6575700602582694),
#    ('arthritis', 0.6575700602582694)]),
#  ('viral',
#   [('viral', 1.0),
#    ('virus', 0.6789279468695711),
#    ('coronavirus', 0.6789279468695711),
#    ('pneumonia', 0.6289952119582034),
#    ('difficile', 0.5907780408541587),
#    ('superinfection', 0.5907780408541587),
#    ('microbial', 0.5907780408541587),
#    ('influenza', 0.513816028588837),
#    ('immune', 0.5129531531950872)]),
#  ('infect',
#   [('infect', 1.0),
#    ('virus', 0.6573915701516425),
#    ('coronavirus', 0.6573915701516425),
#    ('pneumonia', 0.5950294030457614),
#    ('susceptible', 0.5343829898802083)]),
#  ('influenza',
#   [('influenza', 1.0),
#    ('quarantine', 0.699400466700272),
#    ('vaccination', 0.6479943843871718),
#    ('epidemic', 0.6435812281406311),
#    ('fever', 0.6320381452813847),
#    ('virus', 0.6127954967737034),
#    ('coronavirus', 0.6127954967737034),
#    ('hospitalization', 0.608865799798042),
#    ('illness', 0.608865799798042),
#    ('pneumonia', 0.603404838735448)]),
#  ('quarantine',
#   [('quarantine', 1.0),
#    ('epidemic', 0.7496999518467676),
#    ('influenza', 0.6994004904415994),
#    ('pneumonia', 0.5921143392902705),
#    ('fever', 0.575384944128796),
#    ('virus', 0.574623868868135),
#    ('coronavirus', 0.574623868868135),
#    ('disease', 0.5478079615900759),
#    ('vaccination', 0.5423195894551589),
#    ('hospitalization', 0.5147422543598418)]),
#  ('disease',
#   [('disease', 1.0),
#    ('infectious', 0.9019842531645132),
#    ('diabetes', 0.7507223055535066),
#    ('diabete', 0.7507223055535066),
#    ('chronic', 0.7505860249999791),
#    ('arthritis', 0.7505860249999791),
#    ('rheumatoid', 0.7505860249999791),
#    ('hospitalization', 0.7385644799193568),
#    ('illness', 0.7385644799193568),
#    ('dysfunction', 0.7295921383085955)]),
#  ('difficile',
#   [('difficile', 1.0),
#    ('superinfection', 0.9999999422223542),
#    ('microbial', 0.9999999422223542),
#    ('pneumonia', 0.7614366734514749),
#    ('infectious', 0.6076465893606661),
#    ('viral', 0.5907780504939281),
#    ('antigen', 0.5866105909088323),
#    ('antibody', 0.5866105909088323),
#    ('membrane', 0.5866105909088323),
#    ('disease', 0.5823650399135328)]),
#  ('superinfection',
#   [('superinfection', 1.0),
#    ('difficile', 0.9999999422223542),
#    ('microbial', 0.9999999422223542),
#    ('pneumonia', 0.7614366734514749),
#    ('infectious', 0.6076465893606661),
#    ('viral', 0.5907780504939281),
#    ('antigen', 0.5866105909088323),
#    ('antibody', 0.5866105909088323),
#    ('membrane', 0.5866105909088323),
#    ('disease', 0.5823650399135328)])]

# %%
ten_diseases = []
for i,mots in top_similar_sorted :
    if mots not in ten_diseases:
        ten_diseases.append(i)
ten_diseases
# Out:
# ['superinfection',
#  'difficile',
#  'microbial',
#  'pneumonia',
#  'infectious',
#  'viral',
#  'antigen',
#  'antibody',
#  'membrane',
#  'disease']

# %%
hundred_diseases = []
for i,mots in top_ten_of_ten :
    for mot,val in mots:
        if mot not in hundred_diseases:
            hundred_diseases.append(mot)
hundred_diseases
# Out:
# ['coronavirus',
#  'virus',
#  'pneumonia',
#  'viral',
#  'infect',
#  'influenza',
#  'quarantine',
#  'disease',
#  'difficile',
#  'superinfection',
#  'microbial',
#  'infectious',
#  'chronic',
#  'arthritis',
#  'immune',
#  'susceptible',
#  'vaccination',
#  'epidemic',
#  'fever',
#  'hospitalization',
#  'illness',
#  'diabetes',
#  'diabete',
#  'rheumatoid',
#  'dysfunction',
#  'antigen',
#  'antibody',
#  'membrane']

# %%
print(lemmatizer.lemmatize("diabete"))
print(lemmatizer.lemmatize("diabetes"))
print(lemmatizer.lemmatize("diabetic"))

print(lemmatizer.lemmatize("feet"))

print(lemmatizer.lemmatize("vaccinations"))
print(lemmatizer.lemmatize("vaccination"))
print(lemmatizer.lemmatize("vaccinated"))

print(lemmatizer.lemmatize("speaking"))
print(lemmatizer.lemmatize("speaks"))
print(lemmatizer.lemmatize("spoken"))
# Out:
# diabete
# diabetes
# diabetic
# foot
# vaccination
# vaccination
# vaccinated
# speaking
# speaks
# spoken

# %% [markdown]
# # LDA

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

tf = CountVectorizer(max_df=0.9, min_df=5, stop_words='english')
tff = tf.fit_transform(text)
lda = LatentDirichletAllocation(n_components=20, max_iter=10, learning_method='online', random_state=42)
lda.fit(tff)
# Out:
# LatentDirichletAllocation(learning_method='online', n_components=20,
#                           random_state=42)

# %%
tf_feature_names = tf.get_feature_names()
plot_top_words(lda, tf_feature_names, 40, 'Topics in LDA model')

# %%
all_keywords = []
for topic_idx, topic in enumerate(nmf.components_):
    #top words = 100
    top_features_ind = topic.argsort()[:-100 - 1:-1]
    top_features = [tfidf_feature_names[i] for i in top_features_ind]
    all_keywords.append(top_features)

# %%
for num_clus in range(0,20):
    print("*************Cluster ",num_clus,"*********************")
    str1 = ','.join(all_keywords[num_clus])
    doc = nlp(str1)
    print(str1)
    print("-------------------------------------------")
    TERM_LIST = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
    print("TERM_LIST : " ,TERM_LIST )
    print("")
# Out:
# *************Cluster  0 *********************
# care,social,measure,public,country,impact,lockdown,datum,service,change,practice,research,provide,healthcare,spread,use,people,community,system,base,increase,need,population,work,outbreak,challenge,face,number,time,experience,policy,transmission,control,information,review,medical,physical,support,new,strategy,reduce,article,report,management,survey,access,period,individual,government,participant,state,contact,intervention,response,emergency,relate,life,world,global,home,approach,analysis,professional,virus,evidence,quality,affect,conduct,find,implement,behavior,activity,staff,visit,crisis,resource,effect,aim,future,knowledge,different,mask,area,current,economic,distancing,epidemic,dental,program,prevention,rate,effective,nurse,online,person,lead,telehealth,technology,level,national
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  1 *********************
# cell,immune,response,cytokine,expression,virus,gene,viral,il,host,lung,inflammatory,activation,ifn,human,induce,tissue,interferon,antiviral,innate,infect,storm,pathway,rna,blood,immunity,mechanism,inflammation,cellular,epithelial,signal,cd8,level,severity,type,role,associate,cd4,antigen,target,replication,syndrome,memory,macrophage,cause,express,pathogenesis,mediate,line,specific,understand,activate,increase,production,here,factor,receptor,stem,lymphocyte,therapeutic,profile,lead,entry,coronaviruse,release,characterize,acute,beta,system,pathogen,peripheral,effect,function,highly,potential,lipid,produce,adaptive,individual,healthy,signature,activity,derive,control,monocyte,defense,observe,low,treg,endothelial,critical,therapy,chemokine,cov,damage,dependent,suggest,provide,interleukin,find
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  2 *********************
# mortality,group,hospital,day,admission,icu,age,outcome,rate,compare,level,year,vs,median,001,significantly,cohort,score,admit,hospitalize,associate,care,conclusion,death,discharge,severity,hospitalization,increase,low,difference,30,period,treatment,ventilation,significant,10,non,ratio,intensive,march,male,comorbiditie,mean,retrospective,unit,14,datum,factor,receive,control,time,total,stay,analysis,characteristic,confirm,background,12,decrease,13,value,laboratory,mechanical,follow,count,respectively,aim,positive,objective,observe,05,diabetes,15,20,11,evaluate,iqr,serum,find,blood,old,28,length,incidence,24,18,duration,predictor,record,dimer,16,perform,medical,ill,die,april,predict,primary,lymphocyte,there
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  3 *********************
# test,pcr,rt,positive,assay,sample,detection,sensitivity,negative,swab,reaction,detect,diagnostic,reverse,chain,polymerase,rapid,rna,diagnosis,specimen,specificity,virus,transcription,nasopharyngeal,laboratory,antigen,false,time,real,viral,qpcr,performance,standard,symptom,day,100,igg,acute,saliva,base,perform,asymptomatic,screen,syndrome,kit,confirm,value,pool,nucleic,evaluate,gold,positivity,suspect,extraction,acid,transcriptase,low,individual,igm,serological,amplification,serology,ag,surveillance,sensitive,gene,compare,molecular,agreement,quantitative,collect,cost,lamp,99,copy,threshold,accuracy,show,point,96,obtain,cycle,reliable,symptomatic,rrt,isolation,reference,98,accurate,total,target,surface,load,respectively,primer,concordance,oropharyngeal,demonstrate,presence,nasal
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  4 *********************
# vaccine,vaccination,mrna,dose,candidate,development,efficacy,vaccinate,trial,effective,safety,hesitancy,receive,induce,develop,willingness,safe,platform,immunity,immunogenicity,response,influenza,acceptance,million,protection,intention,effort,approve,concern,pfizer,neutralize,vector,bnt162b2,current,adjuvant,adverse,immune,variant,antigen,inactivate,campaign,strategy,immunization,public,attitude,reaction,cov2,new,biontech,population,use,potential,2021,technology,coverage,effect,approval,challenge,nanoparticle,recipient,virus,base,allergic,need,syndrome,however,novel,mouse,control,global,event,previous,elicit,available,phase,group,effectiveness,reduce,astrazeneca,year,authorization,herd,spike,moderna,currently,highly,rapid,december,country,second,epitope,19,prevent,unprecedented,achieve,acute,animal,age,people,administration
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  5 *********************
# anxiety,depression,mental,stress,psychological,symptom,sleep,disorder,scale,participant,score,questionnaire,relate,level,perceive,survey,factor,fear,impact,social,cope,associate,self,physical,distress,depressive,effect,respondent,ptsd,life,female,quality,report,psychiatric,sectional,cross,001,moderate,significantly,adult,group,significant,problem,negative,relationship,behavior,loneliness,support,phq,people,resilience,worker,lockdown,prevalence,online,general,association,sample,increase,worry,complete,status,age,traumatic,regression,consequence,find,examine,trait,insomnia,activity,work,emotional,aim,lifestyle,change,family,show,nurse,ass,gad,21,intervention,conclusion,sociodemographic,adolescent,respectively,gender,post,burnout,perception,year,staff,conduct,individual,measure,population,disturbance,experience,confinement
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  6 *********************
# acute,symptom,syndrome,complication,report,present,cause,inflammatory,treatment,manifestation,associate,review,neurological,therapy,failure,pulmonary,stroke,cardiovascular,old,pneumonia,presentation,organ,mechanism,system,fever,cardiac,describe,dysfunction,develop,year,evidence,thrombosis,injury,ards,common,damage,neurologic,distress,cytokine,heart,cough,illness,lung,management,inflammation,vascular,viral,diagnosis,lead,literature,possible,rare,course,post,kidney,novel,relate,occur,brain,treat,mild,condition,long,worldwide,recent,term,therapeutic,although,virus,however,know,effect,systemic,disorder,immune,potential,find,gastrointestinal,myocardial,affect,nervous,diagnose,involvement,chronic,world,storm,tissue,death,coronavirus,million,current,covid,summarize,it,role,infect,factor,week,bilateral,thrombotic
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  7 *********************
# ct,chest,image,lung,pneumonia,opacity,scan,ground,glass,tomography,consolidation,compute,find,feature,diagnosis,radiologist,lobe,pcr,rt,ggo,ray,pulmonary,lesion,deep,score,pattern,rsna,volume,typical,segment,radiograph,abnormality,involvement,accuracy,dataset,radiological,sensitivity,severity,material,value,classification,bilateral,negative,year,pleural,cxr,thicken,network,purpose,normal,effusion,show,evaluate,propose,common,lu,pet,respectively,peripheral,segmentation,confirm,auc,hrct,neural,range,learning,detect,manifestation,diagnostic,correlation,examination,to,undergo,computer,pediatric,performance,reverse,sign,suspect,method,follow,initial,stage,radiomic,opacification,positive,learn,diagnose,diffuse,perform,modality,distribution,mild,radiographic,non,retrospectively,male,base,polymerase,evaluation
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  8 *********************
# drug,compound,antiviral,pro,inhibitor,protease,treatment,therapeutic,target,potential,activity,molecular,replication,viral,bind,effective,dock,anti,molecule,candidate,screen,approve,identify,main,virus,ligand,inhibit,repurpose,rna,development,trial,agent,base,discovery,property,remdesivir,3cl,active,therapy,energy,efficacy,novel,vitro,effect,treat,show,inhibition,cause,interaction,silico,site,structure,protein,natural,use,simulation,plpro,plant,promise,affinity,design,currently,approach,available,chemical,fda,rdrp,new,review,cov,option,inhibitory,strategy,mpro,potent,syndrome,human,peptide,select,complex,good,broad,world,mol,kcal,need,library,medicine,product,toxicity,worldwide,database,like,chloroquine,essential,urgent,combination,assay,million,global
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  9 *********************
# protein,ace2,bind,spike,receptor,rbd,human,angiotensin,cov,interaction,host,domain,entry,enzyme,convert,cell,viral,structural,virus,expression,surface,affinity,molecular,express,acid,s1,structure,residue,site,ace,interact,target,glycoprotein,block,peptide,complex,coronaviruse,mechanism,mouse,vitro,fusion,tmprss2,amino,bat,glycan,specie,epitope,identify,neutralize,protease,rna,region,potential,cleavage,find,replication,acute,cellular,envelope,role,silico,subunit,animal,s2,recombinant,analysis,mers,syndrome,inhibitor,ra,function,membrane,ligand,terminal,wild,predict,epithelial,stability,demonstrate,dock,like,nucleocapsid,suggest,contain,functional,show,attachment,furin,enter,infectivity,inhibit,involve,development,mediate,therapeutic,these,ii,covs,different,vivo
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  10 *********************
# ci,95,or,odd,aor,interval,ratio,confidence,associate,analysis,meta,adjust,prevalence,logistic,regression,pool,001,factor,07,14,association,aki,outcome,17,19,estimate,mortality,27,79,identify,21,sex,96,26,02,99,03,15,12,multivariable,18,11,household,65,25,09,10,24,systematic,36,conduct,independent,92,28,01,age,87,rr,individual,respectively,29,76,32,81,pubmed,13,86,participant,45,77,70,37,85,60,68,06,66,ptsd,97,93,59,05,91,00001,39,16,random,34,98,43,67,cohort,survey,multivariate,78,seroprevalence,23,model,search,incidence
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  11 *********************
# antibody,igg,igm,neutralize,anti,rbd,response,serum,assay,titer,specific,plasma,neutralization,elisa,serological,convalescent,spike,iga,seroprevalence,bind,epitope,immune,antigen,s1,immunity,test,domain,therapeutic,humoral,subject,level,sample,monoclonal,individual,immunoglobulin,immunoassay,specificity,detect,recover,receptor,mild,asymptomatic,dose,serology,onset,follow,prevalence,cross,here,sensitivity,coronavirus,donor,escape,elicit,nabs,ml,positive,population,diagnostic,s2,month,cp,seropositive,correlate,fc,syndrome,nucleocapsid,day,healthy,activity,100,seropositivity,cov2,reactivity,351,positivity,participant,seroconversion,ass,symptom,determine,protection,acute,these,worker,protective,au,total,respectively,viral,show,mabs,reactive,investigate,detection,low,transplant,recombinant,clearance,immunization
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  12 *********************
# child,pediatric,mi,parent,adolescent,multisystem,school,inflammatory,adult,family,age,syndrome,year,caregiver,asymptomatic,mis,level,youth,kawasaki,incidence,sleep,mother,obesity,activity,kd,rash,experience,physical,young,home,lifestyle,fever,mild,rare,positive,most,psychological,old,change,weight,describe,population,screen,childhood,report,increase,14,routine,violence,closure,cp,prevention,find,article,behavior,outdoor,rate,hyperinflammatory,healthy,impact,coronavirus,dka,low,datum,cross,diagnosis,sectional,period,adhd,rsv,immunoglobulin,abdominal,infect,compare,18,characteristic,reactive,negative,alt,symptomatic,sign,determine,majority,disparity,household,decrease,feature,difference,abuse,boy,seasonal,social,questionnaire,picture,protect,shock,girl,reopen,purpose,satisfaction
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  13 *********************
# student,learn,school,online,university,medical,education,teach,nursing,course,experience,class,face,academic,educational,program,college,teacher,virtual,curriculum,year,skill,teaching,undergraduate,campus,career,dental,faculty,learning,participate,nurse,volunteer,self,distance,prefer,institution,remote,service,design,future,survey,fourth,semester,training,instruction,educator,item,impact,mental,implement,readiness,graduate,develop,grade,activity,digital,literacy,environment,base,female,scale,perception,motivation,telemedicine,traditional,find,willingness,exam,communication,attitude,total,format,examination,choice,questionnaire,athlete,medicine,score,home,week,residency,privacy,majority,transition,shift,performance,evaluation,enrol,practice,train,sectional,conventional,male,challenge,investigate,platform,closure,hybrid,connection,cross
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  14 *********************
# variant,mutation,sequence,genome,lineage,virus,genetic,rna,strain,sample,genomic,viral,evolution,351,isolate,spike,analysis,clade,phylogenetic,voc,substitution,new,identify,syndrome,variation,host,d614,escape,region,concern,emerge,report,acute,detect,amino,wastewater,emergence,transmission,here,gene,protein,spread,nucleotide,cluster,outbreak,e484,primer,circulate,501y,different,human,surveillance,target,deletion,country,bat,reveal,diversity,mink,suggest,acid,global,animal,gisaid,cause,mutational,swab,brazil,reinfection,infectivity,africa,neutralization,specie,find,understand,neutralize,track,nasopharyngeal,provide,these,evolve,rapid,show,belong,complete,harbor,generation,distinct,rapidly,single,immunity,despite,orf1ab,2021,uk,orf10,site,rate,early,wuhan
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  15 *********************
# woman,pregnant,pregnancy,maternal,delivery,preterm,birth,fetal,neonate,neonatal,vertical,obstetric,trimester,outcome,cesarean,gestational,newborn,prenatal,positive,placental,perinatal,placenta,stress,transmission,man,postpartum,labor,gestation,service,impact,admission,deliver,care,gender,likely,or,population,adverse,reproductive,offspring,intensive,death,cord,require,section,among,minority,breastfeed,safe,illness,there,test,compare,person,depressive,evidence,substance,106,blood,adversity,milk,demographic,week,contaminate,non,baby,appear,vs,stai,no,telehealth,admit,specific,anesthesia,negative,characteristic,screen,violence,relate,change,develop,mobile,know,37,report,age,sexual,modification,need,infect,plan,43,cross,susceptibility,relationship,congenital,103,rare,objective,similar
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  16 *********************
# hcw,worker,healthcare,seroprevalence,burnout,work,hospital,exposure,prevalence,nurse,screen,personal,protective,contact,equipment,symptom,frontline,occupational,test,seropositivity,igg,care,seropositive,vaccination,sectional,participant,ppe,physician,low,psychological,staff,workplace,general,positive,professional,willingness,support,cross,subject,medical,report,group,001,survey,wave,syndrome,line,prioritise,respectively,expose,asymptomatic,female,14,japan,resilience,non,infect,coronavirus,facility,ward,unit,perform,aes,exhaustion,factor,pt,tertiary,outside,nosocomial,hygiene,iga,outbreak,acute,15,evaluate,aim,transmission,protect,prevention,traumatic,determine,designate,population,questionnaire,stress,production,second,assistant,logistic,outpatient,doctor,23,1st,77,cor,all,category,conduct,majority,fight
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  17 *********************
# model,propose,network,prediction,accuracy,dataset,epidemic,spread,forecast,datum,base,predict,deep,performance,learn,neural,dynamic,image,feature,number,mathematical,machine,estimate,parameter,algorithm,simulation,apply,infect,cxr,time,country,ray,death,train,reproduction,analysis,new,learning,classification,rate,order,cnn,scenario,validation,different,paper,transmission,outbreak,system,stability,develop,fractional,susceptible,obtain,control,achieve,fit,value,convolutional,novel,our,cluster,curve,region,decision,term,auc,predictive,virus,world,state,help,detection,ai,technique,process,lstm,human,india,numerical,individual,computational,score,asymptomatic,to,future,daily,use,basic,incidence,class,epidemiological,population,set,hybrid,expose,seir,approach,for,error
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  18 *********************
# infant,mother,newborn,birth,maternal,breastfeed,neonate,bear,delivery,vertical,postpartum,neonatal,milk,transmission,positive,describe,room,baby,separation,preterm,skin,care,breast,bond,month,placenta,age,separate,discharge,seizure,igg,bacterial,exclusive,present,congenital,evidence,infect,vitamin,guideline,perinatal,hospital,possible,at,oh,give,attachment,young,guidance,support,day,group,abnormality,rdv,cesarean,offspring,period,febrile,life,gestational,brain,syndrome,child,rate,underline,30,deliver,hour,immediate,confirm,isolation,home,acute,placental,outcome,fluid,week,little,course,cohort,epilepsy,challenge,impair,neurologic,provide,25,90,emerge,offer,follow,precaution,background,attend,31,choice,suspect,analyze,available,conclusion,iran,management
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  19 *********************
# cancer,treatment,oncology,chemotherapy,breast,lung,screen,surgery,anticancer,delay,colorectal,crc,clinic,surgical,postpone,oncologist,diagnose,therapy,referral,undergo,tumor,thyroid,wave,bc,cohort,care,impact,guideline,there,radiotherapy,prostate,elective,vulnerable,diagnosis,maintain,treat,increase,center,appointment,general,outpatient,follow,challenge,covid,adapt,financial,operation,colonoscopy,it,march,avoid,active,french,year,pathway,vaccination,management,immunotherapy,volume,radiation,postoperative,perioperative,nodule,zealand,progression,or,effect,22,survivor,population,stage,staff,service,malignancy,routine,neck,age,long,skin,palliative,screening,and,expression,newly,bone,change,form,2018,susceptible,affect,ace2,recommendation,detrimental,receive,advance,die,normal,vulnerability,type,national
# -------------------------------------------
# TERM_LIST :  []

# %% [markdown]
# # LSA

# %%
from sklearn.decomposition import TruncatedSVD

# SVD represent documents and terms in vectors 
svd_model = TruncatedSVD(n_components=20, algorithm='randomized', n_iter=100, random_state=122)

svd_model.fit(X)

len(svd_model.components_)
# Out:
# 20

# %%
terms = vectorizer.get_feature_names()

for i, comp in enumerate(svd_model.components_):
    terms_comp = zip(terms, comp)
    sorted_terms = sorted(terms_comp, key= lambda x:x[1], reverse=True)[:7]
    print("Topic "+str(i)+": ")
    for t in sorted_terms:
        print(t[0] ," ",end='')
    print(" ")
# Out:
# Topic 0:
# test  vaccine  virus  care  acute  report  95
# Topic 1:
# vaccine  protein  cell  drug  virus  viral  bind
# Topic 2:
# 95  ci  ct  test  pcr  rt  antibody
# Topic 3:
# test  pcr  rt  ct  assay  sample  antibody
# Topic 4:
# vaccine  vaccination  95  ci  antibody  igg  or
# Topic 5:
# vaccine  vaccination  ct  care  treatment  mortality  pneumonia
# Topic 6:
# ci  95  model  drug  compound  or  mortality
# Topic 7:
# ct  vaccine  image  chest  anxiety  model  lung
# Topic 8:
# drug  compound  treatment  antiviral  pro  care  student
# Topic 9:
# care  antibody  protein  group  hospital  ace2  bind
# Topic 10:
# ci  95  cell  care  student  ct  or
# Topic 11:
# antibody  model  igg  response  cytokine  immune  il
# Topic 12:
# child  antibody  pediatric  mi  student  school  lockdown
# Topic 13:
# student  cell  school  learn  rt  online  pcr
# Topic 14:
# student  variant  learn  antibody  symptom  mutation  model
# Topic 15:
# woman  pregnant  pregnancy  child  model  care  icu
# Topic 16:
# child  hcw  group  worker  pediatric  nurse  healthcare
# Topic 17:
# variant  sequence  mutation  genome  ct  antibody  lockdown
# Topic 18:
# woman  pregnant  pregnancy  transmission  virus  ct  student
# Topic 19:
# cancer  group  treatment  child  anxiety  variant  trial

# %%
all_keywords = []
for topic_idx, topic in enumerate(svd_model.components_):
    #top words = 100
    top_features_ind = topic.argsort()[:-40 - 1:-1]
    top_features = [tfidf_feature_names[i] for i in top_features_ind]
    all_keywords.append(top_features)

# %%
for num_clus in range(0,19):
    print("*************Cluster ",num_clus,"*********************")
    str1 = ','.join(all_keywords[num_clus])
    doc = nlp(str1)
    print(str1)
    print("-------------------------------------------")
    TERM_LIST = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
    print("TERM_LIST : " ,TERM_LIST )
    print("")
# Out:
# *************Cluster  0 *********************
# test,vaccine,virus,care,acute,report,95,symptom,treatment,syndrome,group,ci,increase,datum,hospital,mortality,associate,viral,level,find,model,base,analysis,time,antibody,response,cell,positive,age,day,cause,drug,rate,protein,year,measure,factor,effect,control,use
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  1 *********************
# vaccine,protein,cell,drug,virus,viral,bind,ace2,human,spike,antibody,antiviral,immune,host,therapeutic,target,receptor,cov,rna,compound,potential,syndrome,variant,response,molecular,development,rbd,cause,protease,replication,acute,gene,interaction,expression,anti,inhibitor,mutation,entry,candidate,mechanism
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  2 *********************
# 95,ci,ct,test,pcr,rt,antibody,mortality,day,positive,chest,admission,igg,assay,pneumonia,acute,or,icu,lung,sensitivity,image,hospital,diagnosis,syndrome,laboratory,igm,detection,cell,protein,hospitalize,outcome,severity,polymerase,detect,ratio,median,reaction,sample,cohort,serum
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  3 *********************
# test,pcr,rt,ct,assay,sample,antibody,detection,positive,igg,sensitivity,detect,diagnostic,image,negative,chest,igm,diagnosis,rapid,swab,specificity,reverse,performance,chain,reaction,time,transmission,base,polymerase,virus,antigen,model,accuracy,specimen,real,spread,false,transcription,learn,contact
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  4 *********************
# vaccine,vaccination,95,ci,antibody,igg,or,test,variant,dose,hcw,neutralize,mrna,vaccinate,assay,igm,participant,worker,antigen,rbd,efficacy,sample,spike,hesitancy,candidate,immunity,odd,response,population,individual,seroprevalence,titer,prevalence,willingness,safety,development,confidence,intention,interval,attitude
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  5 *********************
# vaccine,vaccination,ct,care,treatment,mortality,pneumonia,trial,image,hospital,day,review,chest,management,cancer,therapy,complication,dose,acute,receive,icu,death,safety,system,challenge,admission,present,emergency,article,pulmonary,efficacy,outcome,develop,syndrome,world,diagnosis,lung,number,medical,new
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  6 *********************
# ci,95,model,drug,compound,or,mortality,country,analysis,base,spread,datum,number,transmission,antiviral,epidemic,propose,inhibitor,protease,pro,death,estimate,policy,simulation,identify,use,molecular,network,learn,rate,odd,rna,target,measure,prediction,approach,outbreak,public,accuracy,sequence
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  7 *********************
# ct,vaccine,image,chest,anxiety,model,lung,pneumonia,score,depression,scan,opacity,student,mental,feature,ground,stress,vaccination,find,glass,tomography,consolidation,ray,deep,compute,dataset,propose,network,radiologist,accuracy,psychological,lobe,group,ggo,pattern,rt,predict,cxr,neural,learn
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  8 *********************
# drug,compound,treatment,antiviral,pro,care,student,inhibitor,protease,anxiety,trial,vaccine,test,therapeutic,screen,therapy,nurse,target,depression,potential,ct,hcw,candidate,pcr,stress,medical,dock,rt,molecular,activity,approve,anti,mental,treat,cancer,ci,95,healthcare,repurpose,worker
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  9 *********************
# care,antibody,protein,group,hospital,ace2,bind,icu,spike,rbd,student,cell,ct,admission,medical,score,neutralize,receptor,mortality,service,level,visit,domain,igg,cancer,learn,day,compare,nurse,serum,significantly,unit,lung,practice,response,intensive,virtual,staff,admit,healthcare
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  10 *********************
# ci,95,cell,care,student,ct,or,nurse,ace2,image,learn,response,immune,lung,system,service,medical,review,chest,challenge,expression,healthcare,professional,practice,face,article,experience,provide,telehealth,education,burnout,host,aor,cancer,gene,provider,staff,worker,telemedicine,receptor
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  11 *********************
# antibody,model,igg,response,cytokine,immune,il,anti,inflammatory,drug,igm,level,therapy,therapeutic,plasma,treatment,serum,storm,propose,lung,image,trial,convalescent,accuracy,learn,individual,network,inflammation,activation,effect,review,performance,specific,assay,social,sensitivity,elisa,neutralize,control,base
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  12 *********************
# child,antibody,pediatric,mi,student,school,lockdown,parent,activity,bind,ci,physical,95,adult,compound,rbd,year,adolescent,multisystem,old,igg,social,learn,protein,ct,inflammatory,spike,online,change,age,pro,home,anti,family,period,neutralize,image,report,behavior,lifestyle
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  13 *********************
# student,cell,school,learn,rt,online,pcr,test,sample,il,group,gene,rna,university,cytokine,education,assay,expression,level,teach,detection,medical,immune,activity,mortality,vaccine,swab,program,inflammatory,reaction,response,course,specimen,trial,blood,academic,educational,viral,qpcr,reverse
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  14 *********************
# student,variant,learn,antibody,symptom,mutation,model,genome,mortality,sequence,anxiety,acute,medical,icu,university,school,syndrome,course,online,protein,present,bind,teach,death,complication,day,depression,education,country,rbd,develop,igg,report,lineage,failure,cause,outbreak,stroke,neutralize,nursing
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  15 *********************
# woman,pregnant,pregnancy,child,model,care,icu,mortality,outcome,maternal,mental,mother,assay,stress,delivery,anxiety,test,telehealth,admission,infant,protein,depression,newborn,birth,sensitivity,level,social,predict,neonate,development,research,detection,relate,analysis,intensive,identify,datum,service,adult,preterm
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  16 *********************
# child,hcw,group,worker,pediatric,nurse,healthcare,mi,icu,hospital,model,il,parent,level,care,inflammatory,virus,score,burnout,mortality,professional,work,multisystem,cytokine,adolescent,rna,family,predict,cov,psychological,anxiety,gene,sequence,staff,influenza,factor,biomarker,vaccination,value,severity
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  17 *********************
# variant,sequence,mutation,genome,ct,antibody,lockdown,trial,physical,quality,care,sample,therapy,treatment,assay,rna,activity,plasma,lineage,change,review,icu,neutralize,therapeutic,ci,sleep,chest,convalescent,life,viral,group,strain,il,mental,351,or,level,cp,analysis,serum
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  18 *********************
# woman,pregnant,pregnancy,transmission,virus,ct,student,maternal,antiviral,mother,viral,group,infant,delivery,antibody,pneumonia,response,hcw,newborn,dental,birth,neonate,mask,activity,cov,preterm,vertical,contact,mers,neonatal,fetal,spread,aerosol,chest,anti,droplet,worker,participant,opacity,immune
# -------------------------------------------
# TERM_LIST :  []

# %% [markdown]
# # Topic Modeling on Each Cluster
#
# Now we will attempt to find the most significant words in each clusters. K-means clustered the articles but did not label the topics. Through topic modeling we will find out what the most important terms for each cluster are. This will add more meaning to the cluster by giving keywords to quickly identify the themes of the cluster.

# %% [markdown]
# For topic modeling, we will use LDA (Latent Dirichlet Allocation). In LDA, each document can be described by a distribution of topics and each topic can be described by a distribution of words[.](https://towardsdatascience.com/light-on-math-machine-learning-intuitive-guide-to-latent-dirichlet-allocation-437c81220158)

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# First we will create 20 vectorizers, one for each of our cluster labels

# %%
vectorizers = []
    
for ii in range(0, 5):
    # Creating a vectorizer
    vectorizers.append(CountVectorizer(min_df=5, max_df=0.9, stop_words='english', lowercase=True, token_pattern='[a-zA-Z\-][a-zA-Z\-]{2,}'))

# %% [markdown]
# Now we will vectorize the data from each of our clusters

# %%
vectorized_data = []

for current_cluster, cvec in enumerate(vectorizers):
    try:
        vectorized_data.append(cvec.fit_transform(df.loc[df['y'] == current_cluster, 'text_lemmatized_url_html']))
        #d'ou vient df['y'] =   y_pred = kmeans.fit_predict(X_reduced)      df['y'] = y_pred       df['y']
    except Exception as e:
        print("Not enough instances in cluster: " + str(current_cluster))
        vectorized_data.append(None)

# %%
len(vectorized_data)
# Out:
# 5

# %% [markdown]
# Topic modeling will be performed through the use of Latent Dirichlet Allocation (LDA). This is a generative statistical model that allows sets of words to be explained by a shared topic

# %% [markdown]
# # Topic modeling on each cluster using LDA :

# %%
# number of topics per cluster
NUM_TOPICS_PER_CLUSTER = 6

lda_models = []
for ii in range(0, 5):
    # Latent Dirichlet Allocation Model
    lda = LatentDirichletAllocation(n_components=NUM_TOPICS_PER_CLUSTER, max_iter=10, learning_method='online',verbose=False, random_state=42)
    lda_models.append(lda)

# %% [markdown]
# For each cluster, we had created a correspoding LDA model in the previous step. We will now fit_transform all the LDA models on their respective cluster vectors

# %%
clusters_lda_data = []

for current_cluster, lda in enumerate(lda_models):
    # print("Current Cluster: " + str(current_cluster))
    
    if vectorized_data[current_cluster] != None:
        clusters_lda_data.append((lda.fit_transform(vectorized_data[current_cluster])))

# %% [markdown]
# Extracts the keywords from each cluster

# %%
# Functions for printing keywords for each topic
def selected_topics(model, vectorizer, top_n=20):
    current_words = []
    keywords = []
    
    for idx, topic in enumerate(model.components_):
        words = [(vectorizer.get_feature_names()[i], topic[i]) for i in topic.argsort()[:-top_n - 1:-1]]
        for word in words:
            if word[0] not in current_words:
                keywords.append(word)
                current_words.append(word[0])
                
    keywords.sort(key = lambda x: x[1])  
    keywords.reverse()
    return_values = []
    for ii in keywords:
        return_values.append(ii[0])
    return return_values

# %% [markdown]
# Append list of keywords for a single cluster to 2D list of length NUM_TOPICS_PER_CLUSTER

# %%
all_keywords = []
for current_vectorizer, lda in enumerate(lda_models):
    # print("Current Cluster: " + str(current_vectorizer))

    if vectorized_data[current_vectorizer] != None:
        all_keywords.append(selected_topics(lda, vectorizers[current_vectorizer]))

# %%
for i in range(0,5):
    print(all_keywords[i])
# Out:
# ['cell', 'response', 'immune', 'treatment', 'human', 'compound', 'rna', 'drug', 'acute', 'spike', 'syndrome', 'therapeutic', 'bind', 'variant', 'host', 'associate', 'cov', 'mutation', 'cytokine', 'inflammatory', 'replication', 'sequence', 'lung', 'ace', 'viral', 'expression', 'increase', 'antibody', 'cause', 'therapy', 'genome', 'base', 'pro', 'protease', 'review', 'tissue', 'entry', 'molecular', 'receptor', 'angiotensin', 'rbd', 'virus', 'inhibitor', 'protein', 'effect', 'gene', 'factor', 'mechanism', 'dock', 'plasma', 'use', 'anti', 'effective', 'coronaviruse', 'treat', 'orf', 'analysis', 'potential', 'region', 'domain', 'interaction', 'screen', 'identify', 'target', 'molecule', 'main', 'activity', 'energy', 'antiviral', 'hla', 'dna', 'antigen', 'severity', 'non', 'subject', 'gut', 'functional', 'map', 'moderate', 'injection', 'low', 'immunity', 'reactivity', 'background', 'frequency', 'micrornas', 'ligand']
# ['level', 'day', 'group', 'icu', 'hospital', 'treatment', 'severity', 'significantly', 'rate', 'positive', 'admission', 'laboratory', 'associate', 'factor', 'analysis', 'datum', 'ventilation', 'trial', 'control', 'age', 'acute', 'mortality', 'aki', 'effect', 'cohort', 'care', 'meta', 'mechanical', 'participant', 'diabetes', 'death', 'symptom', 'admit', 'year', 'require', 'period', 'woman', 'time', 'intensive', 'aor', 'receive', 'increase', 'report', 'individual', 'outcome', 'survey', 'conclusion', 'compare', 'ratio', 'population', 'score', 'odd', 'test', 'measure', 'regression', 'mental', 'low', 'review', 'adjust', 'pool', 'significant', 'therapy', 'randomize', 'search', 'visit', 'outpatient', 'person', 'anosmia', 'era', 'follow', 'cough', 'covid', 'smell', 'taste', 'month', 'dysfunction', 'headache', 'olfactory', 'median', 'telephone', 'prevalence']
# ['care', 'country', 'acute', 'anxiety', 'measure', 'mental', 'model', 'treatment', 'low', 'datum', 'spread', 'service', 'healthcare', 'stress', 'review', 'medical', 'income', 'public', 'work', 'lockdown', 'number', 'control', 'relate', 'child', 'social', 'experience', 'depression', 'practice', 'psychological', 'hospital', 'level', 'government', 'period', 'need', 'worker', 'evidence', 'outbreak', 'research', 'participant', 'associate', 'score', 'decrease', 'student', 'symptom', 'increase', 'virus', 'support', 'effect', 'middle', 'impact', 'management', 'staff', 'survey', 'factor', 'nurse', 'policy', 'report', 'world', 'state', 'cause', 'provide', 'death', 'online', 'life', 'phase', 'access', 'community', 'change', 'program', 'develop', 'base', 'rate', 'cancer', 'article', 'present', 'syndrome', 'therapy', 'compare', 'recover', 'new', 'mortality', 'literature', 'day', 'activity', 'recovery', 'viral', 'time', 'tocilizumab', 'surgery', 'treat', 'trial', 'transmission', 'woman', 'significant', 'year', 'emergency', 'air', 'parent', 'reduction', 'physical']
# ['sample', 'chest', 'image', 'assay', 'detection', 'lung', 'test', 'pcr', 'pneumonia', 'detect', 'virus', 'sensitivity', 'model', 'igm', 'feature', 'diagnosis', 'rna', 'rapid', 'viral', 'swab', 'symptom', 'diagnostic', 'opacity', 'positive', 'time', 'base', 'scan', 'propose', 'day', 'acute', 'score', 'reaction', 'syndrome', 'report', 'group', 'year', 'evaluate', 'negative', 'anti', 'response', 'child', 'hcw', 'serum', 'specific', 'prevalence', 'serological', 'worker', 'asymptomatic', 'population', 'antibody', 'healthcare', 'participant', 'seroprevalence', 'hospital', 'woman', 'pregnant', 'positivity', 'estimate', 'igg', 'exposure', 'blood', 'donor', 'plasma', 'elisa', 'rbd', 'neutralization', 'tissue', 'convalescent', 'biosensor', 'titer', 'correlate', 'neutralize', 'use', 'october', 'activity', 'concentration', 'significantly', 'potential', 'december', 'november', 'rate', 'crucial', 'antigen', 'review', 'million', 'modality', 'month', 'protein', 'continue', 'currently', 'importance', 'public', 'category', 'mri', 'exponential']
# ['variant', 'antibody', 'cell', 'trial', 'receive', 'dose', 'spike', 'effect', 'increase', 'report', 'public', 'development', 'neutralize', 'influenza', 'induce', 'hesitancy', 'syndrome', 'acute', 'candidate', 'virus', 'survey', 'protein', 'conclusion', 'immune', 'reaction', 'challenge', 'drug', 'attitude', 'develop', 'mrna', 'effective', 'woman', 'use', 'technology', 'response', 'efficacy', 'cause', 'viral', 'cancer', 'phase', 'safety', 'participant', 'research', 'death', 'recipient', 'impact', 'student', 'base', 'country', 'present', 'willingness', 'low', 'respondent', 'year', 'factor', 'acceptance', 'association', 'female', 'uptake', 'willing', 'perception', 'vaccinate', 'child', 'likely', 'point', 'vaccination', 'incidence', 'reduce', 'scenario', 'model', 'level', 'group', 'age', 'rate', 'recommendation', 'strategy', 'concern', 'associate', 'transmission', 'social', 'mortality', 'effectiveness', 'population', 'belief']

# %%
for num_clus in range(0,5):
    print("*************Cluster ",num_clus,"*********************")
    str1 = ','.join(all_keywords[num_clus])
    doc = nlp(str1)
    print(str1)
    print("-------------------------------------------")
    TERM_LIST = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
    print("TERM_LIST : " ,TERM_LIST )
    print("")
# Out:
# *************Cluster  0 *********************
# cell,response,immune,treatment,human,compound,rna,drug,acute,spike,syndrome,therapeutic,bind,variant,host,associate,cov,mutation,cytokine,inflammatory,replication,sequence,lung,ace,viral,expression,increase,antibody,cause,therapy,genome,base,pro,protease,review,tissue,entry,molecular,receptor,angiotensin,rbd,virus,inhibitor,protein,effect,gene,factor,mechanism,dock,plasma,use,anti,effective,coronaviruse,treat,orf,analysis,potential,region,domain,interaction,screen,identify,target,molecule,main,activity,energy,antiviral,hla,dna,antigen,severity,non,subject,gut,functional,map,moderate,injection,low,immunity,reactivity,background,frequency,micrornas,ligand
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  1 *********************
# level,day,group,icu,hospital,treatment,severity,significantly,rate,positive,admission,laboratory,associate,factor,analysis,datum,ventilation,trial,control,age,acute,mortality,aki,effect,cohort,care,meta,mechanical,participant,diabetes,death,symptom,admit,year,require,period,woman,time,intensive,aor,receive,increase,report,individual,outcome,survey,conclusion,compare,ratio,population,score,odd,test,measure,regression,mental,low,review,adjust,pool,significant,therapy,randomize,search,visit,outpatient,person,anosmia,era,follow,cough,covid,smell,taste,month,dysfunction,headache,olfactory,median,telephone,prevalence
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  2 *********************
# care,country,acute,anxiety,measure,mental,model,treatment,low,datum,spread,service,healthcare,stress,review,medical,income,public,work,lockdown,number,control,relate,child,social,experience,depression,practice,psychological,hospital,level,government,period,need,worker,evidence,outbreak,research,participant,associate,score,decrease,student,symptom,increase,virus,support,effect,middle,impact,management,staff,survey,factor,nurse,policy,report,world,state,cause,provide,death,online,life,phase,access,community,change,program,develop,base,rate,cancer,article,present,syndrome,therapy,compare,recover,new,mortality,literature,day,activity,recovery,viral,time,tocilizumab,surgery,treat,trial,transmission,woman,significant,year,emergency,air,parent,reduction,physical
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  3 *********************
# sample,chest,image,assay,detection,lung,test,pcr,pneumonia,detect,virus,sensitivity,model,igm,feature,diagnosis,rna,rapid,viral,swab,symptom,diagnostic,opacity,positive,time,base,scan,propose,day,acute,score,reaction,syndrome,report,group,year,evaluate,negative,anti,response,child,hcw,serum,specific,prevalence,serological,worker,asymptomatic,population,antibody,healthcare,participant,seroprevalence,hospital,woman,pregnant,positivity,estimate,igg,exposure,blood,donor,plasma,elisa,rbd,neutralization,tissue,convalescent,biosensor,titer,correlate,neutralize,use,october,activity,concentration,significantly,potential,december,november,rate,crucial,antigen,review,million,modality,month,protein,continue,currently,importance,public,category,mri,exponential
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  4 *********************
# variant,antibody,cell,trial,receive,dose,spike,effect,increase,report,public,development,neutralize,influenza,induce,hesitancy,syndrome,acute,candidate,virus,survey,protein,conclusion,immune,reaction,challenge,drug,attitude,develop,mrna,effective,woman,use,technology,response,efficacy,cause,viral,cancer,phase,safety,participant,research,death,recipient,impact,student,base,country,present,willingness,low,respondent,year,factor,acceptance,association,female,uptake,willing,perception,vaccinate,child,likely,point,vaccination,incidence,reduce,scenario,model,level,group,age,rate,recommendation,strategy,concern,associate,transmission,social,mortality,effectiveness,population,belief
# -------------------------------------------
# TERM_LIST :  []

# %% [markdown]
# # Topic modeling on each cluster using NMF :

# %%
# number of topics per cluster
NUM_TOPICS_PER_CLUSTER = 6

nmf_models = []
for ii in range(0, 5):
    # nmf
    nmf = NMF(n_components=NUM_TOPICS_PER_CLUSTER, random_state=1,alpha=.1, l1_ratio=.5)
    nmf_models.append(nmf)
    
nmf_models[0]
# Out:
# NMF(alpha=0.1, l1_ratio=0.5, n_components=6, random_state=1)

# %%
clusters_nmf_data = []

for current_cluster, nmf in enumerate(nmf_models):
    print("Current Cluster: " + str(current_cluster))
    if vectorized_data[current_cluster] != None:
        clusters_nmf_data.append((nmf.fit_transform(vectorized_data[current_cluster])))
# Out:
# Current Cluster: 0
# C:\Users\Seyf_GOUMEIDA\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Seyf_GOUMEIDA\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# Current Cluster: 1
# Current Cluster: 2
# C:\Users\Seyf_GOUMEIDA\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# C:\Users\Seyf_GOUMEIDA\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"
# Current Cluster: 3
# Current Cluster: 4
# C:\Users\Seyf_GOUMEIDA\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1076: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"

# %%
# Functions for printing keywords for each topic
def selected_topics(model, vectorizer, top_n=20):
    current_words = []
    keywords = []
    
    for idx, topic in enumerate(model.components_):
        words = [(vectorizer.get_feature_names()[i], topic[i]) for i in topic.argsort()[:-top_n - 1:-1]]
        for word in words:
            if word[0] not in current_words:
                keywords.append(word)
                current_words.append(word[0])
                
    keywords.sort(key = lambda x: x[1])  
    keywords.reverse()
    return_values = []
    for ii in keywords:
        return_values.append(ii[0])
    return return_values

# %%
all_keywords = []
for current_vectorizer, nmf in enumerate(nmf_models):
    # print("Current Cluster: " + str(current_vectorizer))
    if vectorized_data[current_vectorizer] != None:
        all_keywords.append(selected_topics(nmf, vectorizers[current_vectorizer]))

# %%
for i in range(0,5):
    print(all_keywords[i])
# Out:
# ['cell', 'protein', 'drug', 'ace', 'virus', 'compound', 'cytokine', 'inflammatory', 'spike', 'angiotensin', 'antiviral', 'target', 'potential', 'pro', 'treatment', 'rna', 'inhibitor', 'bind', 'convert', 'interaction', 'activity', 'identify', 'protease', 'base', 'cov', 'rbd', 'orf', 'enzyme', 'molecular', 'therapeutic', 'sequence', 'screen', 'therapy', 'expression', 'review', 'effective', 'structural', 'storm', 'animal', 'genome', 'role', 'mers', 'main', 'host', 'dock', 'il-', 'gene', 'level', 'anti', 'cause', 'syndrome', 'candidate', 'domain', 'acute', 'variant', 'transmission', 'viral', 'response', 'spread', 'replication', 'lung', 'acid', 'mutation', 'immune', 'analysis', 'effect', 'infect', 'increase', 'human', 'epithelial', 'site', 'receptor', 'antibody', 'express', 'observe', 'cellular', 'induce', 'specific', 'line', 'entry', 'associate', 'antigen', 'tmprss']
# ['mortality', 'group', 'day', 'covid', 'era', 'icu', 'visit', 'admission', 'person', 'acute', 'hospital', 'rate', 'analysis', 'symptom', 'treatment', 'outcome', 'age', 'telephone', 'control', 'follow', 'trial', 'admit', 'compare', 'death', 'increase', 'pre', 'associate', 'participant', 'protocol', 'stay', 'ratio', 'positive', 'time', 'significantly', 'discharge', 'report', 'syndrome', 'model', 'woman', 'receive', 'intensive', 'odd', 'level', 'cohort', 'score', 'difference', 'identify', 'unit', 'adult', 'child', 'conclusion', 'ventilation', 'mechanical', 'country', 'therapy', 'length', 'factor', 'evaluate', 'efficacy', 'daily', 'relate', 'non', 'significant', 'test', 'association', 'pneumonia', 'datum', 'measure', 'year', 'meta', 'use', 'medication', 'il-', 'period', 'respectively', 'dexamethasone', 'serum', 'care', 'cardiovascular', 'low', 'order', 'hispanic', 'comparison', 'ambulatory', 'black', 'characteristic', 'decrease', 'december', 'clinician']
# ['care', 'student', 'anxiety', 'social', 'model', 'lockdown', 'stress', 'period', 'increase', 'depression', 'datum', 'mental', 'country', 'symptom', 'learn', 'spread', 'online', 'physical', 'activity', 'measure', 'change', 'transmission', 'child', 'virus', 'control', 'compare', 'education', 'hospital', 'base', 'decrease', 'behavior', 'outbreak', 'level', 'adult', 'analysis', 'psychological', 'service', 'relate', 'emergency', 'population', 'scale', 'life', 'use', 'epidemic', 'time', 'old', 'people', 'public', 'practice', 'visit', 'score', 'factor', 'number', 'need', 'rate', 'different', 'school', 'nurse', 'associate', 'test', 'provide', 'work', 'significant', 'woman', 'program', 'university', 'support', 'group', 'month', 'face', 'teach', 'report', 'conclusion', 'disorder', 'march', 'medical', 'experience', 'questionnaire', 'treatment', 'challenge', 'survey', 'management', 'professional', 'participant', 'staff', 'healthcare', 'telehealth', 'worker', 'year', 'course', 'academic', 'telemedicine', 'dental', 'develop', 'impact']
# ['test', 'pcr', 'antibody', 'igg', 'image', 'model', 'negative', 'igm', 'opacity', 'virus', 'propose', 'pneumonia', 'detect', 'accuracy', 'rna', 'feature', 'ground', 'anti', 'ray', 'assay', 'glass', 'viral', 'network', 'dataset', 'swab', 'response', 'group', 'sensitivity', 'serum', 'diagnosis', 'consolidation', 'syndrome', 'cxr', 'specific', 'reaction', 'polymerase', 'chain', 'chest', 'protein', 'laboratory', 'lung', 'deep', 'learn', 'pulmonary', 'lobe', 'year', 'range', 'classification', 'score', 'qpcr', 'rbd', 'child', 'detection', 'time', 'diagnostic', 'specimen', 'neural', 'severity', 'day', 'achieve', 'radiograph', 'collect', 'positive', 'antigen', 'symptom', 'volume', 'scan', 'compare', 'elisa', 'sequence', 'cohort', 'serological', 'base', 'specificity', 'reverse', 'target', 'iga', 'rapid', 'report', 'rate', 'sample', 'conclusion', 'pool', 'evaluate', 'datum', 'hospital', 'gene', 'acute', 'level', 'bind', 'number', 'strategy', 'care', 'low', 'performance', 'need', 'control', 'value', 'use']
# ['vaccination', 'cancer', 'cell', 'cohort', 'anti', 'variant', 'phase', 'receive', 'subject', 'regimen', 'dose', 'response', 'report', 'adverse', 'test', 'development', 'rbd', 'event', 'igg', 'placebo', 'virus', 'efficacy', 'production', 'public', 'antibody', 'syndrome', 'second', 'participant', 'covid', 'healthcare', 'trial', 'spike', 'acute', 'increase', 'vaccinate', 'safety', 'population', 'protein', 'technology', 'drug', 'candidate', 'use', 'confirm', 'viral', 'randomize', 'induce', 'develop', 'neutralize', 'challenge', 'recipient', 'treatment', 'day', 'age', 'immune', 'ratio', 'new', 'effect', 'factor', 'influenza', 'work', 'help', 'survey', 'rate', 'incidence', 'mrna', 'hesitancy', 'level', 'antigen', 'attitude', 'healthy', 'adult', 'bnt', 'conclusion', 'approximately', 'effective', 'type', 'produce', 'different', 'titer', 'willingness', 'approval', 'situation', 'reduce', 'individual', 'group', 'associate', 'specific', 'impact', 'fold', 'respectively', 'control', 'cov']

# %% [markdown]
# ## travail realisé :
#  - detection automatique des noms de maladies
#  - construction d'un corpus en utilisant les noms des maladies detectés

# %%
for num_clus in range(0,5):
    print("*************Cluster ",num_clus,"*********************")
    str1 = ','.join(all_keywords[num_clus])
    doc = nlp(str1)
    print(str1)
    print("-------------------------------------------")
    TERM_LIST = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
    print("TERM_LIST : " ,TERM_LIST )
    print("")
# Out:
# *************Cluster  0 *********************
# cell,protein,drug,ace,virus,compound,cytokine,inflammatory,spike,angiotensin,antiviral,target,potential,pro,treatment,rna,inhibitor,bind,convert,interaction,activity,identify,protease,base,cov,rbd,orf,enzyme,molecular,therapeutic,sequence,screen,therapy,expression,review,effective,structural,storm,animal,genome,role,mers,main,host,dock,il-,gene,level,anti,cause,syndrome,candidate,domain,acute,variant,transmission,viral,response,spread,replication,lung,acid,mutation,immune,analysis,effect,infect,increase,human,epithelial,site,receptor,antibody,express,observe,cellular,induce,specific,line,entry,associate,antigen,tmprss
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  1 *********************
# mortality,group,day,covid,era,icu,visit,admission,person,acute,hospital,rate,analysis,symptom,treatment,outcome,age,telephone,control,follow,trial,admit,compare,death,increase,pre,associate,participant,protocol,stay,ratio,positive,time,significantly,discharge,report,syndrome,model,woman,receive,intensive,odd,level,cohort,score,difference,identify,unit,adult,child,conclusion,ventilation,mechanical,country,therapy,length,factor,evaluate,efficacy,daily,relate,non,significant,test,association,pneumonia,datum,measure,year,meta,use,medication,il-,period,respectively,dexamethasone,serum,care,cardiovascular,low,order,hispanic,comparison,ambulatory,black,characteristic,decrease,december,clinician
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  2 *********************
# care,student,anxiety,social,model,lockdown,stress,period,increase,depression,datum,mental,country,symptom,learn,spread,online,physical,activity,measure,change,transmission,child,virus,control,compare,education,hospital,base,decrease,behavior,outbreak,level,adult,analysis,psychological,service,relate,emergency,population,scale,life,use,epidemic,time,old,people,public,practice,visit,score,factor,number,need,rate,different,school,nurse,associate,test,provide,work,significant,woman,program,university,support,group,month,face,teach,report,conclusion,disorder,march,medical,experience,questionnaire,treatment,challenge,survey,management,professional,participant,staff,healthcare,telehealth,worker,year,course,academic,telemedicine,dental,develop,impact
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  3 *********************
# test,pcr,antibody,igg,image,model,negative,igm,opacity,virus,propose,pneumonia,detect,accuracy,rna,feature,ground,anti,ray,assay,glass,viral,network,dataset,swab,response,group,sensitivity,serum,diagnosis,consolidation,syndrome,cxr,specific,reaction,polymerase,chain,chest,protein,laboratory,lung,deep,learn,pulmonary,lobe,year,range,classification,score,qpcr,rbd,child,detection,time,diagnostic,specimen,neural,severity,day,achieve,radiograph,collect,positive,antigen,symptom,volume,scan,compare,elisa,sequence,cohort,serological,base,specificity,reverse,target,iga,rapid,report,rate,sample,conclusion,pool,evaluate,datum,hospital,gene,acute,level,bind,number,strategy,care,low,performance,need,control,value,use
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  4 *********************
# vaccination,cancer,cell,cohort,anti,variant,phase,receive,subject,regimen,dose,response,report,adverse,test,development,rbd,event,igg,placebo,virus,efficacy,production,public,antibody,syndrome,second,participant,covid,healthcare,trial,spike,acute,increase,vaccinate,safety,population,protein,technology,drug,candidate,use,confirm,viral,randomize,induce,develop,neutralize,challenge,recipient,treatment,day,age,immune,ratio,new,effect,factor,influenza,work,help,survey,rate,incidence,mrna,hesitancy,level,antigen,attitude,healthy,adult,bnt,conclusion,approximately,effective,type,produce,different,titer,willingness,approval,situation,reduce,individual,group,associate,specific,impact,fold,respectively,control,cov
# -------------------------------------------
# TERM_LIST :  []

# %%
from Bio import Entrez
from Bio import Medline
import json


MAX_COUNT = 3
for TERM in ten_diseases:
    Entrez.email = 'A.N.Other@example.com'
    h = Entrez.esearch(db='pubmed', retmax=MAX_COUNT, term=TERM)
    result = Entrez.read(h)
    ids = result['IdList']
    h = Entrez.efetch(db='pubmed', id=ids, rettype='medline', retmode='json')
    records = Medline.parse(h)
    i=0
    for record in records:
        filename="fichier_"+TERM+str(i)+".json"
        json.dump(record, open(".\\new_corpus\\"+filename, 'w'))
        data = json.load(open(".\\new_corpus\\"+filename))
        i=i+1
[(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
# Out:
# [('second', 193, 199, 'ORDINAL')]

# %%
len(all_keywords)
# Out:
# 5
