# %% [markdown]
#  ## Remarque :
#         - L'execution ( les résultats ) affichés ne convient pas avec les données parceque on a changé le nombres de fichiers Json utilisés avant qu'on vous transmet le projet .
#         - il faut reéxecuter le code avec le nombre de fichiers souhaités pour avoir des bons résultat
#         - les parties ambigué et la ou on a trouvé des problems on les a marqué par des commentaires
#
# #//////////////////////////////////////////////////////////////
#
# #//////////////////////////////////////////////////////////////
#
# #//////////////////////////////////////////////////////////////
#
# #les remarque sont écrit de cette forme
#
# #//////////////////////////////////////////////////////////////
#
# #//////////////////////////////////////////////////////////////
#
# #//////////////////////////////////////////////////////////////

# %% [markdown]
# # COVID-19 Literature Clustering

# %% [markdown]
# # Table of Contents
# 1. Loading the data
# 2. Pre-processing
# 3. Vectorization
# 4. PCA  & Clustering
# 5. Dimensionality Reduction with t-SNE
# 6. Topic Modeling on Each Cluster
# 7. Classify
# 8. Plot
# 9. How to Use the Plot?
# 10. Conclusion
# 11. Citation/Sources
#
# <br>

# %% [markdown]
# # Loading the Data
#
#
# https://www.kaggle.com/allen-institute-for-ai/CORD-19-research-challenge

# %% [markdown]
# ### Loading Metadata

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import glob
import json

import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# Let's load the metadata of the dateset. 'title' and 'journal' attributes may be useful later when we cluster the articles to see what kinds of articles cluster together.

# %%
#root_path = 'C:/Users/Seyf_GOUMEIDA/Documents/GitHub/archive'
root_path = 'C:/Users/moham/Downloads/archive'

metadata_path = f'{root_path}/metadata.csv'
meta_df = pd.read_csv(metadata_path, dtype={
    'pubmed_id': str,
    'Microsoft Academic Paper ID': str, 
    'doi': str
})
meta_df.head()
# Out:
# C:\Users\moham\anaconda3\envs\Data2\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1,5,13,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
# 2    Surfactant protein-D and pulmonary host defense           10.1186/rr19
# 3               Role of endothelin-1 in lung disease           10.1186/rr44
# 4  Gene expression in epithelial cells in respons...           10.1186/rr61
#
#       pmcid pubmed_id license  \
# 0  PMC35282  11472636   no-cc
# 1  PMC59543  11667967   no-cc
# 2  PMC59549  11667972   no-cc
# 3  PMC59574  11686871   no-cc
# 4  PMC59580  11686888   no-cc
#
#                                             abstract publish_time  \
# 0  OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1  Inflammatory diseases of the respiratory tract...   2000-08-15
# 2  Surfactant protein-D (SP-D) participates in th...   2000-08-25
# 3  Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22
# 4  Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11
#
#                                              authors         journal  mag_id  \
# 0                Madani, Tariq A; Al-Ghamdi, Aisha A  BMC Infect Dis     NaN
# 1  Vliet, Albert van der; Eiserich, Jason P; Cros...      Respir Res     NaN
# 2                                    Crouch, Erika C      Respir Res     NaN
# 3  Fagan, Karen A; McMurtry, Ivan F; Rodman, David M      Respir Res     NaN
# 4  Domachowske, Joseph B; Bonville, Cynthia A; Ro...      Respir Res     NaN
#
#   who_covidence_id arxiv_id  \
# 0              NaN      NaN
# 1              NaN      NaN
# 2              NaN      NaN
# 3              NaN      NaN
# 4              NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/d1aafb70c066a2068b027...
# 1  document_parses/pdf_json/6b0567729c2143a66d737...
# 2  document_parses/pdf_json/06ced00a5fc04215949aa...
# 3  document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4  document_parses/pdf_json/5f48792a5fa08bed9f560...
#
#                                pmc_json_files  \
# 0  document_parses/pmc_json/PMC35282.xml.json
# 1  document_parses/pmc_json/PMC59543.xml.json
# 2  document_parses/pmc_json/PMC59549.xml.json
# 3  document_parses/pmc_json/PMC59574.xml.json
# 4  document_parses/pmc_json/PMC59580.xml.json
#
#                                                  url  s2_id
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    NaN
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN

# %%
meta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460771 entries, 0 to 460770
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   cord_uid          460771 non-null  object
#  1   sha               152653 non-null  object
#  2   source_x          460771 non-null  object
#  3   title             460542 non-null  object
#  4   doi               254544 non-null  object
#  5   pmcid             161593 non-null  object
#  6   pubmed_id         222669 non-null  object
#  7   license           460771 non-null  object
#  8   abstract          333018 non-null  object
#  9   publish_time      460550 non-null  object
#  10  authors           447591 non-null  object
#  11  journal           430100 non-null  object
#  12  mag_id            0 non-null       float64
#  13  who_covidence_id  188598 non-null  object
#  14  arxiv_id          6023 non-null    object
#  15  pdf_json_files    152653 non-null  object
#  16  pmc_json_files    121847 non-null  object
#  17  url               273795 non-null  object
#  18  s2_id             419707 non-null  float64
# dtypes: float64(2), object(17)
# memory usage: 66.8+ MB

# %% [markdown]
# ### Fetch All of JSON File Path

# %% [markdown]
# Get path to all JSON files:

# %%
all_json = glob.glob(f'{root_path}/**/*.json', recursive=True)
len(all_json)
# Out:
# 283714

# %% [markdown]
# ### Helper Functions

# %% [markdown]
#  #### File Reader Class

# %%
class FileReader:
    def __init__(self, file_path):
        with open(file_path) as file:
            content = json.load(file)
            self.paper_id = content['paper_id']
            self.abstract = []
            self.body_text = []
            # Abstract
            for entry in content['abstract']:
                self.abstract.append(entry['text'])
            # Body text
            for entry in content['body_text']:
                self.body_text.append(entry['text'])
            self.abstract = '\n'.join(self.abstract)
            self.body_text = '\n'.join(self.body_text)
    def __repr__(self):
        return f'{self.paper_id}: {self.abstract[:200]}... {self.body_text[:200]}...'
first_row = FileReader(all_json[0])
print(first_row)
# Out:
# 0000028b5cc154f68b8a269f6578f21e31f62977: ... According to current live statistics at the time of editing this letter, Russia has been the third country in the world to be affected by COVID-19 with both new cases and death rates rising. It remain...

# %% [markdown]
# Helper function adds break after every words when character length reach to certain amount. This is for the interactive plot so that hover tool fits the screen.

# %%
def get_breaks(content, length):
    data = ""
    words = content.split(' ')
    total_chars = 0

    # add break every length characters
    for i in range(len(words)):
        total_chars += len(words[i])
        if total_chars > length:
            data = data + "<br>" + words[i]
            total_chars = 0
        else:
            data = data + " " + words[i]
    return data

# %% [markdown]
# ### Load the Data into DataFrame

# %% [markdown]
# Using the helper functions, let's read in the articles into a DataFrame that can be used easily:

# %%
dict_ = {'paper_id': [], 'doi':[], 'abstract': [], 'body_text': [], 'authors': [], 'title': [], 'journal': [], 'abstract_summary': []}
for idx, entry in enumerate(all_json):
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
#ici on met le nombre des fichiers Json a selectionnés 
#avec 1000 ça prend un temps énorme pour s'executer
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
    if idx > 100:
        break
    if idx % (len(all_json) // 10) == 0:
        print(f'Processing index: {idx} of {len(all_json)}')
    
    try:
        content = FileReader(entry)
    except Exception as e:
        continue  # invalid paper format, skip
    
    # get metadata information
    meta_data = meta_df.loc[meta_df['sha'] == content.paper_id]
    # no metadata, skip this paper
    if len(meta_data) == 0:
        continue
    
    dict_['abstract'].append(content.abstract)
    dict_['paper_id'].append(content.paper_id)
    dict_['body_text'].append(content.body_text)
    
    # also create a column for the summary of abstract to be used in a plot
    if len(content.abstract) == 0: 
        # no abstract provided
        dict_['abstract_summary'].append("Not provided.")
    elif len(content.abstract.split(' ')) > 100:
        # abstract provided is too long for plot, take first 100 words append with ...
        info = content.abstract.split(' ')[:100]
        summary = get_breaks(' '.join(info), 40)
        dict_['abstract_summary'].append(summary + "...")
    else:
        # abstract is short enough
        summary = get_breaks(content.abstract, 40)
        dict_['abstract_summary'].append(summary)
        
    # get metadata information
    meta_data = meta_df.loc[meta_df['sha'] == content.paper_id]
    
    try:
        # if more than one author
        authors = meta_data['authors'].values[0].split(';')
        if len(authors) > 2:
            # if more than 2 authors, take them all with html tag breaks in between
            dict_['authors'].append(get_breaks('. '.join(authors), 40))
        else:
            # authors will fit in plot
            dict_['authors'].append(". ".join(authors))
    except Exception as e:
        # if only one author - or Null valie
        dict_['authors'].append(meta_data['authors'].values[0])
    
    # add the title information, add breaks when needed
    try:
        title = get_breaks(meta_data['title'].values[0], 40)
        dict_['title'].append(title)
    # if title was not provided
    except Exception as e:
        dict_['title'].append(meta_data['title'].values[0])
    
    # add the journal information
    dict_['journal'].append(meta_data['journal'].values[0])
    
    # add doi
    dict_['doi'].append(meta_data['doi'].values[0])
    
df_covid = pd.DataFrame(dict_, columns=['paper_id', 'doi', 'abstract', 'body_text', 'authors', 'title', 'journal', 'abstract_summary'])
df_covid.head()
# Out:
# Processing index: 0 of 283714
#                                    paper_id                           doi  \
# 0  0000028b5cc154f68b8a269f6578f21e31f62977             10.1002/bjs.11940
# 1  00006903b396d50cc0037fed39916d57d50ee801                           NaN
# 2  0000fcce604204b1b9d876dc073eb529eb5ce305    10.1016/j.regg.2021.01.002
# 3  000122a9a774ec76fa35ec0c0f6734e7e8d0c541     10.1016/j.rec.2020.08.002
# 4  0001418189999fea7f7cbe3e82703d71c85a6fe5  10.1016/j.vetmic.2006.11.026
#
#                                             abstract  \
# 0
# 1  Urban green space has been regarded as contrib...
# 2  Contribución de los autores: Rocío Menéndez Co...
# 3  Introduction and objectives: The COVID-19 outb...
# 4  Feline infectious peritonitis virus (FIPV) pos...
#
#                                            body_text  \
# 0  According to current live statistics at the ti...
# 1  The advantages of urban green space for public...
# 2  Se calcula que en España existen cerca de 367....
# 3  Introduction and objectives: The COVID-19 outb...
# 4  Feline infectious peritonitis (FIP) is a fatal...
#
#                                              authors  \
# 0   Tsarkov, Petr V..  Zubayraeva, Albina A.. <br...
# 1   Kwon, Oh-Hyun.  Hong, Inho.  Yang, Jeasurk. <...
# 2   Menéndez-Colino, Rocío.  Argentina,<br>France...
# 3   Rodríguez-Leor, Oriol.  Cid-Álvarez, Belén. <...
# 4   Cornelissen, E..  Dewerchin, H.L..  Van Hamme...
#
#                                                title  \
# 0    “Multi‐faceted” COVID‐19: Russian<br>experience
# 1   Urban green space and happiness in developed<...
# 2   La Geriatría de Enlace con residencias en la<...
# 3   Impact of COVID-19 on ST-segment elevation<br...
# 4   Absence of surface expression of feline<br>in...
#
#                      journal  \
# 0                  Br J Surg
# 1                        NaN
# 2   Rev Esp Geriatr Gerontol
# 3  Rev Esp Cardiol (Engl Ed)
# 4              Vet Microbiol
#
#                                     abstract_summary
# 0                                      Not provided.
# 1   Urban green space has been regarded as<br>con...
# 2   Contribución de los autores: Rocío Menéndez<b...
# 3   Introduction and objectives: The COVID-19<br>...
# 4   Feline infectious peritonitis virus (FIPV)<br...

# %% [markdown]
# ## Some feature engineering
# Adding word count columns for both abstract and body_text can be useful parameters later:

# %%
df_covid['abstract_word_count'] = df_covid['abstract'].apply(lambda x: len(x.strip().split()))  # word count in abstract
df_covid['body_word_count'] = df_covid['body_text'].apply(lambda x: len(x.strip().split()))  # word count in body
df_covid['body_unique_words']=df_covid['body_text'].apply(lambda x:len(set(str(x).split())))  # number of unique words in body
df_covid.head()
# Out:
#                                    paper_id                           doi  \
# 0  0000028b5cc154f68b8a269f6578f21e31f62977             10.1002/bjs.11940
# 1  00006903b396d50cc0037fed39916d57d50ee801                           NaN
# 2  0000fcce604204b1b9d876dc073eb529eb5ce305    10.1016/j.regg.2021.01.002
# 3  000122a9a774ec76fa35ec0c0f6734e7e8d0c541     10.1016/j.rec.2020.08.002
# 4  0001418189999fea7f7cbe3e82703d71c85a6fe5  10.1016/j.vetmic.2006.11.026
#
#                                             abstract  \
# 0
# 1  Urban green space has been regarded as contrib...
# 2  Contribución de los autores: Rocío Menéndez Co...
# 3  Introduction and objectives: The COVID-19 outb...
# 4  Feline infectious peritonitis virus (FIPV) pos...
#
#                                            body_text  \
# 0  According to current live statistics at the ti...
# 1  The advantages of urban green space for public...
# 2  Se calcula que en España existen cerca de 367....
# 3  Introduction and objectives: The COVID-19 outb...
# 4  Feline infectious peritonitis (FIP) is a fatal...
#
#                                              authors  \
# 0   Tsarkov, Petr V..  Zubayraeva, Albina A.. <br...
# 1   Kwon, Oh-Hyun.  Hong, Inho.  Yang, Jeasurk. <...
# 2   Menéndez-Colino, Rocío.  Argentina,<br>France...
# 3   Rodríguez-Leor, Oriol.  Cid-Álvarez, Belén. <...
# 4   Cornelissen, E..  Dewerchin, H.L..  Van Hamme...
#
#                                                title  \
# 0    “Multi‐faceted” COVID‐19: Russian<br>experience
# 1   Urban green space and happiness in developed<...
# 2   La Geriatría de Enlace con residencias en la<...
# 3   Impact of COVID-19 on ST-segment elevation<br...
# 4   Absence of surface expression of feline<br>in...
#
#                      journal  \
# 0                  Br J Surg
# 1                        NaN
# 2   Rev Esp Geriatr Gerontol
# 3  Rev Esp Cardiol (Engl Ed)
# 4              Vet Microbiol
#
#                                     abstract_summary  abstract_word_count  \
# 0                                      Not provided.                    0
# 1   Urban green space has been regarded as<br>con...                  191
# 2   Contribución de los autores: Rocío Menéndez<b...                  406
# 3   Introduction and objectives: The COVID-19<br>...                  286
# 4   Feline infectious peritonitis virus (FIPV)<br...                  165
#
#    body_word_count  body_unique_words
# 0              635                349
# 1             5040               1522
# 2             5021               1659
# 3             3508               1297
# 4             2071                756

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   paper_id             95 non-null     object
#  1   doi                  91 non-null     object
#  2   abstract             95 non-null     object
#  3   body_text            95 non-null     object
#  4   authors              94 non-null     object
#  5   title                95 non-null     object
#  6   journal              89 non-null     object
#  7   abstract_summary     95 non-null     object
#  8   abstract_word_count  95 non-null     int64
#  9   body_word_count      95 non-null     int64
#  10  body_unique_words    95 non-null     int64
# dtypes: int64(3), object(8)
# memory usage: 8.3+ KB

# %%
df_covid['abstract'].describe(include='all')
# Out:
# count     95
# unique    63
# top
# freq      33
# Name: abstract, dtype: object

# %% [markdown]
# ## Handle Possible Duplicates

# %% [markdown]
# When we look at the unique values above, we can see that tehre are duplicates. It may have caused because of author submiting the article to multiple journals. Let's remove the duplicats from our dataset:
#
# (Thank you Desmond Yeoh for recommending the below approach on Kaggle)

# %%
df_covid.drop_duplicates(['abstract', 'body_text'], inplace=True)
df_covid['abstract'].describe(include='all')
# Out:
# count     95
# unique    63
# top
# freq      33
# Name: abstract, dtype: object

# %%
df_covid['body_text'].describe(include='all')
# Out:
# count                                                    95
# unique                                                   95
# top       In order to foster the inclusion of blind and ...
# freq                                                      1
# Name: body_text, dtype: object

# %% [markdown]
# It looks like we didn't have duplicates. Instead, it was articles without Abstracts.

# %% [markdown]
# ## Take a Look at the Data:

# %%
df_covid.head()
# Out:
#                                    paper_id                           doi  \
# 0  0000028b5cc154f68b8a269f6578f21e31f62977             10.1002/bjs.11940
# 1  00006903b396d50cc0037fed39916d57d50ee801                           NaN
# 2  0000fcce604204b1b9d876dc073eb529eb5ce305    10.1016/j.regg.2021.01.002
# 3  000122a9a774ec76fa35ec0c0f6734e7e8d0c541     10.1016/j.rec.2020.08.002
# 4  0001418189999fea7f7cbe3e82703d71c85a6fe5  10.1016/j.vetmic.2006.11.026
#
#                                             abstract  \
# 0
# 1  Urban green space has been regarded as contrib...
# 2  Contribución de los autores: Rocío Menéndez Co...
# 3  Introduction and objectives: The COVID-19 outb...
# 4  Feline infectious peritonitis virus (FIPV) pos...
#
#                                            body_text  \
# 0  According to current live statistics at the ti...
# 1  The advantages of urban green space for public...
# 2  Se calcula que en España existen cerca de 367....
# 3  Introduction and objectives: The COVID-19 outb...
# 4  Feline infectious peritonitis (FIP) is a fatal...
#
#                                              authors  \
# 0   Tsarkov, Petr V..  Zubayraeva, Albina A.. <br...
# 1   Kwon, Oh-Hyun.  Hong, Inho.  Yang, Jeasurk. <...
# 2   Menéndez-Colino, Rocío.  Argentina,<br>France...
# 3   Rodríguez-Leor, Oriol.  Cid-Álvarez, Belén. <...
# 4   Cornelissen, E..  Dewerchin, H.L..  Van Hamme...
#
#                                                title  \
# 0    “Multi‐faceted” COVID‐19: Russian<br>experience
# 1   Urban green space and happiness in developed<...
# 2   La Geriatría de Enlace con residencias en la<...
# 3   Impact of COVID-19 on ST-segment elevation<br...
# 4   Absence of surface expression of feline<br>in...
#
#                      journal  \
# 0                  Br J Surg
# 1                        NaN
# 2   Rev Esp Geriatr Gerontol
# 3  Rev Esp Cardiol (Engl Ed)
# 4              Vet Microbiol
#
#                                     abstract_summary  abstract_word_count  \
# 0                                      Not provided.                    0
# 1   Urban green space has been regarded as<br>con...                  191
# 2   Contribución de los autores: Rocío Menéndez<b...                  406
# 3   Introduction and objectives: The COVID-19<br>...                  286
# 4   Feline infectious peritonitis virus (FIPV)<br...                  165
#
#    body_word_count  body_unique_words
# 0              635                349
# 1             5040               1522
# 2             5021               1659
# 3             3508               1297
# 4             2071                756

# %% [markdown]
# In the majority of this notebook we will be working with **body_text** <br>
# Links to the papers will be generated using **doi**

# %%
df_covid.describe()
# Out:
#        abstract_word_count  body_word_count  body_unique_words
# count            95.000000        95.000000          95.000000
# mean            131.484211      3393.957895        1145.484211
# std             142.092782      2371.087509         615.332964
# min               0.000000       371.000000         234.000000
# 25%               0.000000      1732.500000         721.000000
# 50%             107.000000      2822.000000        1056.000000
# 75%             216.000000      4424.500000        1441.500000
# max             722.000000     12451.000000        3590.000000

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ### Réduction de la taille du dataset :

# %% [markdown]
# Unfortunately, running the next steps of the notebook is not possible on the full dataset within Kaggle. The full plot is available is at https://maksimekin.github.io/COVID19-Literature-Clustering/plots/t-sne_covid-19_interactive.html.
#
# In Kaggle we will limit the dataframe to **10,000** instances

# %%
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
#ici on choisit 80 fichiers entre les 100 qui sont déja lus 
# si on change le 100 en haut en doit changer aussi le nmbr des samples ici 
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////

#df = df_covid.sample(4000, random_state=42)
#del df_covid
df = df_covid

# %% [markdown]
# ### Suppression des valeurs null :

# %% [markdown]
# Now that we have our dataset loaded, we need to clean-up the text to improve any clustering or classification efforts. First, let's drop Null vales:

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88 entries, 0 to 94
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   paper_id             88 non-null     object
#  1   doi                  88 non-null     object
#  2   abstract             88 non-null     object
#  3   body_text            88 non-null     object
#  4   authors              88 non-null     object
#  5   title                88 non-null     object
#  6   journal              88 non-null     object
#  7   abstract_summary     88 non-null     object
#  8   abstract_word_count  88 non-null     int64
#  9   body_word_count      88 non-null     int64
#  10  body_unique_words    88 non-null     int64
# dtypes: int64(3), object(8)
# memory usage: 8.2+ KB

# %% [markdown]
# ### Handling multiple languages
# Next we are going to determine the language of each paper in the dataframe. Not all of the sources are English and the language needs to be identified so that we know how handle these instances

# %%
from tqdm import tqdm
from langdetect import detect
from langdetect import DetectorFactory

# set seed
DetectorFactory.seed = 0

# hold label - language
languages = []

# go through each text
for ii in tqdm(range(0,len(df))):
    # split by space into list, take the first x intex, join with space
    text = df.iloc[ii]['body_text'].split(" ")
    
    lang = "en"
    try:
        if len(text) > 50:
            lang = detect(" ".join(text[:50]))
        elif len(text) > 0:
            lang = detect(" ".join(text[:len(text)]))
    # ught... beginning of the document was not in a good format
    except Exception as e:
        all_words = set(text)
        try:
            lang = detect(" ".join(all_words))
        # what!! :( let's see if we can find any text in abstract...
        except Exception as e:
            
            try:
                # let's try to label it through the abstract then
                lang = detect(df.iloc[ii]['abstract_summary'])
            except Exception as e:
                lang = "unknown"
                pass
    
    # get the language    
    languages.append(lang)
# Out:
# 100%|██████████| 88/88 [00:01<00:00, 47.09it/s]

# %%
from pprint import pprint

languages_dict = {}
for lang in set(languages):
    languages_dict[lang] = languages.count(lang)
    
print("Total: {}\n".format(len(languages)))
pprint(languages_dict)
# Out:
# Total: 88
#
# {'de': 2, 'en': 82, 'es': 3, 'fr': 1}

# %% [markdown]
# Lets take a look at the language distribution in the dataset

# %%
df['language'] = languages
plt.bar(range(len(languages_dict)), list(languages_dict.values()), align='center')
plt.xticks(range(len(languages_dict)), list(languages_dict.keys()))
plt.title("Distribution of Languages in Dataset")
plt.show()

# %% [markdown]
# We will be dropping any language that is not English. Attempting to translate foreign texts gave the following problems:
#
# 1. API calls were limited
#
# 2. Translating the language may not carry over the true semantic meaning of the text

# %%
df = df[df['language'] == 'en'] 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82 entries, 0 to 94
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   paper_id             82 non-null     object
#  1   doi                  82 non-null     object
#  2   abstract             82 non-null     object
#  3   body_text            82 non-null     object
#  4   authors              82 non-null     object
#  5   title                82 non-null     object
#  6   journal              82 non-null     object
#  7   abstract_summary     82 non-null     object
#  8   abstract_word_count  82 non-null     int64
#  9   body_word_count      82 non-null     int64
#  10  body_unique_words    82 non-null     int64
#  11  language             82 non-null     object
# dtypes: int64(3), object(9)
# memory usage: 8.3+ KB

# %%
#Download the spacy bio parser

from IPython.utils import io
# with io.capture_output() as captured:
#    !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_core_sci_lg-0.4.0.tar.gz

# %%
import spacy.cli
spacy.cli.download("en_core_web_lg")
import en_core_web_lg
nlp = en_core_web_lg.load()
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
#NLP 
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
import en_core_sci_lg  # model downloaded in previous step

# %% [markdown]
# ### Stopwords
#
# Part of the preprocessing will be finding and removing stopwords (common words that will act as noise in the clustering step).

# %%
import string

punctuations = string.punctuation
stopwords = list(STOP_WORDS)
stopwords
# Out:
# ['he',
#  'next',
#  'not',
#  '‘m',
#  'via',
#  'say',
#  'the',
#  'up',
#  'move',
#  'throughout',
#  'few',
#  'myself',
#  'besides',
#  'would',
#  'these',
#  'its',
#  'mine',
#  'keep',
#  'was',
#  'front',
#  'whatever',
#  'herein',
#  'beyond',
#  'somewhere',
#  'does',
#  'amount',
#  'just',
#  'whereupon',
#  'yourselves',
#  "n't",
#  '’d',
#  'off',
#  'anyone',
#  'himself',
#  'doing',
#  'ten',
#  'who',
#  'several',
#  'is',
#  'every',
#  'alone',
#  'towards',
#  'much',
#  'eight',
#  'wherever',
#  'how',
#  'but',
#  'be',
#  "'s",
#  'call',
#  'beforehand',
#  'further',
#  'here',
#  'she',
#  'below',
#  'if',
#  'really',
#  "'ll",
#  'being',
#  '‘s',
#  'and',
#  'even',
#  'whose',
#  'afterwards',
#  'i',
#  'neither',
#  'however',
#  'been',
#  'same',
#  'another',
#  'namely',
#  '’ll',
#  'all',
#  'nine',
#  'during',
#  'someone',
#  'will',
#  'over',
#  'because',
#  'since',
#  'see',
#  'seemed',
#  'themselves',
#  'now',
#  'sometimes',
#  'own',
#  'hundred',
#  'anyhow',
#  'did',
#  'could',
#  'meanwhile',
#  'side',
#  'behind',
#  'across',
#  'one',
#  'whether',
#  'due',
#  'of',
#  'seems',
#  'when',
#  'once',
#  'get',
#  'part',
#  '’s',
#  'yours',
#  'thereafter',
#  'until',
#  'whither',
#  'former',
#  'well',
#  'which',
#  'nor',
#  'thereby',
#  'fifteen',
#  'my',
#  'enough',
#  'they',
#  'as',
#  'regarding',
#  'your',
#  'has',
#  'somehow',
#  'it',
#  'each',
#  'go',
#  'became',
#  'hereby',
#  'never',
#  'have',
#  'him',
#  'whereafter',
#  'n‘t',
#  'an',
#  'else',
#  'formerly',
#  'should',
#  'some',
#  '‘ve',
#  'noone',
#  'whenever',
#  'while',
#  'nothing',
#  'or',
#  'please',
#  '’m',
#  'more',
#  'that',
#  'becomes',
#  'already',
#  'anywhere',
#  'serious',
#  'amongst',
#  'n’t',
#  'hers',
#  'any',
#  'thence',
#  'are',
#  'ca',
#  'his',
#  'whoever',
#  'onto',
#  'through',
#  'only',
#  'empty',
#  'less',
#  'least',
#  'though',
#  'still',
#  'per',
#  'must',
#  'toward',
#  'done',
#  'above',
#  'none',
#  'upon',
#  'something',
#  'last',
#  'back',
#  'twenty',
#  'fifty',
#  'for',
#  'me',
#  'down',
#  'latterly',
#  'ever',
#  'unless',
#  "'d",
#  'us',
#  'her',
#  'cannot',
#  'everyone',
#  'whence',
#  'using',
#  'what',
#  'about',
#  'had',
#  'indeed',
#  'among',
#  're',
#  'mostly',
#  'in',
#  'thru',
#  'four',
#  'anything',
#  "'ve",
#  'nowhere',
#  'almost',
#  'from',
#  'were',
#  'two',
#  'under',
#  'this',
#  '‘d',
#  'without',
#  'eleven',
#  'three',
#  '’re',
#  'rather',
#  'a',
#  'can',
#  'seeming',
#  'first',
#  'either',
#  '‘ll',
#  'at',
#  'sometime',
#  'wherein',
#  'becoming',
#  'again',
#  'yourself',
#  'them',
#  'why',
#  'very',
#  'hereafter',
#  'after',
#  'both',
#  'twelve',
#  'anyway',
#  'show',
#  'thereupon',
#  'there',
#  'no',
#  'everything',
#  'may',
#  'full',
#  'whereas',
#  'forty',
#  'beside',
#  'so',
#  'our',
#  'seem',
#  'third',
#  'to',
#  '‘re',
#  'on',
#  'others',
#  'whereby',
#  'herself',
#  'various',
#  'whom',
#  'yet',
#  'also',
#  'therein',
#  'moreover',
#  'put',
#  'give',
#  'many',
#  'name',
#  'whole',
#  'you',
#  "'re",
#  'made',
#  'hence',
#  'than',
#  'their',
#  'itself',
#  'become',
#  'do',
#  'by',
#  'then',
#  'into',
#  'latter',
#  'make',
#  'except',
#  'ours',
#  'where',
#  'take',
#  'around',
#  'along',
#  'nobody',
#  'sixty',
#  'against',
#  'most',
#  'might',
#  'before',
#  "'m",
#  'often',
#  'with',
#  'although',
#  'bottom',
#  'am',
#  'within',
#  'everywhere',
#  'always',
#  'we',
#  'elsewhere',
#  '’ve',
#  'other',
#  'six',
#  'otherwise',
#  'ourselves',
#  'between',
#  'five',
#  'top',
#  'used',
#  'such',
#  'out',
#  'hereupon',
#  'thus',
#  'nevertheless',
#  'quite',
#  'therefore',
#  'those',
#  'too',
#  'perhaps',
#  'together']

# %% [markdown]
# Now the above stopwords are used in everyday english text. Research papers will often frequently use words that don't actually contribute to the meaning and are not considered everyday stopwords.
#
# Thank you Daniel Wolffram for the idea.
# #### Cite: [Custom Stop Words | Topic Modeling: Finding Related Articles](https://www.kaggle.com/danielwolffram/topic-modeling-finding-related-articles)

# %%
custom_stop_words = [
    'doi', 'preprint', 'copyright', 'peer', 'reviewed', 'org', 'https', 'et', 'al', 'author', 'figure', 
    'rights', 'reserved', 'permission', 'used', 'using', 'biorxiv', 'medrxiv', 'license', 'fig', 'fig.', 
    'al.', 'Elsevier', 'PMC', 'CZI', 'www'
]

for w in custom_stop_words:
    if w not in stopwords:
        stopwords.append(w)

# %% [markdown]
# ### Next lets create a function that will process the text data for us.
# For this purpose we will be using the spacy library. This function will convert text to lower case, remove punctuation, and find and remove stopwords. For the parser, we will use en_core_sci_lg. This is a model for processing biomedical, scientific or clinical text.

# %%
# Parser
parser = en_core_sci_lg.load(disable=["tagger", "ner"])
parser.max_length = 7000000

def spacy_tokenizer(sentence):
    mytokens = parser(sentence)
    #mytokens = [ word.lemma.lower().strip() if word.pos_ != "-PRON-" else word.lower for word.text in mytokens ]
    #mytokens2 = [word.lemma_.lower().strip() for word in mytokens if word.pos_ != "PUNCT" and word.text not in stopwords]

    mytokens = [ word for word in mytokens if word not in stopwords and word.text not in punctuations ]
    mytokens = " ".join([i for i in mytokens])
    return mytokens

# %%
cat = 5
type(cat)
# Out:
# int

# %% [markdown]
# Applying the text-processing function on the **body_text**.

# %%
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
#c'est dans cette partie la que ça bug , ça prend un temps énorme et on a pas eu de résultat  
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
#//////////////////////////////////////////////////////////////
#tqdm.pandas()
#df["processed_text"] = df["body_text"].progress_apply(spacy_tokenizer)

# %%
import spacy
nlp = en_core_web_lg.load()
def spacy_process(texte):
    tmp = []
    tmp.append(texte)
    for lt in tmp:
        mytokens = nlp(lt)
        mytokens2 = [word.lemma_.lower().strip() for word in mytokens if word.pos_ != "PUNCT" and word.text not in stopwords]
        mytokens2 = " ".join([i for i in mytokens2])
    return mytokens2
df["processed_text"] = df["body_text"].apply(spacy_process)
#a = ['je suis la bonne personne et droit à la caricature.', 'Je suis la bonne personne et droit à la caricature.']
#return :  je suis la bonne personne et droit à la caricature
# Out:
# <ipython-input-33-f3ac0eca20f0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["processed_text"] = df["body_text"].apply(spacy_process)

# %%
df.head()
# Out:
#                                    paper_id                           doi  \
# 0  0000028b5cc154f68b8a269f6578f21e31f62977             10.1002/bjs.11940
# 3  000122a9a774ec76fa35ec0c0f6734e7e8d0c541     10.1016/j.rec.2020.08.002
# 4  0001418189999fea7f7cbe3e82703d71c85a6fe5  10.1016/j.vetmic.2006.11.026
# 5  00031cc15aafa30b187ed2cd3790e970e5046895             10.1159/000512683
# 6  00033d5a12240a8684cfe943954132b43434cf48             10.3390/v12080849
#
#                                             abstract  \
# 0
# 3  Introduction and objectives: The COVID-19 outb...
# 4  Feline infectious peritonitis virus (FIPV) pos...
# 5  Background: SARS-CoV-2 infection can cause ren...
# 6  Background: Amplification of viral ribonucleic...
#
#                                            body_text  \
# 0  According to current live statistics at the ti...
# 3  Introduction and objectives: The COVID-19 outb...
# 4  Feline infectious peritonitis (FIP) is a fatal...
# 5  increased serum creatinine, variable degrees o...
# 6  Severe acute respiratory syndrome coronavirus ...
#
#                                              authors  \
# 0   Tsarkov, Petr V..  Zubayraeva, Albina A.. <br...
# 3   Rodríguez-Leor, Oriol.  Cid-Álvarez, Belén. <...
# 4   Cornelissen, E..  Dewerchin, H.L..  Van Hamme...
# 5   Wang, Mo.  Xiong, Huaying.  Chen, Han.  Li, Q...
# 6   Wandernoth, Petra.  Kriegsmann, Katharina. <b...
#
#                                                title  \
# 0    “Multi‐faceted” COVID‐19: Russian<br>experience
# 3   Impact of COVID-19 on ST-segment elevation<br...
# 4   Absence of surface expression of feline<br>in...
# 5   Renal Injury by SARS-CoV-2 Infection: A<br>Sy...
# 6   Detection of Severe Acute Respiratory<br>Synd...
#
#                      journal  \
# 0                  Br J Surg
# 3  Rev Esp Cardiol (Engl Ed)
# 4              Vet Microbiol
# 5         Kidney Dis (Basel)
# 6                    Viruses
#
#                                     abstract_summary  abstract_word_count  \
# 0                                      Not provided.                    0
# 3   Introduction and objectives: The COVID-19<br>...                  286
# 4   Feline infectious peritonitis virus (FIPV)<br...                  165
# 5   Background: SARS-CoV-2 infection can cause<br...                   98
# 6   Background: Amplification of viral<br>ribonuc...                  224
#
#    body_word_count  body_unique_words language  \
# 0              635                349       en
# 3             3508               1297       en
# 4             2071                756       en
# 5             4220               1491       en
# 6             1899                835       en
#
#                                       processed_text
# 0  accord current live statistic time edit letter...
# 3  introduction objective the covid-19 outbreak u...
# 4  feline infectious peritonitis fip fatal chroni...
# 5  increase serum creatinine variable degree prot...
# 6  severe acute respiratory syndrome coronavirus ...

# %% [markdown]
# ### Removal of Frequent words
# So this step is to remove the frequent words in the given corpus. If we use something like tfidf, this is automatically taken care of.

# %%
from collections import Counter
cnt = Counter()
for text in df["processed_text"].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(40)
# Out:
# [('the', 1796),
#  ('patient', 1186),
#  ('-', 1151),
#  ('%', 972),
#  ('study', 886),
#  ('cell', 876),
#  ('covid-19', 769),
#  ('infection', 760),
#  ('in', 746),
#  ('virus', 685),
#  ('1', 638),
#  ('2', 623),
#  ('/', 597),
#  ('high', 592),
#  ('protein', 533),
#  ('sars', 526),
#  ('include', 508),
#  ('case', 506),
#  ('show', 494),
#  ('group', 494),
#  ('disease', 492),
#  ('result', 487),
#  ('risk', 478),
#  ('health', 465),
#  ('test', 461),
#  ('increase', 445),
#  ('c', 445),
#  ('this', 442),
#  ('time', 437),
#  ('3', 437),
#  ('sample', 397),
#  ('a', 391),
#  ('p', 390),
#  ('cov-2', 390),
#  ('viral', 386),
#  ('datum', 385),
#  ('report', 384),
#  ('level', 380),
#  ('day', 374),
#  ('response', 359)]

# %%
FREQWORDS = set([w for (w, wc) in cnt.most_common(30)])
def remove_freqwords(text):
    """custom function to remove the frequent words"""
    return " ".join([word for word in str(text).split() if word not in FREQWORDS])

df["text_wo_stopfreq"] = df["processed_text"].apply(lambda text: remove_freqwords(text))
# Out:
# <ipython-input-36-e97c1f8b22c9>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text_wo_stopfreq"] = df["processed_text"].apply(lambda text: remove_freqwords(text))

# %%
df["body_text"]
# Out:
# 0     According to current live statistics at the ti...
# 3     Introduction and objectives: The COVID-19 outb...
# 4     Feline infectious peritonitis (FIP) is a fatal...
# 5     increased serum creatinine, variable degrees o...
# 6     Severe acute respiratory syndrome coronavirus ...
#                             ...
# 88    In order to foster the inclusion of blind and ...
# 89    Worldwide, ovarian cancer has the worst progno...
# 90    Mucosal surfaces are prone to infection by man...
# 93    Public health, unlike medicine, is not about d...
# 94    A wide testing strategy is effective in detect...
# Name: body_text, Length: 82, dtype: object

# %%
df["text_wo_stopfreq"]
# Out:
# 0     accord current live statistic edit letter russ...
# 3     introduction objective outbreak unclear impact...
# 4     feline infectious peritonitis fip fatal chroni...
# 5     serum creatinine variable degree proteinuria h...
# 6     severe acute respiratory syndrome coronavirus ...
#                             ...
# 88    order foster inclusion blind visually impaired...
# 89    worldwide ovarian cancer bad prognosis mortali...
# 90    mucosal surface prone pathogen adequate protec...
# 93    public unlike medicine doctor treat individual...
# 94    a wide testing strategy effective detect asymp...
# Name: text_wo_stopfreq, Length: 82, dtype: object

# %%
df["processed_text"]
# Out:
# 0     accord current live statistic time edit letter...
# 3     introduction objective the covid-19 outbreak u...
# 4     feline infectious peritonitis fip fatal chroni...
# 5     increase serum creatinine variable degree prot...
# 6     severe acute respiratory syndrome coronavirus ...
#                             ...
# 88    in order foster inclusion blind visually impai...
# 89    worldwide ovarian cancer bad prognosis high mo...
# 90    mucosal surface prone infection pathogen adequ...
# 93    public health unlike medicine doctor treat ind...
# 94    a wide testing strategy effective detect asymp...
# Name: processed_text, Length: 82, dtype: object

# %% [markdown]
# ### Removal of Rare words
# This is very similar to previous preprocessing step but we will remove the rare words from the corpus.

# %%
#cnt.most_common()[:-500-1:-1]

# %%
# n_rare_words = 10
# RAREWORDS = set([w for (w, wc) in cnt.most_common()[:-n_rare_words-1:-1]])
# def remove_rarewords(text):
#     """custom function to remove the rare words"""
#     return " ".join([word for word in str(text).split() if word not in RAREWORDS])

# df["text_wo_stopfreqrare"] = df["text_wo_stopfreq"].apply(lambda text: remove_rarewords(text))
# df.head()

# %% [markdown]
# ### Lemmatization

# %% [markdown]
# Lemmatization is similar to stemming in reducing inflected words to their word stem but differs in the way that it makes sure the root word (also called as lemma) belongs to the language.

# %%
import nltk
#nltk.download('wordnet')

# %%
#from nltk.stem import WordNetLemmatizer
#lemmatizer = WordNetLemmatizer()
#def lemmatize_words(text):
#    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])#
#df["text_lemmatized"] = df["text_wo_stopfreq"].apply(lambda text: lemmatize_words(text))
#df.head()

# %% [markdown]
# Now let us redo the lemmatization process for our dataset.

# %%
nltk.download('averaged_perceptron_tagger')

# %%
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}
def lemmatize_words(text):
    pos_tagged_text = nltk.pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text])

df["text_lemmatized"] = df["text_wo_stopfreq"].apply(lambda text: lemmatize_words(text))
# Out:
# <ipython-input-44-a975cedaa34d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text_lemmatized"] = df["text_wo_stopfreq"].apply(lambda text: lemmatize_words(text))

# %%
df.head()
# Out:
#                                    paper_id                           doi  \
# 0  0000028b5cc154f68b8a269f6578f21e31f62977             10.1002/bjs.11940
# 3  000122a9a774ec76fa35ec0c0f6734e7e8d0c541     10.1016/j.rec.2020.08.002
# 4  0001418189999fea7f7cbe3e82703d71c85a6fe5  10.1016/j.vetmic.2006.11.026
# 5  00031cc15aafa30b187ed2cd3790e970e5046895             10.1159/000512683
# 6  00033d5a12240a8684cfe943954132b43434cf48             10.3390/v12080849
#
#                                             abstract  \
# 0
# 3  Introduction and objectives: The COVID-19 outb...
# 4  Feline infectious peritonitis virus (FIPV) pos...
# 5  Background: SARS-CoV-2 infection can cause ren...
# 6  Background: Amplification of viral ribonucleic...
#
#                                            body_text  \
# 0  According to current live statistics at the ti...
# 3  Introduction and objectives: The COVID-19 outb...
# 4  Feline infectious peritonitis (FIP) is a fatal...
# 5  increased serum creatinine, variable degrees o...
# 6  Severe acute respiratory syndrome coronavirus ...
#
#                                              authors  \
# 0   Tsarkov, Petr V..  Zubayraeva, Albina A.. <br...
# 3   Rodríguez-Leor, Oriol.  Cid-Álvarez, Belén. <...
# 4   Cornelissen, E..  Dewerchin, H.L..  Van Hamme...
# 5   Wang, Mo.  Xiong, Huaying.  Chen, Han.  Li, Q...
# 6   Wandernoth, Petra.  Kriegsmann, Katharina. <b...
#
#                                                title  \
# 0    “Multi‐faceted” COVID‐19: Russian<br>experience
# 3   Impact of COVID-19 on ST-segment elevation<br...
# 4   Absence of surface expression of feline<br>in...
# 5   Renal Injury by SARS-CoV-2 Infection: A<br>Sy...
# 6   Detection of Severe Acute Respiratory<br>Synd...
#
#                      journal  \
# 0                  Br J Surg
# 3  Rev Esp Cardiol (Engl Ed)
# 4              Vet Microbiol
# 5         Kidney Dis (Basel)
# 6                    Viruses
#
#                                     abstract_summary  abstract_word_count  \
# 0                                      Not provided.                    0
# 3   Introduction and objectives: The COVID-19<br>...                  286
# 4   Feline infectious peritonitis virus (FIPV)<br...                  165
# 5   Background: SARS-CoV-2 infection can cause<br...                   98
# 6   Background: Amplification of viral<br>ribonuc...                  224
#
#    body_word_count  body_unique_words language  \
# 0              635                349       en
# 3             3508               1297       en
# 4             2071                756       en
# 5             4220               1491       en
# 6             1899                835       en
#
#                                       processed_text  \
# 0  accord current live statistic time edit letter...
# 3  introduction objective the covid-19 outbreak u...
# 4  feline infectious peritonitis fip fatal chroni...
# 5  increase serum creatinine variable degree prot...
# 6  severe acute respiratory syndrome coronavirus ...
#
#                                     text_wo_stopfreq  \
# 0  accord current live statistic edit letter russ...
# 3  introduction objective outbreak unclear impact...
# 4  feline infectious peritonitis fip fatal chroni...
# 5  serum creatinine variable degree proteinuria h...
# 6  severe acute respiratory syndrome coronavirus ...
#
#                                      text_lemmatized
# 0  accord current live statistic edit letter russ...
# 3  introduction objective outbreak unclear impact...
# 4  feline infectious peritonitis fip fatal chroni...
# 5  serum creatinine variable degree proteinuria h...
# 6  severe acute respiratory syndrome coronavirus ...

# %% [markdown]
# ### Removal of URLs

# %%
import re
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

# %%
df["text_lemmatized_no_url"] = df["text_lemmatized"].apply(lambda text: remove_urls(text))
df.head()
# Out:
# <ipython-input-47-a38abe2b0ba1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text_lemmatized_no_url"] = df["text_lemmatized"].apply(lambda text: remove_urls(text))
#                                    paper_id                           doi  \
# 0  0000028b5cc154f68b8a269f6578f21e31f62977             10.1002/bjs.11940
# 3  000122a9a774ec76fa35ec0c0f6734e7e8d0c541     10.1016/j.rec.2020.08.002
# 4  0001418189999fea7f7cbe3e82703d71c85a6fe5  10.1016/j.vetmic.2006.11.026
# 5  00031cc15aafa30b187ed2cd3790e970e5046895             10.1159/000512683
# 6  00033d5a12240a8684cfe943954132b43434cf48             10.3390/v12080849
#
#                                             abstract  \
# 0
# 3  Introduction and objectives: The COVID-19 outb...
# 4  Feline infectious peritonitis virus (FIPV) pos...
# 5  Background: SARS-CoV-2 infection can cause ren...
# 6  Background: Amplification of viral ribonucleic...
#
#                                            body_text  \
# 0  According to current live statistics at the ti...
# 3  Introduction and objectives: The COVID-19 outb...
# 4  Feline infectious peritonitis (FIP) is a fatal...
# 5  increased serum creatinine, variable degrees o...
# 6  Severe acute respiratory syndrome coronavirus ...
#
#                                              authors  \
# 0   Tsarkov, Petr V..  Zubayraeva, Albina A.. <br...
# 3   Rodríguez-Leor, Oriol.  Cid-Álvarez, Belén. <...
# 4   Cornelissen, E..  Dewerchin, H.L..  Van Hamme...
# 5   Wang, Mo.  Xiong, Huaying.  Chen, Han.  Li, Q...
# 6   Wandernoth, Petra.  Kriegsmann, Katharina. <b...
#
#                                                title  \
# 0    “Multi‐faceted” COVID‐19: Russian<br>experience
# 3   Impact of COVID-19 on ST-segment elevation<br...
# 4   Absence of surface expression of feline<br>in...
# 5   Renal Injury by SARS-CoV-2 Infection: A<br>Sy...
# 6   Detection of Severe Acute Respiratory<br>Synd...
#
#                      journal  \
# 0                  Br J Surg
# 3  Rev Esp Cardiol (Engl Ed)
# 4              Vet Microbiol
# 5         Kidney Dis (Basel)
# 6                    Viruses
#
#                                     abstract_summary  abstract_word_count  \
# 0                                      Not provided.                    0
# 3   Introduction and objectives: The COVID-19<br>...                  286
# 4   Feline infectious peritonitis virus (FIPV)<br...                  165
# 5   Background: SARS-CoV-2 infection can cause<br...                   98
# 6   Background: Amplification of viral<br>ribonuc...                  224
#
#    body_word_count  body_unique_words language  \
# 0              635                349       en
# 3             3508               1297       en
# 4             2071                756       en
# 5             4220               1491       en
# 6             1899                835       en
#
#                                       processed_text  \
# 0  accord current live statistic time edit letter...
# 3  introduction objective the covid-19 outbreak u...
# 4  feline infectious peritonitis fip fatal chroni...
# 5  increase serum creatinine variable degree prot...
# 6  severe acute respiratory syndrome coronavirus ...
#
#                                     text_wo_stopfreq  \
# 0  accord current live statistic edit letter russ...
# 3  introduction objective outbreak unclear impact...
# 4  feline infectious peritonitis fip fatal chroni...
# 5  serum creatinine variable degree proteinuria h...
# 6  severe acute respiratory syndrome coronavirus ...
#
#                                      text_lemmatized  \
# 0  accord current live statistic edit letter russ...
# 3  introduction objective outbreak unclear impact...
# 4  feline infectious peritonitis fip fatal chroni...
# 5  serum creatinine variable degree proteinuria h...
# 6  severe acute respiratory syndrome coronavirus ...
#
#                               text_lemmatized_no_url
# 0  accord current live statistic edit letter russ...
# 3  introduction objective outbreak unclear impact...
# 4  feline infectious peritonitis fip fatal chroni...
# 5  serum creatinine variable degree proteinuria h...
# 6  severe acute respiratory syndrome coronavirus ...

# %% [markdown]
# ### Removal of HTML Tags

# %%
def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

# %%
df["text_lemmatized_url_html"] = df["text_lemmatized_no_url"].apply(lambda text: remove_html(text))
df.head()
# Out:
# <ipython-input-49-e19f1b691939>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["text_lemmatized_url_html"] = df["text_lemmatized_no_url"].apply(lambda text: remove_html(text))
#                                    paper_id                           doi  \
# 0  0000028b5cc154f68b8a269f6578f21e31f62977             10.1002/bjs.11940
# 3  000122a9a774ec76fa35ec0c0f6734e7e8d0c541     10.1016/j.rec.2020.08.002
# 4  0001418189999fea7f7cbe3e82703d71c85a6fe5  10.1016/j.vetmic.2006.11.026
# 5  00031cc15aafa30b187ed2cd3790e970e5046895             10.1159/000512683
# 6  00033d5a12240a8684cfe943954132b43434cf48             10.3390/v12080849
#
#                                             abstract  \
# 0
# 3  Introduction and objectives: The COVID-19 outb...
# 4  Feline infectious peritonitis virus (FIPV) pos...
# 5  Background: SARS-CoV-2 infection can cause ren...
# 6  Background: Amplification of viral ribonucleic...
#
#                                            body_text  \
# 0  According to current live statistics at the ti...
# 3  Introduction and objectives: The COVID-19 outb...
# 4  Feline infectious peritonitis (FIP) is a fatal...
# 5  increased serum creatinine, variable degrees o...
# 6  Severe acute respiratory syndrome coronavirus ...
#
#                                              authors  \
# 0   Tsarkov, Petr V..  Zubayraeva, Albina A.. <br...
# 3   Rodríguez-Leor, Oriol.  Cid-Álvarez, Belén. <...
# 4   Cornelissen, E..  Dewerchin, H.L..  Van Hamme...
# 5   Wang, Mo.  Xiong, Huaying.  Chen, Han.  Li, Q...
# 6   Wandernoth, Petra.  Kriegsmann, Katharina. <b...
#
#                                                title  \
# 0    “Multi‐faceted” COVID‐19: Russian<br>experience
# 3   Impact of COVID-19 on ST-segment elevation<br...
# 4   Absence of surface expression of feline<br>in...
# 5   Renal Injury by SARS-CoV-2 Infection: A<br>Sy...
# 6   Detection of Severe Acute Respiratory<br>Synd...
#
#                      journal  \
# 0                  Br J Surg
# 3  Rev Esp Cardiol (Engl Ed)
# 4              Vet Microbiol
# 5         Kidney Dis (Basel)
# 6                    Viruses
#
#                                     abstract_summary  abstract_word_count  \
# 0                                      Not provided.                    0
# 3   Introduction and objectives: The COVID-19<br>...                  286
# 4   Feline infectious peritonitis virus (FIPV)<br...                  165
# 5   Background: SARS-CoV-2 infection can cause<br...                   98
# 6   Background: Amplification of viral<br>ribonuc...                  224
#
#    body_word_count  body_unique_words language  \
# 0              635                349       en
# 3             3508               1297       en
# 4             2071                756       en
# 5             4220               1491       en
# 6             1899                835       en
#
#                                       processed_text  \
# 0  accord current live statistic time edit letter...
# 3  introduction objective the covid-19 outbreak u...
# 4  feline infectious peritonitis fip fatal chroni...
# 5  increase serum creatinine variable degree prot...
# 6  severe acute respiratory syndrome coronavirus ...
#
#                                     text_wo_stopfreq  \
# 0  accord current live statistic edit letter russ...
# 3  introduction objective outbreak unclear impact...
# 4  feline infectious peritonitis fip fatal chroni...
# 5  serum creatinine variable degree proteinuria h...
# 6  severe acute respiratory syndrome coronavirus ...
#
#                                      text_lemmatized  \
# 0  accord current live statistic edit letter russ...
# 3  introduction objective outbreak unclear impact...
# 4  feline infectious peritonitis fip fatal chroni...
# 5  serum creatinine variable degree proteinuria h...
# 6  severe acute respiratory syndrome coronavirus ...
#
#                               text_lemmatized_no_url  \
# 0  accord current live statistic edit letter russ...
# 3  introduction objective outbreak unclear impact...
# 4  feline infectious peritonitis fip fatal chroni...
# 5  serum creatinine variable degree proteinuria h...
# 6  severe acute respiratory syndrome coronavirus ...
#
#                             text_lemmatized_url_html
# 0  accord current live statistic edit letter russ...
# 3  introduction objective outbreak unclear impact...
# 4  feline infectious peritonitis fip fatal chroni...
# 5  serum creatinine variable degree proteinuria h...
# 6  severe acute respiratory syndrome coronavirus ...

# %% [markdown]
# ### Let's take a look at word count in the papers

# %%
import seaborn as sns

# %%
sns.distplot(df['body_word_count'])
df['body_word_count'].describe()
# Out:
# C:\Users\moham\anaconda3\envs\Data2\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count      82.000000
# mean     3330.390244
# std      2270.744838
# min       371.000000
# 25%      1664.000000
# 50%      2897.500000
# 75%      4406.250000
# max      9722.000000
# Name: body_word_count, dtype: float64

# %%
sns.distplot(df['body_unique_words'])
df['body_unique_words'].describe()
# Out:
# C:\Users\moham\anaconda3\envs\Data2\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count      82.000000
# mean     1122.414634
# std       579.224726
# min       234.000000
# 25%       700.750000
# 50%      1074.500000
# 75%      1394.250000
# max      2679.000000
# Name: body_unique_words, dtype: float64

# %% [markdown]
# These two plots give us a good idea of the content we are dealing with. Most papers are about 5000 words in length. The long tails in both plots are caused by outliers. In fact, ~98% of the papers are under 20,000 words in length while a select few are over 200,000! <br><br>

# %% [markdown]
# # Vectorization
#
# Now that we have pre-processed the data, it is time to convert it into a format that can be handled by our algorithms. For this purpose we will be using tf-idf. This will convert our string formatted data into a measure of how important each word is to the instance out of the literature as a whole.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
def vectorize(text, maxx_features):
    
    global vectorizer 
    X = vectorizer.fit_transform(text)
    return X

# %% [markdown]
# Vectorize our data. We will be clustering based off the content of the body text. The maximum number of features will be limited. Only the top 2 ** 12 features will be used, eseentially acting as a noise filter. Additionally, more features cause painfully long runtimes.

# %%
text = df['text_lemmatized_url_html'].values
vectorizer = TfidfVectorizer(max_features= 2 ** 12)
X = vectorize(text, 2 ** 12)
X.shape
print(X)
# Out:
#   (0, 466)	0.03879370182329524
#   (0, 1235)	0.04541854793783832
#   (0, 3456)	0.03530414003306301
#   (0, 3116)	0.04935886606418219
#   (0, 900)	0.054562043652275835
#   (0, 3221)	0.04662938926934021
#   (0, 3719)	0.03296603239069628
#   (0, 312)	0.03879370182329524
#   (0, 2215)	0.05674379717411552
#   (0, 1013)	0.022478858182899287
#   (0, 207)	0.03879370182329524
#   (0, 2662)	0.02953943361059648
#   (0, 3529)	0.03594496259448009
#   (0, 3699)	0.021640783154419082
#   (0, 2416)	0.02826562926896216
#   (0, 2083)	0.04429128162697348
#   (0, 2699)	0.03879370182329524
#   (0, 4062)	0.03959087850523936
#   (0, 1822)	0.022768049465283914
#   (0, 948)	0.03959087850523936
#   (0, 989)	0.04323679441599863
#   (0, 3090)	0.03661194830145555
#   (0, 284)	0.03879370182329524
#   (0, 2926)	0.059262446774009964
#   (0, 1221)	0.02634118627615321
#   :	:
#   (81, 2915)	0.015481748341082562
#   (81, 2861)	0.17799065372556044
#   (81, 4017)	0.04579538925378308
#   (81, 2495)	0.10476757309320495
#   (81, 3680)	0.23169472203322736
#   (81, 1104)	0.02860285725263274
#   (81, 780)	0.008671960075588184
#   (81, 2219)	0.009769799189323056
#   (81, 894)	0.007935930491064048
#   (81, 476)	0.008561258737541275
#   (81, 2767)	0.008784692743803963
#   (81, 928)	0.008137383228655776
#   (81, 164)	0.011999402733857618
#   (81, 3848)	0.015534300824910299
#   (81, 1243)	0.010784009232798873
#   (81, 138)	0.011275772261593962
#   (81, 3684)	0.019145519873078453
#   (81, 2283)	0.01430142862631637
#   (81, 2661)	0.04442975837457598
#   (81, 3504)	0.03143027192796148
#   (81, 2137)	0.013766851779383959
#   (81, 3164)	0.009637670268091592
#   (81, 2061)	0.014557439343066117
#   (81, 1021)	0.02095351461864099
#   (81, 2515)	0.027407580625122743

# %% [markdown]
# # PCA  & Clustering
#
# Let's see how much we can reduce the dimensions while still keeping 95% variance. We will apply Principle Component Analysis (PCA) to our vectorized data. The reason for this is that by keeping a large number of dimensions with PCA, you don’t destroy much of the information, but hopefully will remove some noise/outliers from the data, and make the clustering problem easier for k-means. Note that X_reduced will only be used for k-means, t-SNE will still use the original feature vector X that was generated through tf-idf on the NLP processed text.
#
# (Thank you Dr. Edward Raff for the suggestion)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.95, random_state=42)
X_reduced= pca.fit_transform(X.toarray())
X_reduced.shape
# Out:
# (82, 75)

# %% [markdown]
# To separate the literature, k-means will be run on the vectorized text. Given the number of clusters, k, k-means will categorize each vector by taking the mean distance to a randomly initialized centroid. The centroids are updated iteratively.

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ### How many clusters?
#
# To find the best k value for k-means we'll look at the distortion at different k values. Distortion computes the sum of squared distances from each point to its assigned center. When distortion is plotted against k there will be a k value after which decreases in distortion are minimal. This is the desired number of clusters.

# %%
from sklearn import metrics
from scipy.spatial.distance import cdist

# run kmeans with many different k
distortions = []
K = range(2, 10)
for k in K:
    k_means = KMeans(n_clusters=k, random_state=42).fit(X_reduced)
    k_means.fit(X_reduced)
    distortions.append(sum(np.min(cdist(X_reduced, k_means.cluster_centers_, 'euclidean'), axis=1)) / X.shape[0])
    #print('Found distortion for {} clusters'.format(k))

# %%
X_line = [K[0], K[-1]]
Y_line = [distortions[0], distortions[-1]]

# Plot the elbow
plt.plot(K, distortions, 'b-')
plt.plot(X_line, Y_line, 'r')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# In this plot we can see that the better k values are between 18-25. After that, the decrease in distortion is not as significant. For simplicity, we will use k=20

# %% [markdown]
# ### Run k-means

# %% [markdown]
# Now that we have an appropriate k value, we can run k-means on the PCA-processed feature vector (X_reduced).

# %%
k = 5
kmeans = KMeans(n_clusters=k, random_state=42)
y_pred = kmeans.fit_predict(X_reduced)
df['y'] = y_pred
df['y']
# Out:
# <ipython-input-59-fe9c866d954f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['y'] = y_pred
# 0     3
# 3     2
# 4     2
# 5     4
# 6     2
#      ..
# 88    1
# 89    3
# 90    4
# 93    1
# 94    2
# Name: y, Length: 82, dtype: int32

# %% [markdown]
# # Dimensionality Reduction with t-SNE

# %%
from sklearn.manifold import TSNE

tsne = TSNE(verbose=1, perplexity=100, random_state=42)
X_embedded = tsne.fit_transform(X.toarray())
# Out:
# [t-SNE] Computing 81 nearest neighbors...
# [t-SNE] Indexed 82 samples in 0.002s...
# [t-SNE] Computed neighbors for 82 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 82 / 82
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 40.942039
# [t-SNE] KL divergence after 900 iterations: 0.001741

# %% [markdown]
# So that step took a while! Let's take a look at what our data looks like when compressed to 2 dimensions.

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# sns settings
sns.set(rc={'figure.figsize':(15,15)})

# colors
palette = sns.color_palette("bright", 1)

# plot
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], palette=palette)
plt.title('t-SNE with no Labels')
plt.savefig("t-sne_covid19.png")
plt.show()
# Out:
# C:\Users\moham\anaconda3\envs\Data2\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# This looks pretty bland. There are some clusters we can immediately detect, but the many instances closer to the center are harder to separate. t-SNE did a good job at reducing the dimensionality, but now we need some labels. Let's use the clusters found by k-means as labels. This will help visually separate different concentrations of topics.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# sns settings
sns.set(rc={'figure.figsize':(15,15)})

# colors
palette = sns.hls_palette(5, l=.4, s=.9)

# plot
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y_pred, legend='full', palette=palette)
plt.title('t-SNE with Kmeans Labels')
plt.savefig("improved_cluster_tsne.png")
plt.show()
# Out:
# C:\Users\moham\anaconda3\envs\Data2\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The labeled plot gives better insight into how the papers are grouped. It is interesting that both k-means and t-SNE are able to agree on certain clusters even though they were ran independetly. The location of each paper on the plot was determined by t-SNE while the label (color) was determined by k-means. If we look at a particular part of the plot where t-SNE has grouped many articles forming a cluster, it is likely that k-means is uniform in the labeling of this cluster (most of the cluster is the same color). This behavior shows that structure within the literature can be observed and measured to some extent.
#
# Now there are other cases where the colored labels (k-means) are spread out on the plot (t-SNE). This is a result of t-SNE and k-means finding different connections in the higher dimensional data. The topics of these papers often intersect so it hard to cleanly separate them. This effect can be observed in the formation of subclusters on the plot. These subclusters are a conglomeration of different k-means labels but may share some connection determined by t-SNE.
#
# This organization of the data does not act as a simple search engine. The clustering + dimensionality reduction is performed on the mathematical similarities of the publications. As an unsupervised approach, the algorithms may even find connections that were unnaparent to humans. This may highlight hidden shared information and advance further research.

# %% [markdown]
# # NMF

# %%
import en_ner_bc5cdr_md
nlp = spacy.load("en_ner_bc5cdr_md")

# %%
from sklearn.decomposition import NMF, LatentDirichletAllocation
nmf = NMF(n_components=20, random_state=1,
          alpha=.1, l1_ratio=.5).fit(X)

# %%
def plot_top_words(model, feature_names, n_top_words, title):
    fig, axes = plt.subplots(5, 4, figsize=(30, 60), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[:-n_top_words - 1:-1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f'Topic {topic_idx +1}',
                     fontdict={'fontsize': 30})
        ax.invert_yaxis()
        ax.tick_params(axis='both', which='major', labelsize=20)
        for i in 'top right left'.split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()

# %%
#vectorizer = TfidfVectorizer(max_features= 2 ** 12)

# %%
tfidf_feature_names = vectorizer.get_feature_names()
plot_top_words(nmf, tfidf_feature_names, 40,
               'Topics in NMF model')

# %%
all_keywords = []
for topic_idx, topic in enumerate(nmf.components_):
    #top words = 100
    top_features_ind = topic.argsort()[:-40 - 1:-1]
    top_features = [tfidf_feature_names[i] for i in top_features_ind]
    all_keywords.append(top_features)

# %%
for num_clus in range(0,20):
    print("*************Cluster ",num_clus,"*********************")
    str1 = ','.join(all_keywords[num_clus])
    doc = nlp(str1)
    print(str1)
    print("-------------------------------------------")
    TERM_LIST = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
    print("TERM_LIST : " ,TERM_LIST )
    print("")
# Out:
# *************Cluster  0 *********************
# icu,respiratory,ecmo,hospital,h5n1,acquire,day,influenza,positive,admission,failure,pcr,incidence,ards,survival,care,ventilation,sd,viral,ard,datum,discharge,mechanical,mortality,outcome,vv,paulo,hospitalize,year,mean,ward,bed,sao,responsible,therapy,management,severe,stay,aminotransferase,report
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  1 *********************
# cov,igm,igg,pcr,saliva,sample,onset,rrt,specific,vaccine,day,serum,antibody,negative,test,positive,hcp,assay,resident,antigen,week,rt,level,detection,iga,collect,swab,specimen,transmission,cut,dpso,viral,renal,ace2,2020,primer,clinical,severe,agena,find
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  2 *********************
# social,service,professional,disaster,healthcare,community,scheme,prescribe,care,pharmacist,referral,public,people,medical,economic,pandemic,emergency,prescribing,sector,global,policy,system,worker,rt,management,medication,need,identity,benefit,profession,education,team,inequality,assessment,provide,problem,hazard,individual,access,member
# -------------------------------------------
# TERM_LIST :  ['pandemic']
#
# *************Cluster  3 *********************
# il,cytokine,chemokine,dc,ifn,iron,inflammatory,th1,induce,plasma,hlh,mcp,response,th2,ferritin,production,macrophage,ip,pmn,immune,concentration,cov,inflammation,tnf,lung,obese,activation,pdcs,elevate,subset,10,proinflammatory,tissue,corticosteroid,mdc1,pathogen,human,monocyte,mouse,fp
# -------------------------------------------
# TERM_LIST :  ['inflammation']
#
# *************Cluster  4 *********************
# codon,tuller,gene,viral,genome,structure,code,mutation,sequence,host,position,2009,expression,silent,2016,nfc,translation,fitness,region,nsp6,selection,goz,dana,elongation,2010,rna,2012,ribosome,2013,bias,relate,evolution,2014,bahir,2014b,zur,mrna,synonymous,2015,2011
# -------------------------------------------
# TERM_LIST :  ['tuller', 'elongation,2010,rna,2012,ribosome,2013,bias']
#
# *************Cluster  5 *********************
# fipv,centrifugation,cat,mhc,strain,antigen,inoculation,stain,viral,centrifuge,centrifugal,infect,antibody,culture,exudate,monocyte,type,surface,ucd,ku,titer,fip,feline,400,fcwf,inoculate,method,1146,ii,pedersen,pyogranuloma,enhancement,plaque,positive,infectious,black,serotype,lysis,mediate,effusive
# -------------------------------------------
# TERM_LIST :  ['pyogranuloma', 'effusive']
#
# *************Cluster  6 *********************
# ili,qol,child,ent,par,parent,score,sf,12v2,episode,caregiver,influenza,parental,interview,questionnaire,emotional,domain,impact,acute,season,item,examination,essential,europe,exclude,euclidean,etkin,etiology,ethical,ethic,etc,estimation,estimate,establish,especially,escherichia,exclusion,erythrocyte,error,erb
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  7 *********************
# pm,italian,exposure,province,pollution,death,proportion,incidence,provincial,region,territorial,lg,gender,10,association,confounder,extension,distribution,regression,variable,italy,geographical,number,annual,datum,crude,stratify,mean,humidity,independent,air,etiology,euclidean,european,etkin,exclusively,europe,excretion,estimate,ethical
# -------------------------------------------
# TERM_LIST :  ['death']
#
# *************Cluster  8 *********************
# antiviral,resistance,drug,hcv,nanoparticle,viral,inhibitor,hiv,interferon,ribavirin,hbv,replication,development,agent,inhibit,agnps,approve,therapy,rna,review,treatment,target,analogue,nucleoside,host,activity,polymerase,hsv,influenza,aunps,major,effective,act,protease,hepatitis,entry,treat,antiretroviral,propagation,clinical
# -------------------------------------------
# TERM_LIST :  ['hbv', 'hepatitis']
#
# *************Cluster  9 *********************
# hcw,influenza,atypical,ed,ppe,scii,presentation,contact,symptom,continue,household,season,abdominal,vaccination,car,ct,participant,illness,report,asymptomatic,pain,prior,berlin,exposure,team,ili,day,ari,chest,communication,care,present,find,ownership,respiratory,child,manuscript,titre,transport,non
# -------------------------------------------
# TERM_LIST :  ['illness', 'pain', 'chest,communication,']
#
# *************Cluster  10 *********************
# sleep,mother,anxiety,insomnia,maternal,child,crisis,report,quality,trait,change,confinement,acute,level,score,symptom,isi,pandemic,2020,home,retrospectively,age,duration,001,conduct,difference,exception,euclidean,etkin,exclusion,etiology,ethical,ethic,etc,estimation,exclusively,excretion,estimate,european,establish
# -------------------------------------------
# TERM_LIST :  ['anxiety', 'insomnia']
#
# *************Cluster  11 *********************
# surgery,surgical,contamination,covid19,dedicate,procedure,hospital,prefer,complication,perform,possibility,worker,arterial,during,phase,department,effective,take,period,consideration,general,italy,rarely,tracheostomy,admit,negative,aerosol,outbreak,positive,acute,staff,multidisciplinary,perspective,reduce,undergo,th,steady,intubation,marginal,aggravate
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  12 *********************
# msp,pf,pv,malarial,antibody,19,malaria,antigen,subclass,platelet,punnath,thrombocytopenia,level,hec,anemia,anti,endemic,igg,mangaluru,2011,merozoite,igg3,igg4,05,infect,rbc,falciparum,igg1,plasmodium,observe,anemic,al,southern,hemoglobin,biotech,parasitemia,ll,2009,even,event
# -------------------------------------------
# TERM_LIST :  ['thrombocytopenia', 'anemia', 'falciparum', 'parasitemia']
#
# *************Cluster  13 *********************
# device,fda,reference,performance,assay,specimen,clia,diagnostic,npv,clinical,new,sensitivity,ppv,specificity,iu,guidance,eg,multiplex,method,waiver,analyte,analytical,pathogen,waive,prevalence,sponsor,intend,use,estimate,submission,positive,vitro,respiratory,ide,negative,process,pivotal,microbiology,sample,set
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  14 *********************
# donate,gbm,blood,donation,hiri,participant,policy,msm,citizenship,sexual,deferral,man,donor,interview,hiv,eligible,vancouver,toronto,biological,canada,grace,willingness,gay,sex,sense,community,think,low,practice,queer,political,2019,feel,canadian,desire,montreal,etkin,etiology,ethic,excessive
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  15 *********************
# mhv,jhm,peplomer,mutant,wt,ief,nc,sheet,leibowitz,oleszak,goat,antibody,1990a,isoelectric,blot,lysate,microheterogeneity,l2,rinse,1981,page,infect,demyelinate,glycosylation,anti,holmes,focus,ph,min,glycoprotein,describe,lane,demyelination,urea,mouse,molecular,sd,exhibit,ts,specific
# -------------------------------------------
# TERM_LIST :  ['demyelination']
#
# *************Cluster  16 *********************
# african,american,discrimination,disparity,racial,gene,innate,pathway,ace2,social,angiotensin,indirect,depression,anxiety,biological,relate,immune,response,system,expression,ang,inflammation,inflammatory,transcriptional,crisis,promote,think,metabolic,consequence,disproportionately,alteration,get,hypertension,alter,pandemic,issue,storm,home,white,abnormal
# -------------------------------------------
# TERM_LIST :  ['depression', 'anxiety', 'inflammation', 'hypertension', 'pandemic']
#
# *************Cluster  17 *********************
# rural,urban,mexico,old,municipality,area,adult,2020,de,semi,people,000,disparity,access,mortality,65,proportion,live,care,la,million,community,vulnerable,poverty,number,para,age,compare,government,percentage,rate,100,specialty,education,country,el,finally,spatial,2015,need
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  18 *********************
# ns1,chadox1,btv,mva,immunize,mouse,nt,sheep,vaccine,immunization,animal,prime,boost,viremia,dose,serotype,protection,cd8,vector,ifnar,pfu,splenocyte,euclidean,etkin,etiology,europe,ethical,ethic,european,essential,etc,estimation,estimate,establish,evaluate,especially,escherichia,erythrocyte,error,erb
# -------------------------------------------
# TERM_LIST :  ['viremia']
#
# *************Cluster  19 *********************
# mrsa,hcai,vre,teicoplanin,tigecycline,incidence,vancomycin,linezolid,consumption,daptomycin,fusidic,antibiotic,correlation,glycopeptide,aureus,antimicrobial,isolate,acid,trend,use,1000,resistance,find,taiwan,inpatient,resistant,gram,period,annual,bacteria,agent,hospital,engineer,etc,exacerbation,endemic,endogenous,exacerbate,evolve,evolutionary
# -------------------------------------------
# TERM_LIST :  ['aureus']

# %% [markdown]
# # LDA

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

tf = CountVectorizer(max_df=0.9, min_df=5, stop_words='english')
tff = tf.fit_transform(text)
lda = LatentDirichletAllocation(n_components=20, max_iter=10, learning_method='online', random_state=42)
lda.fit(tff)
# Out:
# LatentDirichletAllocation(learning_method='online', n_components=20,
#                           random_state=42)

# %%
tf_feature_names = tf.get_feature_names()
plot_top_words(lda, tf_feature_names, 40, 'Topics in LDA model')

# %%
all_keywords = []
for topic_idx, topic in enumerate(nmf.components_):
    #top words = 100
    top_features_ind = topic.argsort()[:-100 - 1:-1]
    top_features = [tfidf_feature_names[i] for i in top_features_ind]
    all_keywords.append(top_features)

# %%
for num_clus in range(0,20):
    print("*************Cluster ",num_clus,"*********************")
    str1 = ','.join(all_keywords[ ])
    doc = nlp(str1)
    print(str1)
    print("-------------------------------------------")
    TERM_LIST = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
    print("TERM_LIST : " ,TERM_LIST )
    print("")
# Out:
#   File "<ipython-input-73-7c4ec9b87b3b>", line 3
#     str1 = ','.join(all_keywords[ ])
#                                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# # LSA

# %%
from sklearn.decomposition import TruncatedSVD

# SVD represent documents and terms in vectors 
svd_model = TruncatedSVD(n_components=20, algorithm='randomized', n_iter=100, random_state=122)

svd_model.fit(X)

len(svd_model.components_)
# Out:
# 20

# %%
terms = vectorizer.get_feature_names()

for i, comp in enumerate(svd_model.components_):
    terms_comp = zip(terms, comp)
    sorted_terms = sorted(terms_comp, key= lambda x:x[1], reverse=True)[:7]
    print("Topic "+str(i)+": ")
    for t in sorted_terms:
        print(t[0] ," ",end='')
    print(" ")
# Out:
# Topic 0:
# cov  hospital  care  viral  respiratory  day  pcr
# Topic 1:
# service  social  disaster  people  public  care  community
# Topic 2:
# hospital  pcr  respiratory  cov  icu  day  positive
# Topic 3:
# cytokine  il  chemokine  obese  iron  icu  dc
# Topic 4:
# gene  icu  dataset  ecmo  genome  codon  heartbeat
# Topic 5:
# fipv  centrifugation  antigen  mhc  cat  strain  surface
# Topic 6:
# surgery  antiviral  viral  surgical  drug  resistance  cov
# Topic 7:
# city  pm  child  sleep  chilblain  2020  dengue
# Topic 8:
# hcw  influenza  ili  child  antiviral  qol  ppe
# Topic 9:
# fipv  gene  ed  service  genome  african  ppe
# Topic 10:
# fipv  pcr  icu  child  sleep  ili  obese
# Topic 11:
# surgery  surgical  procedure  platelet  sleep  bc  mother
# Topic 12:
# surgery  vaccine  ns1  surgical  fp  dc  mouse
# Topic 13:
# hcw  platelet  msp  gene  var  service  influenza
# Topic 14:
# hcw  surgery  youth  surgical  il  resident  participant
# Topic 15:
# water  device  foal  dog  saliva  waterborne  var
# Topic 16:
# golgi  membrane  carrier  lipid  gramicidin  ddao  nmr
# Topic 17:
# saliva  hcw  dog  city  surgical  egypt  receptor
# Topic 18:
# heartbeat  diagram  rural  erb  cov  diabetes  task
# Topic 19:
# pm  exposure  disaster  ace2  golgi  device  economic

# %%
all_keywords = []
for topic_idx, topic in enumerate(svd_model.components_):
    #top words = 100
    top_features_ind = topic.argsort()[:-40 - 1:-1]
    top_features = [tfidf_feature_names[i] for i in top_features_ind]
    all_keywords.append(top_features)

# %%
for num_clus in range(0,19):
    print("*************Cluster ",num_clus,"*********************")
    str1 = ','.join(all_keywords[num_clus])
    doc = nlp(str1)
    print(str1)
    print("-------------------------------------------")
    TERM_LIST = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
    print("TERM_LIST : " ,TERM_LIST )
    print("")
# Out:
# *************Cluster  0 *********************
# cov,hospital,care,viral,respiratory,day,pcr,sample,report,positive,service,vaccine,public,clinical,gene,people,pandemic,social,icu,2020,datum,community,medical,influenza,coronavirus,cytokine,level,response,healthcare,specific,symptom,negative,system,number,device,disaster,10,we,emergency,acute
# -------------------------------------------
# TERM_LIST :  ['pandemic']
#
# *************Cluster  1 *********************
# service,social,disaster,people,public,care,community,emergency,healthcare,professional,medical,pharmacist,policy,rural,pandemic,economic,hospital,area,team,old,management,referral,perception,education,worker,surgery,access,scheme,surgical,assessment,urban,prescribe,benefit,event,global,home,government,crisis,resource,mask
# -------------------------------------------
# TERM_LIST :  ['pandemic']
#
# *************Cluster  2 *********************
# hospital,pcr,respiratory,cov,icu,day,positive,ecmo,hcw,h5n1,negative,symptom,hcp,surgery,surgical,influenza,acquire,test,sample,igm,onset,swab,rrt,admission,igg,resident,technician,tpe,stemi,ppe,collect,specimen,ventilation,discharge,ed,device,lab,failure,care,week
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  3 *********************
# cytokine,il,chemokine,obese,iron,icu,dc,inflammatory,ecmo,obesity,ifn,induce,tpe,immune,hospital,ferritin,pe,h5n1,hlh,inflammation,lung,renal,injury,tissue,fp,surgery,ace2,elevate,mouse,acute,plasma,th1,production,failure,kidney,response,ards,trivalent,macrophage,ventilation
# -------------------------------------------
# TERM_LIST :  ['obesity', 'inflammation', 'lung,renal,injury']
#
# *************Cluster  4 *********************
# gene,icu,dataset,ecmo,genome,codon,heartbeat,hospital,datum,tuller,viral,respiratory,language,model,tree,receptor,ssl,var,similarity,satisfy,analysis,matrix,smooth,lisa,netdx,omic,prediction,pm,pfswib,mutation,network,probability,idrw,sequence,peak,surgery,parameter,position,property,hemodynamic
# -------------------------------------------
# TERM_LIST :  ['tuller']
#
# *************Cluster  5 *********************
# fipv,centrifugation,antigen,mhc,cat,strain,surface,antibody,inoculation,infect,stain,viral,centrifuge,centrifugal,hcw,exudate,culture,influenza,msp,type,monocyte,mhv,ucd,ku,titer,surgery,fip,feline,400,resistance,jhm,foal,device,positive,fcwf,method,antiviral,nw,infectious,inoculate
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  6 *********************
# surgery,antiviral,viral,surgical,drug,resistance,cov,hcv,hospital,vaccine,nanoparticle,country,dedicate,dengue,inhibitor,icu,contamination,mutation,host,2020,egypt,agent,codon,rna,genome,treatment,interferon,hiv,agnps,acquire,inhibit,respiratory,tuller,pharmacist,city,outbreak,effective,treat,replication,covid19
# -------------------------------------------
# TERM_LIST :  ['dengue', 'tuller']
#
# *************Cluster  7 *********************
# city,pm,child,sleep,chilblain,2020,dengue,msp,ili,egypt,water,mother,country,cov,peak,insomnia,qol,bc,transmission,disaster,search,anxiety,population,igm,igg,antibody,travel,pf,outbreak,maternal,level,pv,rate,people,ae,tourist,onset,italian,confinement,economic
# -------------------------------------------
# TERM_LIST :  ['insomnia', 'anxiety']
#
# *************Cluster  8 *********************
# hcw,influenza,ili,child,antiviral,qol,ppe,sleep,resistance,ed,atypical,vaccine,hcv,drug,nanoparticle,mother,kd,anxiety,scii,viral,insomnia,report,symptom,presentation,maternal,pims,crisis,ent,vaccination,inhibitor,exposure,abdominal,par,continue,illness,hiv,bc,season,transmission,contact
# -------------------------------------------
# TERM_LIST :  ['hcv', 'anxiety', 'insomnia', 'illness,hiv,bc']
#
# *************Cluster  9 *********************
# fipv,gene,ed,service,genome,african,ppe,codon,centrifugation,pe,american,tuller,viral,myelitis,atypical,ace2,renal,kd,team,cat,inoculation,strain,expression,presentation,care,immune,cov,she,rural,mutation,var,mri,we,mask,ts,social,symptom,injury,image,stain
# -------------------------------------------
# TERM_LIST :  ['tuller', 'myelitis']
#
# *************Cluster  10 *********************
# fipv,pcr,icu,child,sleep,ili,obese,qol,anxiety,influenza,respiratory,acquire,hospital,social,insomnia,african,mother,bc,obesity,technician,lab,centrifugation,gene,rrt,sample,cytokine,h5n1,maternal,positive,american,swab,cat,collect,incidence,var,outcome,disaster,ent,inoculation,oropharyngeal
# -------------------------------------------
# TERM_LIST :  ['anxiety', 'insomnia', 'obesity', 'oropharyngeal']
#
# *************Cluster  11 *********************
# surgery,surgical,procedure,platelet,sleep,bc,mother,child,anxiety,contamination,insomnia,lisa,psychological,covid19,cov,avatrombopag,maternal,intubation,drug,nurse,score,complication,kd,dedicate,african,prefer,crisis,acute,ace2,premedication,possibility,igm,qol,saliva,american,antiviral,worker,pims,aerosol,effective
# -------------------------------------------
# TERM_LIST :  ['anxiety', 'insomnia']
#
# *************Cluster  12 *********************
# surgery,vaccine,ns1,surgical,fp,dc,mouse,trivalent,chadox1,bc,btv,gene,contamination,mva,immunize,2020,rural,covid19,hcw,psychological,vns,apc,dedicate,sleep,receptor,figure,induce,expression,insomnia,outbreak,stemi,var,anxiety,worker,nurse,immunization,tg,procedure,department,old
# -------------------------------------------
# TERM_LIST :  ['insomnia', 'anxiety']
#
# *************Cluster  13 *********************
# hcw,platelet,msp,gene,var,service,influenza,antibody,day,igg,pfswib,hospital,pf,ecmo,igm,codon,pv,saliva,tuller,h5n1,pharmacist,icu,ed,malarial,onset,serum,mhv,blood,avatrombopag,level,mrsa,ili,incidence,hcai,ns1,jhm,community,antigen,prescribe,dog
# -------------------------------------------
# TERM_LIST :  ['tuller']
#
# *************Cluster  14 *********************
# hcw,surgery,youth,surgical,il,resident,participant,hcp,pcr,donate,dc,cytokine,lu,policy,influenza,language,mask,city,gbm,positive,blood,donation,disaster,pregnant,gene,atypical,perception,chemokine,genome,codon,tuller,ili,woman,ed,diagram,satisfy,contamination,hiri,asymptomatic,ppe
# -------------------------------------------
# TERM_LIST :  ['tuller']
#
# *************Cluster  15 *********************
# water,device,foal,dog,saliva,waterborne,var,dengue,ppe,pathogen,cryptosporidium,pfswib,vns,youth,hcw,ace2,ed,fi,expression,mask,outbreak,atypical,yr,drinking,gene,fda,contamination,oocyst,nigeria,american,parvovirosis,immunocompromised,african,groundwater,sample,stemi,parasite,2002,boko,nigerian
# -------------------------------------------
# TERM_LIST :  ['foal', 'cryptosporidium', 'parvovirosis']
#
# *************Cluster  16 *********************
# golgi,membrane,carrier,lipid,gramicidin,ddao,nmr,grama,temperature,chain,professional,mhv,surfactant,service,order,jhm,mutant,vesicle,plasma,bc,dmpc,interconnect,peak,rt,arf1,pi,hwhm,acyl,concentration,secretory,cargo,eo,positional,healthcare,traffic,peplomer,cholesterol,tsvsv,parameter,3d
# -------------------------------------------
# TERM_LIST :  []
#
# *************Cluster  17 *********************
# saliva,hcw,dog,city,surgical,egypt,receptor,transmission,dataset,surgery,influenza,antiviral,sample,image,parvovirosis,mode,coronavirus,public,drug,differentially,ct,economic,dedicate,go,pve,healthcare,social,aerosol,mrsa,travel,ray,hcai,igm,serum,network,vaccination,canine,nanoparticle,pm,professional
# -------------------------------------------
# TERM_LIST :  ['parvovirosis']
#
# *************Cluster  18 *********************
# heartbeat,diagram,rural,erb,cov,diabetes,task,audial,hcw,msf,user,language,participant,igm,framework,iron,graphic,onset,old,query,fipv,stemi,research,people,access,ili,urban,area,mexico,golgi,ethic,insulin,adult,influenza,type,emergency,team,kd,cytokine,paediatric
# -------------------------------------------
# TERM_LIST :  ['diabetes']

# %% [markdown]
# # Topic Modeling on Each Cluster
#
# Now we will attempt to find the most significant words in each clusters. K-means clustered the articles but did not label the topics. Through topic modeling we will find out what the most important terms for each cluster are. This will add more meaning to the cluster by giving keywords to quickly identify the themes of the cluster.

# %% [markdown]
# For topic modeling, we will use LDA (Latent Dirichlet Allocation). In LDA, each document can be described by a distribution of topics and each topic can be described by a distribution of words[.](https://towardsdatascience.com/light-on-math-machine-learning-intuitive-guide-to-latent-dirichlet-allocation-437c81220158)

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# First we will create 20 vectorizers, one for each of our cluster labels

# %%
vectorizers = []
    
for ii in range(0, 5):
    # Creating a vectorizer
    vectorizers.append(CountVectorizer(min_df=5, max_df=0.9, stop_words='english', lowercase=True, token_pattern='[a-zA-Z\-][a-zA-Z\-]{2,}'))

# %% [markdown]
# Now we will vectorize the data from each of our clusters

# %%
vectorized_data = []

for current_cluster, cvec in enumerate(vectorizers):
    try:
        vectorized_data.append(cvec.fit_transform(df.loc[df['y'] == current_cluster, 'text_lemmatized_url_html']))
        #d'ou vient df['y'] =   y_pred = kmeans.fit_predict(X_reduced)      df['y'] = y_pred       df['y']
    except Exception as e:
        print("Not enough instances in cluster: " + str(current_cluster))
        vectorized_data.append(None)
# Out:
# Not enough instances in cluster: 0
# Not enough instances in cluster: 4

# %%
len(vectorized_data)
# Out:
# 5

# %% [markdown]
# Topic modeling will be performed through the use of Latent Dirichlet Allocation (LDA). This is a generative statistical model that allows sets of words to be explained by a shared topic

# %% [markdown]
# # Topic modeling on each cluster using LDA :

# %%
# number of topics per cluster
NUM_TOPICS_PER_CLUSTER = 6

lda_models = []
for ii in range(0, 5):
    # Latent Dirichlet Allocation Model
    lda = LatentDirichletAllocation(n_components=NUM_TOPICS_PER_CLUSTER, max_iter=10, learning_method='online',verbose=False, random_state=42)
    lda_models.append(lda)

# %% [markdown]
# For each cluster, we had created a correspoding LDA model in the previous step. We will now fit_transform all the LDA models on their respective cluster vectors

# %%
clusters_lda_data = []

for current_cluster, lda in enumerate(lda_models):
    # print("Current Cluster: " + str(current_cluster))
    
    if vectorized_data[current_cluster] != None:
        clusters_lda_data.append((lda.fit_transform(vectorized_data[current_cluster])))

# %% [markdown]
# Extracts the keywords from each cluster

# %%
# Functions for printing keywords for each topic
def selected_topics(model, vectorizer, top_n=20):
    current_words = []
    keywords = []
    
    for idx, topic in enumerate(model.components_):
        words = [(vectorizer.get_feature_names()[i], topic[i]) for i in topic.argsort()[:-top_n - 1:-1]]
        for word in words:
            if word[0] not in current_words:
                keywords.append(word)
                current_words.append(word[0])
                
    keywords.sort(key = lambda x: x[1])  
    keywords.reverse()
    return_values = []
    for ii in keywords:
        return_values.append(ii[0])
    return return_values

# %% [markdown]
# Append list of keywords for a single cluster to 2D list of length NUM_TOPICS_PER_CLUSTER

# %%
all_keywords = []
for current_vectorizer, lda in enumerate(lda_models):
    # print("Current Cluster: " + str(current_vectorizer))

    if vectorized_data[current_vectorizer] != None:
        all_keywords.append(selected_topics(lda, vectorizers[current_vectorizer]))

# %%
for i in range(0,5):
    print(all_keywords[i])
# Out:
# ['water', 'research', 'device', 'public', 'service', 'people', 'healthcare', 'review', 'low', 'professional', 'individual', 'pandemic', 'clinical', 'report', 'value', 'community', 'base', 'new', 'emergency', 'nurse', 'resource', 'non', 'model', 'measure', 'medical', 'method', 'use', 'child', 'treatment', 'analysis', 'outbreak', 'information', 'disaster', 'rural', 'crisis', 'datum', 'form', 'worker', 'provide', 'support', 'female', 'symptom', 'source', 'protocol', 'limit', 'impact', 'old', 'issue', 'area', 'distribution', 'mask', 'adult', 'consent', 'urban', 'example', 'illness', 'global', 'member', 'population', 'quality', 'survey', 'associate', 'participant', 'collect', 'event', 'supply', 'estimate', 'policy', 'current', 'rate', 'response', 'care', 'mortality', 'occur', 'exposure', 'cause', 'daily', 'plan', 'condition', 'access', 'number', 'early', 'live', 'compare', 'social', 'age', 'wear', 'change']
# ['sample', 'blood', 'cov-', 'antibody', 'dengue', 'pcr', 'antiviral', 'mouse', 'saliva', 'participant', 'carrier', 'influenza', 'level', 'child', 'policy', 'donation', 'gene', 'drug', 'collect', 'specific', 'test', 'negative', 'hospital', 'vaccine', 'animal', 'transmission', 'viral', 'antigen', 'report', 'clinical', 'day', 'igg', 'score', 'serum', 'response', 'primer', 'inhibit', 'activity', 'protection', 'respiratory', 'low', 'dna', 'agent', 'plasma', 'control', 'positive', 'analysis', 'reaction', 'effect', 'express', 'country', 'order', 'acute', 'human', 'transport', 'care', 'cause', 'icu', 'temperature', 'chain', 'factor', 'treatment', 'relate', 'non', 'use', 'genome', 'associate', 'domain', 'host', 'code', 'lipid', 'expression', 'structure', 'exposure', 'peak', 'rate', 'death', 'membrane', 'number', 'rna', 'important', 'province', 'region', 'datum', 'type', 'phase', 'suggest', 'sequence', 'infect', 'bias', 'strain', 'inclusion', 'parameter', 'centrifugation', 'mechanism', 'incidence', 'proportion', 'encode', 'position']
# ['dataset', 'probability', 'table', 'sample', 'method', 'set', 'figure', 'coronavirus', 'datum', 'single', 'value', 'measure', 'infectious', 'source', 'large', 'matrix', 'number', 'network', 'main', 'class', 'analysis', 'obtain', 'spread', 'propose', 'fig', 'clinical', 'example', 'prediction', 'express', 'type', 'people', 'sequence', 'need', 'previous', 'information', 'pandemic', 'follow', 'approach', 'average', 'process', 'individual', 'develop', 'impact', 'control', 'strategy', 'model', 'use', 'compare', 'treatment', 'low', 'likely', 'available', 'reduce', 'country', 'base', 'human', 'isolate', 'cause', 'phase', 'step', 'report', 'paper', 'learn', 'performance', 'affect', 'work', 'exist']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-86-43f1b7795aa5> in <module>
#       1 for i in range(0,5):
# ----> 2     print(all_keywords[i])
#
# IndexError: list index out of range

# %%
for num_clus in range(0,5):
    print("*************Cluster ",num_clus,"*********************")
    str1 = ','.join(all_keywords[num_clus])
    doc = nlp(str1)
    print(str1)
    print("-------------------------------------------")
    TERM_LIST = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
    print("TERM_LIST : " ,TERM_LIST )
    print("")

# %% [markdown]
# # Topic modeling on each cluster using NMF :

# %%
# number of topics per cluster
NUM_TOPICS_PER_CLUSTER = 6

nmf_models = []
for ii in range(0, 5):
    # nmf
    nmf = NMF(n_components=NUM_TOPICS_PER_CLUSTER, random_state=1,alpha=.1, l1_ratio=.5)
    nmf_models.append(nmf)
    
nmf_models[0]

# %%
clusters_nmf_data = []

for current_cluster, nmf in enumerate(nmf_models):
    print("Current Cluster: " + str(current_cluster))
    if vectorized_data[current_cluster] != None:
        clusters_nmf_data.append((nmf.fit_transform(vectorized_data[current_cluster])))

# %%
# Functions for printing keywords for each topic
def selected_topics(model, vectorizer, top_n=20):
    current_words = []
    keywords = []
    
    for idx, topic in enumerate(model.components_):
        words = [(vectorizer.get_feature_names()[i], topic[i]) for i in topic.argsort()[:-top_n - 1:-1]]
        for word in words:
            if word[0] not in current_words:
                keywords.append(word)
                current_words.append(word[0])
                
    keywords.sort(key = lambda x: x[1])  
    keywords.reverse()
    return_values = []
    for ii in keywords:
        return_values.append(ii[0])
    return return_values

# %%
all_keywords = []
for current_vectorizer, nmf in enumerate(nmf_models):
    # print("Current Cluster: " + str(current_vectorizer))
    if vectorized_data[current_vectorizer] != None:
        all_keywords.append(selected_topics(nmf, vectorizers[current_vectorizer]))

# %%
for i in range(0,5):
    print(all_keywords[i])

# %% [markdown]
# ## travail realisé :
#  - detection automatique des noms de maladies
#  - construction d'un corpus en utilisant les noms des maladies detectés

# %%
for num_clus in range(0,5):
    print("*************Cluster ",num_clus,"*********************")
    str1 = ','.join(all_keywords[num_clus])
    doc = nlp(str1)
    print(str1)
    print("-------------------------------------------")
    TERM_LIST = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
    print("TERM_LIST : " ,TERM_LIST )
    print("")

# %% [markdown]
# # Word's Similarity

# %%
import spacy
nlp = spacy.load('en_core_web_md')
cov_word =nlp("coronavirus")
for num_clus in range(0,20):
    print("*************Cluster ",num_clus,"*********************")
    str1 = ' '.join(all_keywords[num_clus])
    doc = nlp(str1)
    print(str1)
    print("-------------------------------------------")
    words = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
    print("TERM_LIST : " ,words)
    print("")
    for token in doc:
        #print(token.text, token.has_vector, token.vector_norm, token.is_oov) 
        if cov_word.similarity(token) > 0.5 :
            print("Similarity Between {",cov_word,"} and {",token,"} is :   ",cov_word.similarity(token))
    print("__________________________________________________________________")
# Out:
# *************Cluster  0 *********************
# icu respiratory ecmo hospital h5n1 acquire day influenza positive admission failure pcr incidence ards survival care ventilation sd viral ard datum discharge mechanical mortality outcome vv paulo hospitalize year mean ward bed sao responsible therapy management severe stay aminotransferase report
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { influenza } is :    0.6127955278394492
# Similarity Between { coronavirus } and { viral } is :    0.6789279758381194
# __________________________________________________________________
# *************Cluster  1 *********************
# <ipython-input-95-a9ecc4291df1>:15: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   if cov_word.similarity(token) > 0.5 :
# cov igm igg pcr saliva sample onset rrt specific vaccine day serum antibody negative test positive hcp assay resident antigen week rt level detection iga collect swab specimen transmission cut dpso viral renal ace2 2020 primer clinical severe agena find
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { vaccine } is :    0.5881906817418034
# Similarity Between { coronavirus } and { viral } is :    0.6789279758381194
# __________________________________________________________________
# *************Cluster  2 *********************
# social service professional disaster healthcare community scheme prescribe care pharmacist referral public people medical economic pandemic emergency prescribing sector global policy system worker rt management medication need identity benefit profession education team inequality assessment provide problem hazard individual access member
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { pandemic } is :    0.5010447134454742
# __________________________________________________________________
# *************Cluster  3 *********************
# il cytokine chemokine dc ifn iron inflammatory th1 induce plasma hlh mcp response th2 ferritin production macrophage ip pmn immune concentration cov inflammation tnf lung obese activation pdcs elevate subset 10 proinflammatory tissue corticosteroid mdc1 pathogen human monocyte mouse fp
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { immune } is :    0.524877441820188
# Similarity Between { coronavirus } and { pathogen } is :    0.5350284756573006
# __________________________________________________________________
# *************Cluster  4 *********************
# codon tuller gene viral genome structure code mutation sequence host position 2009 expression silent 2016 nfc translation fitness region nsp6 selection goz dana elongation 2010 rna 2012 ribosome 2013 bias relate evolution 2014 bahir 2014b zur mrna synonymous 2015 2011
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { viral } is :    0.6789279758381194
# __________________________________________________________________
# *************Cluster  5 *********************
# fipv centrifugation cat mhc strain antigen inoculation stain viral centrifuge centrifugal infect antibody culture exudate monocyte type surface ucd ku titer fip feline 400 fcwf inoculate method 1146 ii pedersen pyogranuloma enhancement plaque positive infectious black serotype lysis mediate effusive
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { inoculation } is :    0.516190829505902
# Similarity Between { coronavirus } and { viral } is :    0.6789279758381194
# Similarity Between { coronavirus } and { infect } is :    0.6573915586705649
# Similarity Between { coronavirus } and { inoculate } is :    0.6573915586705649
# Similarity Between { coronavirus } and { infectious } is :    0.5332051459892988
# Similarity Between { coronavirus } and { lysis } is :    0.5350284756573006
# __________________________________________________________________
# *************Cluster  6 *********************
# ili qol child ent par parent score sf 12v2 episode caregiver influenza parental interview questionnaire emotional domain impact acute season item examination essential europe exclude euclidean etkin etiology ethical ethic etc estimation estimate establish especially escherichia exclusion erythrocyte error erb
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { influenza } is :    0.6127955278394492
# Similarity Between { coronavirus } and { escherichia } is :    0.5350284756573006
# __________________________________________________________________
# *************Cluster  7 *********************
# pm italian exposure province pollution death proportion incidence provincial region territorial lg gender 10 association confounder extension distribution regression variable italy geographical number annual datum crude stratify mean humidity independent air etiology euclidean european etkin exclusively europe excretion estimate ethical
# -------------------------------------------
# TERM_LIST :  []
#
# __________________________________________________________________
# *************Cluster  8 *********************
# antiviral resistance drug hcv nanoparticle viral inhibitor hiv interferon ribavirin hbv replication development agent inhibit agnps approve therapy rna review treatment target analogue nucleoside host activity polymerase hsv influenza aunps major effective act protease hepatitis entry treat antiretroviral propagation clinical
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { viral } is :    0.6789279758381194
# Similarity Between { coronavirus } and { hsv } is :    0.5938582289935102
# Similarity Between { coronavirus } and { influenza } is :    0.6127955278394492
# Similarity Between { coronavirus } and { hepatitis } is :    0.7140130452187041
# __________________________________________________________________
# *************Cluster  9 *********************
# hcw influenza atypical ed ppe scii presentation contact symptom continue household season abdominal vaccination car ct participant illness report asymptomatic pain prior berlin exposure team ili day ari chest communication care present find ownership respiratory child manuscript titre transport non
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { influenza } is :    0.6127955278394492
# Similarity Between { coronavirus } and { vaccination } is :    0.516190829505902
# __________________________________________________________________
# *************Cluster  10 *********************
# sleep mother anxiety insomnia maternal child crisis report quality trait change confinement acute level score symptom isi pandemic 2020 home retrospectively age duration 001 conduct difference exception euclidean etkin exclusion etiology ethical ethic etc estimation exclusively excretion estimate european establish
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { pandemic } is :    0.5010447134454742
# __________________________________________________________________
# *************Cluster  11 *********************
# surgery surgical contamination covid19 dedicate procedure hospital prefer complication perform possibility worker arterial during phase department effective take period consideration general italy rarely tracheostomy admit negative aerosol outbreak positive acute staff multidisciplinary perspective reduce undergo th steady intubation marginal aggravate
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { outbreak } is :    0.5746238784930114
# __________________________________________________________________
# *************Cluster  12 *********************
# msp pf pv malarial antibody 19 malaria antigen subclass platelet punnath thrombocytopenia level hec anemia anti endemic igg mangaluru 2011 merozoite igg3 igg4 05 infect rbc falciparum igg1 plasmodium observe anemic al southern hemoglobin biotech parasitemia ll 2009 even event
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { malarial } is :    0.5745848854645642
# Similarity Between { coronavirus } and { malaria } is :    0.5332051459892988
# Similarity Between { coronavirus } and { infect } is :    0.6573915586705649
# Similarity Between { coronavirus } and { falciparum } is :    0.5745848854645642
# Similarity Between { coronavirus } and { plasmodium } is :    0.5745848854645642
# __________________________________________________________________
# *************Cluster  13 *********************
# device fda reference performance assay specimen clia diagnostic npv clinical new sensitivity ppv specificity iu guidance eg multiplex method waiver analyte analytical pathogen waive prevalence sponsor intend use estimate submission positive vitro respiratory ide negative process pivotal microbiology sample set
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { pathogen } is :    0.5350284756573006
# __________________________________________________________________
# *************Cluster  14 *********************
# donate gbm blood donation hiri participant policy msm citizenship sexual deferral man donor interview hiv eligible vancouver toronto biological canada grace willingness gay sex sense community think low practice queer political 2019 feel canadian desire montreal etkin etiology ethic excessive
# -------------------------------------------
# TERM_LIST :  []
#
# __________________________________________________________________
# *************Cluster  15 *********************
# mhv jhm peplomer mutant wt ief nc sheet leibowitz oleszak goat antibody 1990a isoelectric blot lysate microheterogeneity l2 rinse 1981 page infect demyelinate glycosylation anti holmes focus ph min glycoprotein describe lane demyelination urea mouse molecular sd exhibit ts specific
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { infect } is :    0.6573915586705649
# __________________________________________________________________
# *************Cluster  16 *********************
# african american discrimination disparity racial gene innate pathway ace2 social angiotensin indirect depression anxiety biological relate immune response system expression ang inflammation inflammatory transcriptional crisis promote think metabolic consequence disproportionately alteration get hypertension alter pandemic issue storm home white abnormal
# -------------------------------------------
# TERM_LIST :  []
# Similarity Between { coronavirus } and { immune } is :    0.524877441820188
# Similarity Between { coronavirus } and { pandemic } is :    0.5010447134454742
# __________________________________________________________________
# *************Cluster  17 *********************
# rural urban mexico old municipality area adult 2020 de semi people 000 disparity access mortality 65 proportion live care la million community vulnerable poverty number para age compare government percentage rate 100 specialty education country el finally spatial 2015 need
# -------------------------------------------
# TERM_LIST :  []
#
# __________________________________________________________________
# *************Cluster  18 *********************
# ns1 chadox1 btv mva immunize mouse nt sheep vaccine immunization animal prime boost viremia dose serotype protection cd8 vector ifnar pfu splenocyte euclidean etkin etiology europe ethical ethic european essential etc estimation estimate establish evaluate especially escherichia erythrocyte error erb
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { vaccine } is :    0.5881906817418034
# Similarity Between { coronavirus } and { immunization } is :    0.516190829505902
# Similarity Between { coronavirus } and { escherichia } is :    0.5350284756573006
# __________________________________________________________________
# *************Cluster  19 *********************
# mrsa hcai vre teicoplanin tigecycline incidence vancomycin linezolid consumption daptomycin fusidic antibiotic correlation glycopeptide aureus antimicrobial isolate acid trend use 1000 resistance find taiwan inpatient resistant gram period annual bacteria agent hospital engineer etc exacerbation endemic endogenous exacerbate evolve evolutionary
# -------------------------------------------
# TERM_LIST :  []
#
# Similarity Between { coronavirus } and { aureus } is :    0.5350284756573006
# Similarity Between { coronavirus } and { antimicrobial } is :    0.5350284756573006
# Similarity Between { coronavirus } and { bacteria } is :    0.5071558643122325
# __________________________________________________________________

# %%
import spacy
nlp = spacy.load('en_core_web_md')
cov_word =nlp("coronavirus")
top_similar = []
for num_clus in range(0,20):
    str1 = ' '.join(all_keywords[num_clus])
    doc = nlp(str1)
    words = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
    for token in doc:
        if cov_word.similarity(token) > 0.5 :
            top_similar.append((token.text , cov_word.similarity(token)))
LL = top_similar
top_similar_sorted = []
for a in top_similar :
    if a not in top_similar_sorted:
        top_similar_sorted.append(a)
top_similar_sorted = sorted(top_similar_sorted, key=lambda tup: tup[1],reverse=True)
top_similar_sorted
# Out:
# <ipython-input-115-7ae6cfacfccd>:10: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   if cov_word.similarity(token) > 0.5 :
# [('hepatitis', 0.7140130452187041),
#  ('viral', 0.6789279758381194),
#  ('infect', 0.6573915586705649),
#  ('inoculate', 0.6573915586705649),
#  ('influenza', 0.6127955278394492),
#  ('hsv', 0.5938582289935102),
#  ('vaccine', 0.5881906817418034),
#  ('outbreak', 0.5746238784930114),
#  ('malarial', 0.5745848854645642),
#  ('falciparum', 0.5745848854645642),
#  ('plasmodium', 0.5745848854645642),
#  ('pathogen', 0.5350284756573006),
#  ('lysis', 0.5350284756573006),
#  ('escherichia', 0.5350284756573006),
#  ('aureus', 0.5350284756573006),
#  ('antimicrobial', 0.5350284756573006),
#  ('infectious', 0.5332051459892988),
#  ('malaria', 0.5332051459892988),
#  ('immune', 0.524877441820188),
#  ('inoculation', 0.516190829505902),
#  ('vaccination', 0.516190829505902),
#  ('immunization', 0.516190829505902),
#  ('bacteria', 0.5071558643122325),
#  ('pandemic', 0.5010447134454742)]

# %%
li = top_similar_sorted[0:10]

# %%
nlp = spacy.load('en_core_web_md')
lii = []
for tup in li:
    cov_word =nlp(tup[0])
    top_similar = []
    for num_clus in range(0,20):
        str1 = ' '.join(all_keywords[num_clus])
        doc = nlp(str1)
        words = [e.text for e in doc.ents if (e.label_ == "DISEASE")]
        for token in doc:
            if cov_word.similarity(token) > 0.5 :
                top_similar.append((token.text , cov_word.similarity(token)))
    top_similar_sorted = []
    for a in top_similar :
        if a not in top_similar_sorted:
            top_similar_sorted.append(a)
    top_similar_sorted = sorted(top_similar_sorted, key=lambda tup: tup[1],reverse=True)
    top_similar_sorted = top_similar_sorted[0:10]
    lii.append((tup[0],top_similar_sorted))
# LL = top_similar
# top_similar_sorted = []
# for a in top_similar :
#     if a not in top_similar_sorted:
#         top_similar_sorted.append(a)
# top_similar_sorted = sorted(top_similar_sorted, key=lambda tup: tup[1],reverse=True)
# top_similar_sorted
lii
# Out:
# <ipython-input-124-47d71d5a65d6>:11: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   if cov_word.similarity(token) > 0.5 :
# [('hepatitis',
#   [('hepatitis', 1.0),
#    ('pathogen', 0.7614367047278192),
#    ('lysis', 0.7614367047278192),
#    ('escherichia', 0.7614367047278192),
#    ('aureus', 0.7614367047278192),
#    ('antimicrobial', 0.7614367047278192),
#    ('hsv', 0.6964687777543246),
#    ('infectious', 0.6859604228532314),
#    ('malaria', 0.6859604228532314),
#    ('onset', 0.679481138478335)]),
#  ('viral',
#   [('viral', 1.0),
#    ('hepatitis', 0.6289952119582034),
#    ('pathogen', 0.5907780408541587),
#    ('lysis', 0.5907780408541587),
#    ('escherichia', 0.5907780408541587),
#    ('aureus', 0.5907780408541587),
#    ('antimicrobial', 0.5907780408541587),
#    ('hsv', 0.5677634550899263),
#    ('vaccine', 0.5168299385443638),
#    ('influenza', 0.513816028588837)]),
#  ('infect',
#   [('infect', 1.0),
#    ('inoculate', 0.9999998812731636),
#    ('hepatitis', 0.5950294030457614),
#    ('malarial', 0.5577280849529789),
#    ('falciparum', 0.5577280849529789),
#    ('plasmodium', 0.5577280849529789),
#    ('bacteria', 0.5526717731580465),
#    ('hospitalize', 0.5072075049318927)]),
#  ('inoculate',
#   [('inoculate', 1.0),
#    ('infect', 0.9999998812731636),
#    ('hepatitis', 0.5950294030457614),
#    ('malarial', 0.5577280849529789),
#    ('falciparum', 0.5577280849529789),
#    ('plasmodium', 0.5577280849529789),
#    ('bacteria', 0.5526717731580465),
#    ('hospitalize', 0.5072075049318927)]),
#  ('influenza',
#   [('influenza', 1.0),
#    ('vaccine', 0.7106952160229285),
#    ('outbreak', 0.699400466700272),
#    ('inoculation', 0.6479943843871718),
#    ('vaccination', 0.6479943843871718),
#    ('immunization', 0.6479943843871718),
#    ('pandemic', 0.6435812281406311),
#    ('illness', 0.608865799798042),
#    ('hepatitis', 0.603404838735448),
#    ('titer', 0.5620360295411544)]),
#  ('hsv',
#   [('hsv', 1.0),
#    ('hcv', 0.6966232839746883),
#    ('hiv', 0.6966232839746883),
#    ('hbv', 0.6966232839746883),
#    ('antiretroviral', 0.6966232839746883),
#    ('hepatitis', 0.6964687492682669),
#    ('mrsa', 0.5767813495621433),
#    ('onset', 0.5731382310167763),
#    ('viral', 0.5677634644533757),
#    ('infectious', 0.5297399884856706)]),
#  ('vaccine',
#   [('vaccine', 1.0),
#    ('inoculation', 0.8618475945728371),
#    ('vaccination', 0.8618475945728371),
#    ('immunization', 0.8618475945728371),
#    ('influenza', 0.7106952024937736),
#    ('titer', 0.6996222704494065),
#    ('immunize', 0.6996222704494065),
#    ('hepatitis', 0.5635536173261945),
#    ('outbreak', 0.5612703018071734),
#    ('ribavirin', 0.5554457356038474)]),
#  ('outbreak',
#   [('outbreak', 1.0),
#    ('pandemic', 0.7496999518467676),
#    ('influenza', 0.6994004904415994),
#    ('hepatitis', 0.5921143392902705),
#    ('vaccine', 0.561270331544264),
#    ('inoculation', 0.5423195894551589),
#    ('vaccination', 0.5423195894551589),
#    ('immunization', 0.5423195894551589),
#    ('illness', 0.5147422543598418),
#    ('infectious', 0.5137626277292313)]),
#  ('malarial',
#   [('falciparum', 1.0000000418393422),
#    ('plasmodium', 1.0000000418393422),
#    ('malarial', 1.0),
#    ('hepatitis', 0.6058311596922014),
#    ('pathogen', 0.6004240005538403),
#    ('lysis', 0.6004240005538403),
#    ('escherichia', 0.6004240005538403),
#    ('aureus', 0.6004240005538403),
#    ('antimicrobial', 0.6004240005538403),
#    ('bacteria', 0.5705381926245026)]),
#  ('falciparum',
#   [('malarial', 1.0000000418393422),
#    ('plasmodium', 1.0000000418393422),
#    ('falciparum', 1.0),
#    ('hepatitis', 0.6058311596922014),
#    ('pathogen', 0.6004240005538403),
#    ('lysis', 0.6004240005538403),
#    ('escherichia', 0.6004240005538403),
#    ('aureus', 0.6004240005538403),
#    ('antimicrobial', 0.6004240005538403),
#    ('bacteria', 0.5705381926245026)])]

# %%
from Bio import Entrez
from Bio import Medline
import json


MAX_COUNT = 3
for TERM in TERM_LIST:
    Entrez.email = 'A.N.Other@example.com'
    h = Entrez.esearch(db='pubmed', retmax=MAX_COUNT, term=TERM)
    result = Entrez.read(h)
    ids = result['IdList']
    h = Entrez.efetch(db='pubmed', id=ids, rettype='medline', retmode='json')
    records = Medline.parse(h)
    i=0
    for record in records:
        filename="fichier_"+TERM+str(i)+".json"
        json.dump(record, open(".\\new_corpus\\"+filename, 'w'))
        data = json.load(open(".\\new_corpus\\"+filename))
        i=i+1
[(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]

# %%
len(all_keywords)
